# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/gobackseb_sweep.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0     7
# name           gobackseb_bbvgg16_totalrepro
# study          iid_study
# model          confidnet_model
# network        vgg16
# fold           0
# confid         mcd_waic
# n_test         10000
# accuracy       0.9324
# nll            0.02026
# brier_score    0.10015
# failauc        0.93007
# failap_suc     0.99446
# failap_err     0.47094
# mce            0.23419
# ece            0.00728
# e-aurc         5.24658
# aurc           7.58476
# fpr@95tpr      0.44231
# Name: 47, dtype: object

# %%
len(df)
# Out:
# 48

# %%
df.groupby("study").count()
# Out:
#            Unnamed: 0  name  model  network  fold  confid  n_test  accuracy  \
# study
# iid_study  48          48    48     48       48    48      48      48
#
#            nll  brier_score  failauc  failap_suc  failap_err  mce  ece  \
# study
# iid_study  48   48           48       48          48          48   48
#
#            e-aurc  aurc  fpr@95tpr
# study
# iid_study  48      48    48

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"], keep="last")

# %%
len(df_clean)
# Out:
# 48

# %%
df_clean.groupby("name").count()
# Out:
#                               Unnamed: 0  study  model  network  fold  confid  \
# name
# gobackseb_bbvgg13             8           8      8      8        8     8
# gobackseb_bbvgg13_fixeddo     8           8      8      8        8     8
# gobackseb_bbvgg13_totalrepro  8           8      8      8        8     8
# gobackseb_bbvgg16             8           8      8      8        8     8
# gobackseb_bbvgg16_fixeddo     8           8      8      8        8     8
# gobackseb_bbvgg16_totalrepro  8           8      8      8        8     8
#
#                               n_test  accuracy  nll  brier_score  failauc  \
# name
# gobackseb_bbvgg13             8       8         8    8            8
# gobackseb_bbvgg13_fixeddo     8       8         8    8            8
# gobackseb_bbvgg13_totalrepro  8       8         8    8            8
# gobackseb_bbvgg16             8       8         8    8            8
# gobackseb_bbvgg16_fixeddo     8       8         8    8            8
# gobackseb_bbvgg16_totalrepro  8       8         8    8            8
#
#                               failap_suc  failap_err  mce  ece  e-aurc  aurc  \
# name
# gobackseb_bbvgg13             8           8           8    8    8       8
# gobackseb_bbvgg13_fixeddo     8           8           8    8    8       8
# gobackseb_bbvgg13_totalrepro  8           8           8    8    8       8
# gobackseb_bbvgg16             8           8           8    8    8       8
# gobackseb_bbvgg16_fixeddo     8           8           8    8    8       8
# gobackseb_bbvgg16_totalrepro  8           8           8    8    8       8
#
#                               fpr@95tpr
# name
# gobackseb_bbvgg13             8
# gobackseb_bbvgg13_fixeddo     8
# gobackseb_bbvgg13_totalrepro  8
# gobackseb_bbvgg16             8
# gobackseb_bbvgg16_fixeddo     8
# gobackseb_bbvgg16_totalrepro  8

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-23-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                             name    confid  accuracy  failauc  failap_err  \
# 2   gobackseb_bbvgg13_fixeddo     mcd_mcp   0.9341    0.93087  0.44997
# 7   gobackseb_bbvgg13_fixeddo     mcd_waic  0.9341    0.93035  0.45205
# 18  gobackseb_bbvgg13_totalrepro  mcd_mcp   0.9329    0.93169  0.44542
# 23  gobackseb_bbvgg13_totalrepro  mcd_waic  0.9329    0.93142  0.44539
# 3   gobackseb_bbvgg13_fixeddo     mcd_pe    0.9341    0.92677  0.42000
# 4   gobackseb_bbvgg13_fixeddo     mcd_ee    0.9341    0.92660  0.40821
# 19  gobackseb_bbvgg13_totalrepro  mcd_pe    0.9329    0.92955  0.42619
# 42  gobackseb_bbvgg16_totalrepro  mcd_mcp   0.9324    0.93058  0.47023
# 20  gobackseb_bbvgg13_totalrepro  mcd_ee    0.9329    0.92847  0.42333
# 22  gobackseb_bbvgg13_totalrepro  mcd_sv    0.9329    0.92825  0.40997
# 47  gobackseb_bbvgg16_totalrepro  mcd_waic  0.9324    0.93007  0.47094
# 21  gobackseb_bbvgg13_totalrepro  mcd_mi    0.9329    0.92699  0.40632
# 6   gobackseb_bbvgg13_fixeddo     mcd_sv    0.9341    0.92347  0.38730
# 43  gobackseb_bbvgg16_totalrepro  mcd_pe    0.9324    0.92712  0.44806
# 5   gobackseb_bbvgg13_fixeddo     mcd_mi    0.9341    0.92142  0.40755
# 44  gobackseb_bbvgg16_totalrepro  mcd_ee    0.9324    0.92613  0.43935
# 46  gobackseb_bbvgg16_totalrepro  mcd_sv    0.9324    0.92543  0.41555
# 33  gobackseb_bbvgg16_fixeddo     det_pe    0.9306    0.92999  0.45982
# 34  gobackseb_bbvgg16_fixeddo     mcd_mcp   0.9308    0.93090  0.46162
# 45  gobackseb_bbvgg16_totalrepro  mcd_mi    0.9324    0.92325  0.43060
# 32  gobackseb_bbvgg16_fixeddo     det_mcp   0.9306    0.92914  0.45778
# 39  gobackseb_bbvgg16_fixeddo     mcd_waic  0.9308    0.92814  0.46003
# 1   gobackseb_bbvgg13_fixeddo     det_pe    0.9290    0.92927  0.45585
# 36  gobackseb_bbvgg16_fixeddo     mcd_ee    0.9308    0.92536  0.42503
# 35  gobackseb_bbvgg16_fixeddo     mcd_pe    0.9308    0.92525  0.42570
# 41  gobackseb_bbvgg16_totalrepro  det_pe    0.9297    0.92587  0.47948
# 40  gobackseb_bbvgg16_totalrepro  det_mcp   0.9297    0.92661  0.48728
# 38  gobackseb_bbvgg16_fixeddo     mcd_sv    0.9308    0.92125  0.38795
# 17  gobackseb_bbvgg13_totalrepro  det_pe    0.9296    0.92348  0.47455
# 0   gobackseb_bbvgg13_fixeddo     det_mcp   0.9290    0.92636  0.44673
# 37  gobackseb_bbvgg16_fixeddo     mcd_mi    0.9308    0.91688  0.39414
# 26  gobackseb_bbvgg13             mcd_mcp   0.9248    0.92608  0.45902
# 16  gobackseb_bbvgg13_totalrepro  det_mcp   0.9296    0.92220  0.45565
# 10  gobackseb_bbvgg16             mcd_mcp   0.9229    0.92675  0.48513
# 31  gobackseb_bbvgg13             mcd_waic  0.9248    0.92331  0.45311
# 27  gobackseb_bbvgg13             mcd_pe    0.9248    0.91888  0.42413
# 28  gobackseb_bbvgg13             mcd_ee    0.9248    0.91878  0.41609
# 11  gobackseb_bbvgg16             mcd_pe    0.9229    0.91857  0.44362
# 12  gobackseb_bbvgg16             mcd_ee    0.9229    0.91794  0.43482
# 30  gobackseb_bbvgg13             mcd_sv    0.9248    0.91439  0.38043
# 14  gobackseb_bbvgg16             mcd_sv    0.9229    0.91484  0.39805
# 29  gobackseb_bbvgg13             mcd_mi    0.9248    0.90931  0.39088
# 15  gobackseb_bbvgg16             mcd_waic  0.9229    0.91396  0.45274
# 13  gobackseb_bbvgg16             mcd_mi    0.9229    0.90973  0.41287
# 8   gobackseb_bbvgg16             det_mcp   0.8914    0.90934  0.51365
# 9   gobackseb_bbvgg16             det_pe    0.8914    0.90515  0.48984
# 24  gobackseb_bbvgg13             det_mcp   0.8824    0.91030  0.52946
# 25  gobackseb_bbvgg13             det_pe    0.8824    0.90660  0.50981
#
#         aurc
# 2   7.14442
# 7   7.21584
# 18  7.31631
# 23  7.34310
# 3   7.42017
# 4   7.43107
# 19  7.45652
# 42  7.50950
# 20  7.53710
# 22  7.58209
# 47  7.58476
# 21  7.64831
# 6   7.67690
# 43  7.75144
# 5   7.81963
# 44  7.82906
# 46  7.85367
# 33  7.86970
# 34  7.90192
# 45  8.02231
# 32  8.02862
# 39  8.03351
# 1   8.04654
# 36  8.28180
# 35  8.30506
# 41  8.46712
# 40  8.48594
# 38  8.67732
# 17  8.74848
# 0   8.79179
# 37  9.03139
# 26  9.04380
# 16  9.19956
# 10  9.24038
# 31  9.28728
# 27  9.61914
# 28  9.62501
# 11  9.90280
# 12  9.96121
# 30  10.03210
# 14  10.23281
# 29  10.45428
# 15  10.48567
# 13  10.67731
# 8   17.20619
# 9   17.67669
# 24  18.94556
# 25  19.37704

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["mode"] = df.apply(lambda row: "fixeddo" if "fixeddo" in row["name"] else "normal", axis=1)
df["mode"] = df.apply(lambda row: "totalrepro" if "totalrepro" in row["name"] else row["mode"], axis=1)

# %%
data =  df[(df.study == "iid_study") ]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
dims = ["confid", "backbone", "mode"]
metrics = ["accuracy", "failauc", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()

# %%
sns.stripplot(x="pure_det", y="accuracy", data=df[(df.study == "iid_study") & (df.confid== "det_mcp")])
sns.boxplot(x="pure_det", y="accuracy", data=df[(df.study == "iid_study") & (df.confid== "det_mcp")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")  & (df.confid=="devries")].name
