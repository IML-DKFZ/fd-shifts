# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/tcp_decision_sweep.csv"
df = pd.read_csv(in_path)

# %%
len(df)
# Out:
# 1512

# %%
df.groupby("study").count()
df = df.drop(df[df.model=="mcd_sv"].index)
print(len(df))
# Out:
# 1512

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"])

# %%
len(df_clean)
# Out:
# 1512

# %%
df_clean.groupby("name").count()
# Out:
#                                                Unnamed: 0  study  model  \
# name
# confidnet_model_bbvgg13_do0_ne200_run0_apTrue          27     27     27
# confidnet_model_bbvgg13_do0_ne200_run1_apTrue          27     27     27
# confidnet_model_bbvgg13_do0_ne200_run2_apTrue          27     27     27
# confidnet_model_bbvgg13_do0_ne250_run0_apTrue          27     27     27
# confidnet_model_bbvgg13_do0_ne250_run1_apTrue          27     27     27
# confidnet_model_bbvgg13_do0_ne250_run2_apTrue          27     27     27
# confidnet_model_bbvgg13_do1_ne200_run0_apTrue          99     99     99
# confidnet_model_bbvgg13_do1_ne200_run1_apTrue          99     99     99
# confidnet_model_bbvgg13_do1_ne200_run2_apTrue          99     99     99
# confidnet_model_bbvgg13_do1_ne250_run0_apTrue          99     99     99
# confidnet_model_bbvgg13_do1_ne250_run1_apTrue          99     99     99
# confidnet_model_bbvgg13_do1_ne250_run2_apTrue          99     99     99
# confidnet_model_bbvgg16_do0_ne200_run0_apTrue          27     27     27
# confidnet_model_bbvgg16_do0_ne200_run1_apTrue          27     27     27
# confidnet_model_bbvgg16_do0_ne200_run2_apTrue          27     27     27
# confidnet_model_bbvgg16_do0_ne250_run0_apTrue          27     27     27
# confidnet_model_bbvgg16_do0_ne250_run1_apTrue          27     27     27
# confidnet_model_bbvgg16_do0_ne250_run2_apTrue          27     27     27
# confidnet_model_bbvgg16_do1_ne200_run0_apTrue          99     99     99
# confidnet_model_bbvgg16_do1_ne200_run1_apTrue          99     99     99
# confidnet_model_bbvgg16_do1_ne200_run2_apTrue          99     99     99
# confidnet_model_bbvgg16_do1_ne250_run0_apTrue          99     99     99
# confidnet_model_bbvgg16_do1_ne250_run1_apTrue          99     99     99
# confidnet_model_bbvgg16_do1_ne250_run2_apTrue          99     99     99
#
#                                                network  fold  confid  n_test  \
# name
# confidnet_model_bbvgg13_do0_ne200_run0_apTrue       27    27      27      27
# confidnet_model_bbvgg13_do0_ne200_run1_apTrue       27    27      27      27
# confidnet_model_bbvgg13_do0_ne200_run2_apTrue       27    27      27      27
# confidnet_model_bbvgg13_do0_ne250_run0_apTrue       27    27      27      27
# confidnet_model_bbvgg13_do0_ne250_run1_apTrue       27    27      27      27
# confidnet_model_bbvgg13_do0_ne250_run2_apTrue       27    27      27      27
# confidnet_model_bbvgg13_do1_ne200_run0_apTrue       99    99      99      99
# confidnet_model_bbvgg13_do1_ne200_run1_apTrue       99    99      99      99
# confidnet_model_bbvgg13_do1_ne200_run2_apTrue       99    99      99      99
# confidnet_model_bbvgg13_do1_ne250_run0_apTrue       99    99      99      99
# confidnet_model_bbvgg13_do1_ne250_run1_apTrue       99    99      99      99
# confidnet_model_bbvgg13_do1_ne250_run2_apTrue       99    99      99      99
# confidnet_model_bbvgg16_do0_ne200_run0_apTrue       27    27      27      27
# confidnet_model_bbvgg16_do0_ne200_run1_apTrue       27    27      27      27
# confidnet_model_bbvgg16_do0_ne200_run2_apTrue       27    27      27      27
# confidnet_model_bbvgg16_do0_ne250_run0_apTrue       27    27      27      27
# confidnet_model_bbvgg16_do0_ne250_run1_apTrue       27    27      27      27
# confidnet_model_bbvgg16_do0_ne250_run2_apTrue       27    27      27      27
# confidnet_model_bbvgg16_do1_ne200_run0_apTrue       99    99      99      99
# confidnet_model_bbvgg16_do1_ne200_run1_apTrue       99    99      99      99
# confidnet_model_bbvgg16_do1_ne200_run2_apTrue       99    99      99      99
# confidnet_model_bbvgg16_do1_ne250_run0_apTrue       99    99      99      99
# confidnet_model_bbvgg16_do1_ne250_run1_apTrue       99    99      99      99
# confidnet_model_bbvgg16_do1_ne250_run2_apTrue       99    99      99      99
#
#                                                accuracy  nll  brier_score  \
# name
# confidnet_model_bbvgg13_do0_ne200_run0_apTrue        27    3            3
# confidnet_model_bbvgg13_do0_ne200_run1_apTrue        27    3            3
# confidnet_model_bbvgg13_do0_ne200_run2_apTrue        27    3            3
# confidnet_model_bbvgg13_do0_ne250_run0_apTrue        27    3            3
# confidnet_model_bbvgg13_do0_ne250_run1_apTrue        27    3            3
# confidnet_model_bbvgg13_do0_ne250_run2_apTrue        27    3            3
# confidnet_model_bbvgg13_do1_ne200_run0_apTrue        99   11           11
# confidnet_model_bbvgg13_do1_ne200_run1_apTrue        99   11           11
# confidnet_model_bbvgg13_do1_ne200_run2_apTrue        99   11           11
# confidnet_model_bbvgg13_do1_ne250_run0_apTrue        99   11           11
# confidnet_model_bbvgg13_do1_ne250_run1_apTrue        99   11           11
# confidnet_model_bbvgg13_do1_ne250_run2_apTrue        99   11           11
# confidnet_model_bbvgg16_do0_ne200_run0_apTrue        27    3            3
# confidnet_model_bbvgg16_do0_ne200_run1_apTrue        27    3            3
# confidnet_model_bbvgg16_do0_ne200_run2_apTrue        27    3            3
# confidnet_model_bbvgg16_do0_ne250_run0_apTrue        27    3            3
# confidnet_model_bbvgg16_do0_ne250_run1_apTrue        27    3            3
# confidnet_model_bbvgg16_do0_ne250_run2_apTrue        27    3            3
# confidnet_model_bbvgg16_do1_ne200_run0_apTrue        99   11           11
# confidnet_model_bbvgg16_do1_ne200_run1_apTrue        99   11           11
# confidnet_model_bbvgg16_do1_ne200_run2_apTrue        99   11           11
# confidnet_model_bbvgg16_do1_ne250_run0_apTrue        99   11           11
# confidnet_model_bbvgg16_do1_ne250_run1_apTrue        99   11           11
# confidnet_model_bbvgg16_do1_ne250_run2_apTrue        99   11           11
#
#                                                failauc  failap_suc  \
# name
# confidnet_model_bbvgg13_do0_ne200_run0_apTrue       27          27
# confidnet_model_bbvgg13_do0_ne200_run1_apTrue       27          27
# confidnet_model_bbvgg13_do0_ne200_run2_apTrue       27          27
# confidnet_model_bbvgg13_do0_ne250_run0_apTrue       27          27
# confidnet_model_bbvgg13_do0_ne250_run1_apTrue       27          27
# confidnet_model_bbvgg13_do0_ne250_run2_apTrue       27          27
# confidnet_model_bbvgg13_do1_ne200_run0_apTrue       99          99
# confidnet_model_bbvgg13_do1_ne200_run1_apTrue       99          99
# confidnet_model_bbvgg13_do1_ne200_run2_apTrue       99          99
# confidnet_model_bbvgg13_do1_ne250_run0_apTrue       99          99
# confidnet_model_bbvgg13_do1_ne250_run1_apTrue       99          99
# confidnet_model_bbvgg13_do1_ne250_run2_apTrue       99          99
# confidnet_model_bbvgg16_do0_ne200_run0_apTrue       27          27
# confidnet_model_bbvgg16_do0_ne200_run1_apTrue       27          27
# confidnet_model_bbvgg16_do0_ne200_run2_apTrue       27          27
# confidnet_model_bbvgg16_do0_ne250_run0_apTrue       27          27
# confidnet_model_bbvgg16_do0_ne250_run1_apTrue       27          27
# confidnet_model_bbvgg16_do0_ne250_run2_apTrue       27          27
# confidnet_model_bbvgg16_do1_ne200_run0_apTrue       99          99
# confidnet_model_bbvgg16_do1_ne200_run1_apTrue       99          99
# confidnet_model_bbvgg16_do1_ne200_run2_apTrue       99          99
# confidnet_model_bbvgg16_do1_ne250_run0_apTrue       99          99
# confidnet_model_bbvgg16_do1_ne250_run1_apTrue       99          99
# confidnet_model_bbvgg16_do1_ne250_run2_apTrue       99          99
#
#                                                failap_err  mce  ece  e-aurc  \
# name
# confidnet_model_bbvgg13_do0_ne200_run0_apTrue          27   27   27      27
# confidnet_model_bbvgg13_do0_ne200_run1_apTrue          27   27   27      27
# confidnet_model_bbvgg13_do0_ne200_run2_apTrue          27   27   27      27
# confidnet_model_bbvgg13_do0_ne250_run0_apTrue          27   27   27      27
# confidnet_model_bbvgg13_do0_ne250_run1_apTrue          27   27   27      27
# confidnet_model_bbvgg13_do0_ne250_run2_apTrue          27   27   27      27
# confidnet_model_bbvgg13_do1_ne200_run0_apTrue          99   99   99      99
# confidnet_model_bbvgg13_do1_ne200_run1_apTrue          99   99   99      99
# confidnet_model_bbvgg13_do1_ne200_run2_apTrue          99   99   99      99
# confidnet_model_bbvgg13_do1_ne250_run0_apTrue          99   99   99      99
# confidnet_model_bbvgg13_do1_ne250_run1_apTrue          99   99   99      99
# confidnet_model_bbvgg13_do1_ne250_run2_apTrue          99   99   99      99
# confidnet_model_bbvgg16_do0_ne200_run0_apTrue          27   27   27      27
# confidnet_model_bbvgg16_do0_ne200_run1_apTrue          27   27   27      27
# confidnet_model_bbvgg16_do0_ne200_run2_apTrue          27   27   27      27
# confidnet_model_bbvgg16_do0_ne250_run0_apTrue          27   27   27      27
# confidnet_model_bbvgg16_do0_ne250_run1_apTrue          27   27   27      27
# confidnet_model_bbvgg16_do0_ne250_run2_apTrue          27   27   27      27
# confidnet_model_bbvgg16_do1_ne200_run0_apTrue          99   99   99      99
# confidnet_model_bbvgg16_do1_ne200_run1_apTrue          99   99   99      99
# confidnet_model_bbvgg16_do1_ne200_run2_apTrue          99   99   99      99
# confidnet_model_bbvgg16_do1_ne250_run0_apTrue          99   99   99      99
# confidnet_model_bbvgg16_do1_ne250_run1_apTrue          99   99   99      99
# confidnet_model_bbvgg16_do1_ne250_run2_apTrue          99   99   99      99
#
#                                                aurc  fpr@95tpr
# name
# confidnet_model_bbvgg13_do0_ne200_run0_apTrue    27         27
# confidnet_model_bbvgg13_do0_ne200_run1_apTrue    27         27
# confidnet_model_bbvgg13_do0_ne200_run2_apTrue    27         27
# confidnet_model_bbvgg13_do0_ne250_run0_apTrue    27         27
# confidnet_model_bbvgg13_do0_ne250_run1_apTrue    27         27
# confidnet_model_bbvgg13_do0_ne250_run2_apTrue    27         27
# confidnet_model_bbvgg13_do1_ne200_run0_apTrue    99         99
# confidnet_model_bbvgg13_do1_ne200_run1_apTrue    99         99
# confidnet_model_bbvgg13_do1_ne200_run2_apTrue    99         99
# confidnet_model_bbvgg13_do1_ne250_run0_apTrue    99         99
# confidnet_model_bbvgg13_do1_ne250_run1_apTrue    99         99
# confidnet_model_bbvgg13_do1_ne250_run2_apTrue    99         99
# confidnet_model_bbvgg16_do0_ne200_run0_apTrue    27         27
# confidnet_model_bbvgg16_do0_ne200_run1_apTrue    27         27
# confidnet_model_bbvgg16_do0_ne200_run2_apTrue    27         27
# confidnet_model_bbvgg16_do0_ne250_run0_apTrue    27         27
# confidnet_model_bbvgg16_do0_ne250_run1_apTrue    27         27
# confidnet_model_bbvgg16_do0_ne250_run2_apTrue    27         27
# confidnet_model_bbvgg16_do1_ne200_run0_apTrue    99         99
# confidnet_model_bbvgg16_do1_ne200_run1_apTrue    99         99
# confidnet_model_bbvgg16_do1_ne200_run2_apTrue    99         99
# confidnet_model_bbvgg16_do1_ne250_run0_apTrue    99         99
# confidnet_model_bbvgg16_do1_ne250_run1_apTrue    99         99
# confidnet_model_bbvgg16_do1_ne250_run2_apTrue    99         99

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean
df[:10]
# Out:
#    Unnamed: 0                                           name  \
# 0           0  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 1           1  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 2           2  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 3           0  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 4           1  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 5           2  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 6           0  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 7           1  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 8           2  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
# 9           0  confidnet_model_bbvgg13_do0_ne200_run2_apTrue
#
#                                                study            model network  \
# 0                                          iid_study  confidnet_model   vgg13
# 1                                          iid_study  confidnet_model   vgg13
# 2                                          iid_study  confidnet_model   vgg13
# 3         new_class_study_tinyimagenet_original_mode  confidnet_model   vgg13
# 4         new_class_study_tinyimagenet_original_mode  confidnet_model   vgg13
# 5         new_class_study_tinyimagenet_original_mode  confidnet_model   vgg13
# 6         new_class_study_tinyimagenet_proposed_mode  confidnet_model   vgg13
# 7         new_class_study_tinyimagenet_proposed_mode  confidnet_model   vgg13
# 8         new_class_study_tinyimagenet_proposed_mode  confidnet_model   vgg13
# 9  new_class_study_tinyimagenet_resize_original_mode  confidnet_model   vgg13
#
#    fold   confid  n_test  accuracy      nll  brier_score  failauc  failap_suc  \
# 0     0  det_mcp    9000   0.94622  0.01933      0.08421  0.93423     0.99506
# 1     0   det_pe    9000   0.94622  0.01933      0.08421  0.93525     0.99539
# 2     0      tcp    9000   0.94622  0.01933      0.08421  0.93506     0.99527
# 3     0  det_mcp   18000   0.50000      NaN          NaN  0.93594     0.94456
# 4     0   det_pe   18000   0.50000      NaN          NaN  0.94220     0.95021
# 5     0      tcp   18000   0.50000      NaN          NaN  0.93585     0.94577
# 6     0  det_mcp   17516   0.48618      NaN          NaN  0.95614     0.95662
# 7     0   det_pe   17516   0.48618      NaN          NaN  0.96027     0.96152
# 8     0      tcp   17516   0.48618      NaN          NaN  0.95576     0.95790
# 9     0  det_mcp   18000   0.50000      NaN          NaN  0.93438     0.94360
#
#    failap_err      mce      ece    e-aurc       aurc  fpr@95tpr
# 0     0.47112  0.29053  0.02907   4.71886    6.19153    0.33678
# 1     0.48842  0.26125  0.01411   4.39973    5.87240    0.34298
# 2     0.47679  0.16055  0.02104   4.51832    5.99098    0.33264
# 3     0.91644  0.74592  0.35373  31.98592  185.41233    0.42944
# 4     0.93062  0.63905  0.29239  28.33400  181.76041    0.38033
# 5     0.92007  0.72816  0.31383  31.16329  184.58970    0.43933
# 6     0.94971  0.78660  0.36936  23.76247  186.95802    0.25378
# 7     0.95857  0.68200  0.30807  20.79661  183.99217    0.23578
# 8     0.95155  0.76304  0.32998  22.96406  186.15961    0.26978
# 9     0.91444  0.74225  0.35559  32.60052  186.02693    0.43900

# %%
df = df.dropna(subset=["name"])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)
#df[(df.study.str.contains("tinyimagenet_resize_original")) & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="failauc", ascending=False)
# Out:
# <ipython-input-12-6bbc6dd86d9c>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df = df[df.name.str.contains("ne2") ]
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["model"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["run"] = df.apply(lambda row: row["name"].split("run")[1].split("_")[0] if "run" in row["name"] else "-1", axis=1)
# df["relu"] = df.apply(lambda row: "last" if ("last" in row["name"] or row["backbone"]=="vgg") else "first", axis=1)
# df["reflect"] = df.apply(lambda row: False if ("noreflect" in row["name"] or row["backbone"]=="vgg") else True, axis=1)
df["ne"] = df.apply(lambda row: row["name"].split("_ne")[1].split("_")[0], axis=1)
df["ap"] = df.apply(lambda row: False if "apFalse" in row["name"] else True, axis=1)


# df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)
# df.backbone.tolist()

# %%
import numpy as np
dfg = df.groupby(by=["study", "backbone", "ne", "dropout", "ap", "confid"]).mean().reset_index()
dfg_std = df.groupby(by=["study", "backbone", "ne", "dropout", "ap", "confid"]).std().reset_index()
rename_dict = {k:"{}_std".format(k) for k in dfg.columns if k not in ["study", "backbone", "ne", "dropout", "ap", "confid"] }
dfg_std = dfg_std.rename(columns=rename_dict)
print(len(df), len(dfg), len(dfg_std))
print(dfg_std.columns)
print(rename_dict)
# Out:
# 1512 504 504
# Index(['study', 'backbone', 'ne', 'dropout', 'ap', 'confid', 'Unnamed: 0_std',
#        'fold_std', 'n_test_std', 'accuracy_std', 'nll_std', 'brier_score_std',
#        'failauc_std', 'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std',
#        'e-aurc_std', 'aurc_std', 'fpr@95tpr_std'],
#       dtype='object')
# {'Unnamed: 0': 'Unnamed: 0_std', 'fold': 'fold_std', 'n_test': 'n_test_std', 'accuracy': 'accuracy_std', 'nll': 'nll_std', 'brier_score': 'brier_score_std', 'failauc': 'failauc_std', 'failap_suc': 'failap_suc_std', 'failap_err': 'failap_err_std', 'mce': 'mce_std', 'ece': 'ece_std', 'e-aurc': 'e-aurc_std', 'aurc': 'aurc_std', 'fpr@95tpr': 'fpr@95tpr_std'}

# %%
study= "iid_study"
data =  dfg[(dfg.study == study)]
data_std =  dfg_std[(dfg_std.study == study)]
# data =  df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]

# %%
plot_data = data
dims = ["confid", "backbone", "dropout", "ne", "ap"]
metrics = ["accuracy", "failauc", "failap_err", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()

# %%
std_columns = [c for c in data_std.columns if "std"in c]
for s in std_columns:
    data[s] = data_std[s]

print(data.columns)
print(data_std.columns)
print(len(data))
data[["backbone", "ne", "ap", "dropout", "confid", "failauc", "failauc_std", "aurc", "aurc_std", "failap_suc", "accuracy", "accuracy_std"]].sort_values(by="aurc", ascending=True)
# Out:
# Index(['study', 'backbone', 'ne', 'dropout', 'ap', 'confid', 'Unnamed: 0',
#        'fold', 'n_test', 'accuracy', 'nll', 'brier_score', 'failauc',
#        'failap_suc', 'failap_err', 'mce', 'ece', 'e-aurc', 'aurc', 'fpr@95tpr',
#        'Unnamed: 0_std', 'fold_std', 'n_test_std', 'accuracy_std', 'nll_std',
#        'brier_score_std', 'failauc_std', 'failap_suc_std', 'failap_err_std',
#        'mce_std', 'ece_std', 'e-aurc_std', 'aurc_std', 'fpr@95tpr_std'],
#       dtype='object')
# Index(['study', 'backbone', 'ne', 'dropout', 'ap', 'confid', 'Unnamed: 0_std',
#        'fold_std', 'n_test_std', 'accuracy_std', 'nll_std', 'brier_score_std',
#        'failauc_std', 'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std',
#        'e-aurc_std', 'aurc_std', 'fpr@95tpr_std'],
#       dtype='object')
# 56
# <ipython-input-17-97c2e6ee3129>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[s] = data_std[s]
#    backbone   ne    ap dropout    confid   failauc  failauc_std      aurc  \
# 48  vgg16    250  True  1       mcd_mcp   0.942110  0.001185     5.000660
# 50  vgg16    250  True  1       mcd_pe    0.939757  0.001046     5.132473
# 20  vgg13    250  True  1       mcd_mcp   0.938620  0.002740     5.145330
# 6   vgg13    200  True  1       mcd_mcp   0.939403  0.001984     5.174943
# 47  vgg16    250  True  1       mcd_ee    0.938930  0.000442     5.175550
# 26  vgg13    250  True  1       tcp_mcd   0.937273  0.002536     5.184370
# 54  vgg16    250  True  1       tcp_mcd   0.939940  0.001352     5.186270
# 30  vgg16    200  True  0       tcp       0.937173  0.003078     5.190873
# 29  vgg16    200  True  0       det_pe    0.937693  0.000881     5.208897
# 22  vgg13    250  True  1       mcd_pe    0.936973  0.002842     5.234547
# 27  vgg13    250  True  1       tcp_waic  0.936237  0.002392     5.235120
# 12  vgg13    200  True  1       tcp_mcd   0.938113  0.001228     5.242700
# 55  vgg16    250  True  1       tcp_waic  0.938717  0.001534     5.254717
# 19  vgg13    250  True  1       mcd_ee    0.936137  0.002589     5.285703
# 15  vgg13    250  True  0       det_pe    0.937100  0.003474     5.285880
# 8   vgg13    200  True  1       mcd_pe    0.937013  0.002632     5.307013
# 13  vgg13    200  True  1       tcp_waic  0.936593  0.001587     5.319227
# 5   vgg13    200  True  1       mcd_ee    0.936450  0.002141     5.335630
# 51  vgg16    250  True  1       mcd_sv    0.936110  0.002291     5.340733
# 16  vgg13    250  True  0       tcp       0.936707  0.003025     5.343590
# 23  vgg13    250  True  1       mcd_sv    0.933673  0.003314     5.410413
# 49  vgg16    250  True  1       mcd_mi    0.934953  0.002525     5.413513
# 21  vgg13    250  True  1       mcd_mi    0.933323  0.003943     5.419827
# 1   vgg13    200  True  0       det_pe    0.934370  0.004406     5.429367
# 34  vgg16    200  True  1       mcd_mcp   0.939573  0.001378     5.460383
# 46  vgg16    250  True  1       det_pe    0.938610  0.001106     5.466887
# 24  vgg13    250  True  1       mcd_waic  0.933123  0.003988     5.490167
# 52  vgg16    250  True  1       mcd_waic  0.934750  0.002481     5.504620
# 2   vgg13    200  True  0       tcp       0.934403  0.006151     5.523770
# 9   vgg13    200  True  1       mcd_sv    0.933317  0.003253     5.529937
# 14  vgg13    250  True  0       det_mcp   0.937260  0.003591     5.558393
# 53  vgg16    250  True  1       tcp       0.937987  0.000915     5.571900
# 40  vgg16    200  True  1       tcp_mcd   0.937333  0.001404     5.577810
# 44  vgg16    250  True  0       tcp       0.934020  0.006151     5.579627
# 7   vgg13    200  True  1       mcd_mi    0.932410  0.003207     5.580850
# 41  vgg16    200  True  1       tcp_waic  0.935757  0.000975     5.629737
# 36  vgg16    200  True  1       mcd_pe    0.936620  0.000930     5.631720
# 28  vgg16    200  True  0       det_mcp   0.936327  0.000133     5.667563
# 45  vgg16    250  True  1       det_mcp   0.938000  0.001323     5.689660
# 18  vgg13    250  True  1       det_pe    0.935300  0.001011     5.696847
# 43  vgg16    250  True  0       det_pe    0.932717  0.004100     5.697920
# 33  vgg16    200  True  1       mcd_ee    0.935343  0.001004     5.710817
# 0   vgg13    200  True  0       det_mcp   0.933900  0.004704     5.740200
# 25  vgg13    250  True  1       tcp       0.934680  0.001419     5.743950
# 11  vgg13    200  True  1       tcp       0.933757  0.002134     5.754440
# 4   vgg13    200  True  1       det_pe    0.933333  0.002211     5.756047
# 37  vgg16    200  True  1       mcd_sv    0.934073  0.001141     5.764690
# 32  vgg16    200  True  1       det_pe    0.936980  0.001782     5.855330
# 17  vgg13    250  True  1       det_mcp   0.934717  0.001643     5.865993
# 35  vgg16    200  True  1       mcd_mi    0.932270  0.000946     5.868337
# 39  vgg16    200  True  1       tcp       0.936203  0.000531     5.963453
# 3   vgg13    200  True  1       det_mcp   0.932500  0.002169     5.977663
# 38  vgg16    200  True  1       mcd_waic  0.931943  0.004518     6.002530
# 31  vgg16    200  True  1       det_mcp   0.936523  0.001260     6.009587
# 10  vgg13    200  True  1       mcd_waic  0.925383  0.018973     6.055517
# 42  vgg16    250  True  0       det_mcp   0.932217  0.003817     6.109457
#
#     aurc_std  failap_suc  accuracy  accuracy_std
# 48  0.140008  0.996330    0.946000  0.000440
# 50  0.131938  0.996193    0.946000  0.000440
# 20  0.118252  0.996147    0.946553  0.001284
# 6   0.195290  0.996133    0.946223  0.000445
# 47  0.090508  0.996150    0.946000  0.000440
# 26  0.119033  0.996107    0.946553  0.001284
# 54  0.142841  0.996133    0.946000  0.000440
# 30  0.269244  0.996003    0.948260  0.001346
# 29  0.191356  0.995983    0.948260  0.001346
# 22  0.124029  0.996057    0.946553  0.001284
# 27  0.099583  0.996053    0.946553  0.001284
# 12  0.168475  0.996063    0.946223  0.000445
# 55  0.133795  0.996063    0.946000  0.000440
# 19  0.147389  0.996003    0.946553  0.001284
# 15  0.408556  0.995907    0.948110  0.001093
# 8   0.221733  0.995997    0.946223  0.000445
# 13  0.192644  0.995983    0.946223  0.000445
# 5   0.177559  0.995967    0.946223  0.000445
# 51  0.181813  0.995977    0.946000  0.000440
# 16  0.353773  0.995850    0.948110  0.001093
# 23  0.109868  0.995877    0.946553  0.001284
# 49  0.222261  0.995897    0.946000  0.000440
# 21  0.134691  0.995867    0.946553  0.001284
# 1   0.395559  0.995753    0.948297  0.002861
# 34  0.227369  0.995977    0.943703  0.001381
# 46  0.092057  0.995907    0.944777  0.001613
# 24  0.390689  0.995783    0.946553  0.001284
# 52  0.231523  0.995797    0.946000  0.000440
# 2   0.408530  0.995653    0.948297  0.002861
# 9   0.278425  0.995767    0.946223  0.000445
# 14  0.489590  0.995623    0.948110  0.001093
# 53  0.207345  0.995793    0.944777  0.001613
# 40  0.062143  0.995857    0.943703  0.001381
# 44  0.616343  0.995567    0.948740  0.001373
# 7   0.284306  0.995713    0.946223  0.000445
# 41  0.105179  0.995803    0.943703  0.001381
# 36  0.261028  0.995797    0.943703  0.001381
# 28  0.217838  0.995503    0.948260  0.001346
# 45  0.028751  0.995670    0.944777  0.001613
# 18  0.231533  0.995713    0.943963  0.001835
# 43  0.546125  0.995443    0.948740  0.001373
# 33  0.270079  0.995720    0.943703  0.001381
# 0   0.391114  0.995430    0.948297  0.002861
# 25  0.245887  0.995667    0.943963  0.001835
# 11  0.148992  0.995610    0.944703  0.001580
# 4   0.095387  0.995610    0.944703  0.001580
# 37  0.243700  0.995660    0.943703  0.001381
# 32  0.175437  0.995640    0.942333  0.001567
# 17  0.252885  0.995537    0.943963  0.001835
# 35  0.247702  0.995553    0.943703  0.001381
# 39  0.208286  0.995523    0.942333  0.001567
# 3   0.131874  0.995377    0.944703  0.001580
# 38  0.088860  0.995407    0.943703  0.001381
# 31  0.239219  0.995480    0.942333  0.001567
# 10  1.220113  0.995210    0.946223  0.000445
# 42  0.315040  0.995017    0.948740  0.001373

# %%
df[(df.study == "iid_study") & (df.dropout == "1")]

# %%
import numpy as np
np.std([0.95000, 0.94633, 1])
np.std([95.000, 94.633], ddof=1)
