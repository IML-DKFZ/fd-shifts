# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/goback_devries_sweep.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0                                                     2
# name                              devries_model_bbvgg16_do0_run0
# study          new_class_study_tinyimagenet_resize_proposed_mode
# model                                              devries_model
# network                                                    vgg16
# fold                                                           0
# confid                                                   devries
# n_test                                                     17446
# accuracy                                                 0.48412
# nll                                                          NaN
# brier_score                                                  NaN
# failauc                                                  0.93347
# failap_suc                                               0.93865
# failap_err                                                0.9243
# mce                                                      0.48067
# ece                                                      0.13393
# e-aurc                                                   33.9986
# aurc                                                     198.685
# fpr@95tpr                                                0.40056
# Name: 149, dtype: object

# %%
len(df)
# Out:
# 150

# %%
df.groupby("study").count()
# Out:
#                                                    Unnamed: 0  name  model  \
# study
# iid_study                                                  30    30     30
# new_class_study_tinyimagenet_original_mode                 30    30     30
# new_class_study_tinyimagenet_proposed_mode                 30    30     30
# new_class_study_tinyimagenet_resize_original_mode          30    30     30
# new_class_study_tinyimagenet_resize_proposed_mode          30    30     30
#
#                                                    network  fold  confid  \
# study
# iid_study                                               30    30      30
# new_class_study_tinyimagenet_original_mode              30    30      30
# new_class_study_tinyimagenet_proposed_mode              30    30      30
# new_class_study_tinyimagenet_resize_original_mode       30    30      30
# new_class_study_tinyimagenet_resize_proposed_mode       30    30      30
#
#                                                    n_test  accuracy  nll  \
# study
# iid_study                                              30        30   30
# new_class_study_tinyimagenet_original_mode             30        30    0
# new_class_study_tinyimagenet_proposed_mode             30        30    0
# new_class_study_tinyimagenet_resize_original_mode      30        30    0
# new_class_study_tinyimagenet_resize_proposed_mode      30        30    0
#
#                                                    brier_score  failauc  \
# study
# iid_study                                                   30       30
# new_class_study_tinyimagenet_original_mode                   0       30
# new_class_study_tinyimagenet_proposed_mode                   0       30
# new_class_study_tinyimagenet_resize_original_mode            0       30
# new_class_study_tinyimagenet_resize_proposed_mode            0       30
#
#                                                    failap_suc  failap_err  \
# study
# iid_study                                                  30          30
# new_class_study_tinyimagenet_original_mode                 30          30
# new_class_study_tinyimagenet_proposed_mode                 30          30
# new_class_study_tinyimagenet_resize_original_mode          30          30
# new_class_study_tinyimagenet_resize_proposed_mode          30          30
#
#                                                    mce  ece  e-aurc  aurc  \
# study
# iid_study                                           30   30      30    30
# new_class_study_tinyimagenet_original_mode          30   30      30    30
# new_class_study_tinyimagenet_proposed_mode          30   30      30    30
# new_class_study_tinyimagenet_resize_original_mode   30   30      30    30
# new_class_study_tinyimagenet_resize_proposed_mode   30   30      30    30
#
#                                                    fpr@95tpr
# study
# iid_study                                                 30
# new_class_study_tinyimagenet_original_mode                30
# new_class_study_tinyimagenet_proposed_mode                30
# new_class_study_tinyimagenet_resize_original_mode         30
# new_class_study_tinyimagenet_resize_proposed_mode         30

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"], keep="last")

# %%
len(df_clean)
# Out:
# 150

# %%
df_clean.groupby("name").count()
# Out:
#                                 Unnamed: 0  study  model  network  fold  \
# name
# devries_model_bbvgg13_do0_run0          15     15     15       15    15
# devries_model_bbvgg13_do0_run1          15     15     15       15    15
# devries_model_bbvgg13_do0_run2          15     15     15       15    15
# devries_model_bbvgg13_do0_run3          15     15     15       15    15
# devries_model_bbvgg13_do0_run4          15     15     15       15    15
# devries_model_bbvgg16_do0_run0          15     15     15       15    15
# devries_model_bbvgg16_do0_run1          15     15     15       15    15
# devries_model_bbvgg16_do0_run2          15     15     15       15    15
# devries_model_bbvgg16_do0_run3          15     15     15       15    15
# devries_model_bbvgg16_do0_run4          15     15     15       15    15
#
#                                 confid  n_test  accuracy  nll  brier_score  \
# name
# devries_model_bbvgg13_do0_run0      15      15        15    3            3
# devries_model_bbvgg13_do0_run1      15      15        15    3            3
# devries_model_bbvgg13_do0_run2      15      15        15    3            3
# devries_model_bbvgg13_do0_run3      15      15        15    3            3
# devries_model_bbvgg13_do0_run4      15      15        15    3            3
# devries_model_bbvgg16_do0_run0      15      15        15    3            3
# devries_model_bbvgg16_do0_run1      15      15        15    3            3
# devries_model_bbvgg16_do0_run2      15      15        15    3            3
# devries_model_bbvgg16_do0_run3      15      15        15    3            3
# devries_model_bbvgg16_do0_run4      15      15        15    3            3
#
#                                 failauc  failap_suc  failap_err  mce  ece  \
# name
# devries_model_bbvgg13_do0_run0       15          15          15   15   15
# devries_model_bbvgg13_do0_run1       15          15          15   15   15
# devries_model_bbvgg13_do0_run2       15          15          15   15   15
# devries_model_bbvgg13_do0_run3       15          15          15   15   15
# devries_model_bbvgg13_do0_run4       15          15          15   15   15
# devries_model_bbvgg16_do0_run0       15          15          15   15   15
# devries_model_bbvgg16_do0_run1       15          15          15   15   15
# devries_model_bbvgg16_do0_run2       15          15          15   15   15
# devries_model_bbvgg16_do0_run3       15          15          15   15   15
# devries_model_bbvgg16_do0_run4       15          15          15   15   15
#
#                                 e-aurc  aurc  fpr@95tpr
# name
# devries_model_bbvgg13_do0_run0      15    15         15
# devries_model_bbvgg13_do0_run1      15    15         15
# devries_model_bbvgg13_do0_run2      15    15         15
# devries_model_bbvgg13_do0_run3      15    15         15
# devries_model_bbvgg13_do0_run4      15    15         15
# devries_model_bbvgg16_do0_run0      15    15         15
# devries_model_bbvgg16_do0_run1      15    15         15
# devries_model_bbvgg16_do0_run2      15    15         15
# devries_model_bbvgg16_do0_run3      15    15         15
# devries_model_bbvgg16_do0_run4      15    15         15

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-11-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                name   confid  accuracy  failauc  failap_err  \
# 44   devries_model_bbvgg13_do0_run2  devries  0.93933   0.93385  0.41266
# 62   devries_model_bbvgg13_do0_run1  devries  0.94033   0.93085  0.41731
# 107  devries_model_bbvgg16_do0_run4  devries  0.93867   0.93465  0.47919
# 116  devries_model_bbvgg16_do0_run3  devries  0.93922   0.93515  0.48868
# 77   devries_model_bbvgg16_do0_run1  devries  0.94078   0.93060  0.43015
# 23   devries_model_bbvgg13_do0_run3  devries  0.93933   0.93247  0.43934
# 86   devries_model_bbvgg16_do0_run2  devries  0.93989   0.93001  0.43175
# 2    devries_model_bbvgg13_do0_run4  devries  0.93656   0.93520  0.44603
# 115  devries_model_bbvgg16_do0_run3  det_pe   0.93922   0.93286  0.50549
# 106  devries_model_bbvgg16_do0_run4  det_pe   0.93867   0.93073  0.49133
# 137  devries_model_bbvgg16_do0_run0  devries  0.93844   0.92820  0.41774
# 17   devries_model_bbvgg13_do0_run0  devries  0.93956   0.92913  0.42073
# 114  devries_model_bbvgg16_do0_run3  det_mcp  0.93922   0.93243  0.48503
# 85   devries_model_bbvgg16_do0_run2  det_pe   0.93989   0.92682  0.45599
# 76   devries_model_bbvgg16_do0_run1  det_pe   0.94078   0.92679  0.45947
# 136  devries_model_bbvgg16_do0_run0  det_pe   0.93844   0.92558  0.42521
# 105  devries_model_bbvgg16_do0_run4  det_mcp  0.93867   0.93012  0.47565
# 43   devries_model_bbvgg13_do0_run2  det_pe   0.93933   0.92588  0.44831
# 135  devries_model_bbvgg16_do0_run0  det_mcp  0.93844   0.92600  0.42476
# 84   devries_model_bbvgg16_do0_run2  det_mcp  0.93989   0.92639  0.45739
# 42   devries_model_bbvgg13_do0_run2  det_mcp  0.93933   0.92683  0.45076
# 61   devries_model_bbvgg13_do0_run1  det_pe   0.94033   0.92165  0.45857
# 75   devries_model_bbvgg16_do0_run1  det_mcp  0.94078   0.92594  0.45241
# 22   devries_model_bbvgg13_do0_run3  det_pe   0.93933   0.92238  0.48765
# 60   devries_model_bbvgg13_do0_run1  det_mcp  0.94033   0.92322  0.46710
# 21   devries_model_bbvgg13_do0_run3  det_mcp  0.93933   0.92270  0.48509
# 1    devries_model_bbvgg13_do0_run4  det_pe   0.93656   0.92411  0.50186
# 16   devries_model_bbvgg13_do0_run0  det_pe   0.93956   0.91684  0.46499
# 0    devries_model_bbvgg13_do0_run4  det_mcp  0.93656   0.92470  0.49514
# 15   devries_model_bbvgg13_do0_run0  det_mcp  0.93956   0.91685  0.45741
#
#         aurc
# 44   6.34703
# 62   6.51057
# 107  6.54163
# 116  6.60517
# 77   6.60997
# 23   6.73528
# 86   6.73624
# 2    6.76235
# 115  6.84537
# 106  6.88233
# 137  6.96421
# 17   6.99772
# 114  7.07635
# 85   7.12874
# 76   7.20182
# 136  7.25432
# 105  7.28459
# 43   7.44887
# 135  7.45110
# 84   7.49942
# 42   7.63649
# 61   7.68911
# 75   7.74793
# 22   7.83995
# 60   7.87152
# 21   8.20882
# 1    8.52093
# 16   8.69049
# 0    8.77682
# 15   8.95360

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["run"] = df.apply(lambda row: row["name"].split("run")[1], axis=1)

# %%
data =  df[(df.study == "iid_study") ]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
dims = ["confid", "backbone", "run"]
metrics = ["accuracy", "failauc", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()

# %%
sns.stripplot(x="pure_det", y="accuracy", data=df[(df.study == "iid_study") & (df.confid== "det_mcp")])
sns.boxplot(x="pure_det", y="accuracy", data=df[(df.study == "iid_study") & (df.confid== "det_mcp")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")  & (df.confid=="devries")].name
