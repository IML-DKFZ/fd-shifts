# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/ultimate_cifar_sweep.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0     2
# name           confidnet_model_bbvgg16_do0_cutoutTrue
# study          new_class_study_tinyimagenet_resize_proposed_mode
# model          confidnet_model
# network        vgg16
# fold           0
# confid         tcp
# n_test         17524
# accuracy       0.48642
# nll            NaN
# brier_score    NaN
# failauc        0.96024
# failap_suc     0.96582
# failap_err     0.9544
# mce            0.74963
# ece            0.32675
# e-aurc         19.0066
# aurc           182.033
# fpr@95tpr      0.26244
# Name: 504, dtype: object

# %%
len(df)
# Out:
# 505

# %%
df.groupby("study").count()
# Out:
#                                                    Unnamed: 0  name  model  \
# study
# iid_study                                          101         101   101
# new_class_study_tinyimagenet_original_mode         101         101   101
# new_class_study_tinyimagenet_proposed_mode         101         101   101
# new_class_study_tinyimagenet_resize_original_mode  101         101   101
# new_class_study_tinyimagenet_resize_proposed_mode  101         101   101
#
#                                                    network  fold  confid  \
# study
# iid_study                                          101      101   101
# new_class_study_tinyimagenet_original_mode         101      101   101
# new_class_study_tinyimagenet_proposed_mode         101      101   101
# new_class_study_tinyimagenet_resize_original_mode  101      101   101
# new_class_study_tinyimagenet_resize_proposed_mode  101      101   101
#
#                                                    n_test  accuracy  nll  \
# study
# iid_study                                          101     101       101
# new_class_study_tinyimagenet_original_mode         101     101       0
# new_class_study_tinyimagenet_proposed_mode         101     101       0
# new_class_study_tinyimagenet_resize_original_mode  101     101       0
# new_class_study_tinyimagenet_resize_proposed_mode  101     101       0
#
#                                                    brier_score  failauc  \
# study
# iid_study                                          101          101
# new_class_study_tinyimagenet_original_mode         0            101
# new_class_study_tinyimagenet_proposed_mode         0            101
# new_class_study_tinyimagenet_resize_original_mode  0            101
# new_class_study_tinyimagenet_resize_proposed_mode  0            101
#
#                                                    failap_suc  failap_err  \
# study
# iid_study                                          101         101
# new_class_study_tinyimagenet_original_mode         101         101
# new_class_study_tinyimagenet_proposed_mode         101         101
# new_class_study_tinyimagenet_resize_original_mode  101         101
# new_class_study_tinyimagenet_resize_proposed_mode  101         101
#
#                                                    mce  ece  e-aurc  aurc  \
# study
# iid_study                                          101  101  101     101
# new_class_study_tinyimagenet_original_mode         101  101  101     101
# new_class_study_tinyimagenet_proposed_mode         101  101  101     101
# new_class_study_tinyimagenet_resize_original_mode  101  101  101     101
# new_class_study_tinyimagenet_resize_proposed_mode  101  101  101     101
#
#                                                    fpr@95tpr
# study
# iid_study                                          101
# new_class_study_tinyimagenet_original_mode         101
# new_class_study_tinyimagenet_proposed_mode         101
# new_class_study_tinyimagenet_resize_original_mode  101
# new_class_study_tinyimagenet_resize_proposed_mode  101

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"], keep="last")

# %%
len(df_clean)
# Out:
# 505

# %%
df_clean.groupby("name").count()
# Out:
#                                          Unnamed: 0  study  model  network  \
# name
# confidnet_model_bbvgg13_do0_cutoutFalse  15          15     15     15
# confidnet_model_bbvgg13_do0_cutoutTrue   15          15     15     15
# confidnet_model_bbvgg13_do1_cutoutFalse  55          55     55     55
# confidnet_model_bbvgg13_do1_cutoutTrue   55          55     55     55
# confidnet_model_bbvgg16_do0_cutoutFalse  15          15     15     15
# confidnet_model_bbvgg16_do0_cutoutTrue   15          15     15     15
# confidnet_model_bbvgg16_do1_cutoutFalse  55          55     55     55
# devries_model_bbvgg13_do0_cutoutFalse    15          15     15     15
# devries_model_bbvgg13_do0_cutoutTrue     15          15     15     15
# devries_model_bbvgg13_do1_cutoutFalse    55          55     55     55
# devries_model_bbvgg13_do1_cutoutTrue     55          55     55     55
# devries_model_bbvgg16_do0_cutoutFalse    15          15     15     15
# devries_model_bbvgg16_do0_cutoutTrue     15          15     15     15
# devries_model_bbvgg16_do1_cutoutFalse    55          55     55     55
# devries_model_bbvgg16_do1_cutoutTrue     55          55     55     55
#
#                                          fold  confid  n_test  accuracy  nll  \
# name
# confidnet_model_bbvgg13_do0_cutoutFalse  15    15      15      15        3
# confidnet_model_bbvgg13_do0_cutoutTrue   15    15      15      15        3
# confidnet_model_bbvgg13_do1_cutoutFalse  55    55      55      55        11
# confidnet_model_bbvgg13_do1_cutoutTrue   55    55      55      55        11
# confidnet_model_bbvgg16_do0_cutoutFalse  15    15      15      15        3
# confidnet_model_bbvgg16_do0_cutoutTrue   15    15      15      15        3
# confidnet_model_bbvgg16_do1_cutoutFalse  55    55      55      55        11
# devries_model_bbvgg13_do0_cutoutFalse    15    15      15      15        3
# devries_model_bbvgg13_do0_cutoutTrue     15    15      15      15        3
# devries_model_bbvgg13_do1_cutoutFalse    55    55      55      55        11
# devries_model_bbvgg13_do1_cutoutTrue     55    55      55      55        11
# devries_model_bbvgg16_do0_cutoutFalse    15    15      15      15        3
# devries_model_bbvgg16_do0_cutoutTrue     15    15      15      15        3
# devries_model_bbvgg16_do1_cutoutFalse    55    55      55      55        11
# devries_model_bbvgg16_do1_cutoutTrue     55    55      55      55        11
#
#                                          brier_score  failauc  failap_suc  \
# name
# confidnet_model_bbvgg13_do0_cutoutFalse  3            15       15
# confidnet_model_bbvgg13_do0_cutoutTrue   3            15       15
# confidnet_model_bbvgg13_do1_cutoutFalse  11           55       55
# confidnet_model_bbvgg13_do1_cutoutTrue   11           55       55
# confidnet_model_bbvgg16_do0_cutoutFalse  3            15       15
# confidnet_model_bbvgg16_do0_cutoutTrue   3            15       15
# confidnet_model_bbvgg16_do1_cutoutFalse  11           55       55
# devries_model_bbvgg13_do0_cutoutFalse    3            15       15
# devries_model_bbvgg13_do0_cutoutTrue     3            15       15
# devries_model_bbvgg13_do1_cutoutFalse    11           55       55
# devries_model_bbvgg13_do1_cutoutTrue     11           55       55
# devries_model_bbvgg16_do0_cutoutFalse    3            15       15
# devries_model_bbvgg16_do0_cutoutTrue     3            15       15
# devries_model_bbvgg16_do1_cutoutFalse    11           55       55
# devries_model_bbvgg16_do1_cutoutTrue     11           55       55
#
#                                          failap_err  mce  ece  e-aurc  aurc  \
# name
# confidnet_model_bbvgg13_do0_cutoutFalse  15          15   15   15      15
# confidnet_model_bbvgg13_do0_cutoutTrue   15          15   15   15      15
# confidnet_model_bbvgg13_do1_cutoutFalse  55          55   55   55      55
# confidnet_model_bbvgg13_do1_cutoutTrue   55          55   55   55      55
# confidnet_model_bbvgg16_do0_cutoutFalse  15          15   15   15      15
# confidnet_model_bbvgg16_do0_cutoutTrue   15          15   15   15      15
# confidnet_model_bbvgg16_do1_cutoutFalse  55          55   55   55      55
# devries_model_bbvgg13_do0_cutoutFalse    15          15   15   15      15
# devries_model_bbvgg13_do0_cutoutTrue     15          15   15   15      15
# devries_model_bbvgg13_do1_cutoutFalse    55          55   55   55      55
# devries_model_bbvgg13_do1_cutoutTrue     55          55   55   55      55
# devries_model_bbvgg16_do0_cutoutFalse    15          15   15   15      15
# devries_model_bbvgg16_do0_cutoutTrue     15          15   15   15      15
# devries_model_bbvgg16_do1_cutoutFalse    55          55   55   55      55
# devries_model_bbvgg16_do1_cutoutTrue     55          55   55   55      55
#
#                                          fpr@95tpr
# name
# confidnet_model_bbvgg13_do0_cutoutFalse  15
# confidnet_model_bbvgg13_do0_cutoutTrue   15
# confidnet_model_bbvgg13_do1_cutoutFalse  55
# confidnet_model_bbvgg13_do1_cutoutTrue   55
# confidnet_model_bbvgg16_do0_cutoutFalse  15
# confidnet_model_bbvgg16_do0_cutoutTrue   15
# confidnet_model_bbvgg16_do1_cutoutFalse  55
# devries_model_bbvgg13_do0_cutoutFalse    15
# devries_model_bbvgg13_do0_cutoutTrue     15
# devries_model_bbvgg13_do1_cutoutFalse    55
# devries_model_bbvgg13_do1_cutoutTrue     55
# devries_model_bbvgg16_do0_cutoutFalse    15
# devries_model_bbvgg16_do0_cutoutTrue     15
# devries_model_bbvgg16_do1_cutoutFalse    55
# devries_model_bbvgg16_do1_cutoutTrue     55

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-80-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                         name        confid  accuracy  failauc  \
# 267  devries_model_bbvgg16_do0_cutoutTrue     devries       0.94656   0.93751
# 491  confidnet_model_bbvgg16_do0_cutoutTrue   det_pe        0.94711   0.93597
# 492  confidnet_model_bbvgg16_do0_cutoutTrue   tcp           0.94711   0.93550
# 2    devries_model_bbvgg13_do0_cutoutTrue     devries       0.94444   0.93707
# 490  confidnet_model_bbvgg16_do0_cutoutTrue   det_mcp       0.94711   0.93507
# 351  confidnet_model_bbvgg13_do0_cutoutTrue   det_pe        0.94656   0.93080
# 266  devries_model_bbvgg16_do0_cutoutTrue     det_pe        0.94656   0.93171
# 11   devries_model_bbvgg13_do0_cutoutFalse    devries       0.94167   0.93369
# 352  confidnet_model_bbvgg13_do0_cutoutTrue   tcp           0.94656   0.92941
# 350  confidnet_model_bbvgg13_do0_cutoutTrue   det_mcp       0.94656   0.92999
# 1    devries_model_bbvgg13_do0_cutoutTrue     det_pe        0.94444   0.93249
# 265  devries_model_bbvgg16_do0_cutoutTrue     det_mcp       0.94656   0.93225
# 0    devries_model_bbvgg13_do0_cutoutTrue     det_mcp       0.94444   0.93233
# 252  devries_model_bbvgg16_do0_cutoutFalse    devries       0.93878   0.92818
# 440  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_mcp       0.93267   0.93239
# 445  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_waic      0.93267   0.92944
# 438  confidnet_model_bbvgg13_do1_cutoutTrue   tcp_mcd       0.93267   0.92805
# 439  confidnet_model_bbvgg13_do1_cutoutTrue   tcp_waic      0.93267   0.92554
# 442  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_ee        0.93267   0.92528
# 441  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_pe        0.93267   0.92518
# 385  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_mcp       0.93167   0.92615
# 10   devries_model_bbvgg13_do0_cutoutFalse    det_pe        0.94167   0.91654
# 300  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_mcp       0.93022   0.92783
# 305  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_waic      0.93022   0.92704
# 383  confidnet_model_bbvgg13_do1_cutoutFalse  tcp_mcd       0.93167   0.92325
# 68   devries_model_bbvgg13_do1_cutoutTrue     mcd_mcp       0.92878   0.92895
# 73   devries_model_bbvgg13_do1_cutoutTrue     mcd_waic      0.92878   0.92783
# 444  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_sv        0.93267   0.92104
# 367  confidnet_model_bbvgg13_do0_cutoutFalse  tcp           0.93889   0.91742
# 366  confidnet_model_bbvgg13_do0_cutoutFalse  det_pe        0.93889   0.91814
# 384  confidnet_model_bbvgg13_do1_cutoutFalse  tcp_waic      0.93167   0.92033
# 35   devries_model_bbvgg16_do1_cutoutFalse    mcd_mcp       0.92911   0.92821
# 386  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_pe        0.93167   0.91975
# 387  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_ee        0.93167   0.91947
# 301  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_pe        0.93022   0.92178
# 298  confidnet_model_bbvgg16_do1_cutoutFalse  tcp_mcd       0.93022   0.92299
# 200  devries_model_bbvgg13_do1_cutoutFalse    mcd_mcp       0.93033   0.92074
# 299  confidnet_model_bbvgg16_do1_cutoutFalse  tcp_waic      0.93022   0.92118
# 145  devries_model_bbvgg16_do1_cutoutTrue     mcd_mcp       0.92600   0.92928
# 443  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_mi        0.93267   0.91579
# 302  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_ee        0.93022   0.92016
# 389  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_sv        0.93167   0.91652
# 304  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_sv        0.93022   0.91892
# 205  devries_model_bbvgg13_do1_cutoutFalse    mcd_waic      0.93033   0.91846
# 69   devries_model_bbvgg13_do1_cutoutTrue     mcd_pe        0.92878   0.92163
# 9    devries_model_bbvgg13_do0_cutoutFalse    det_mcp       0.94167   0.91569
# 390  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_waic      0.93167   0.91723
# 150  devries_model_bbvgg16_do1_cutoutTrue     mcd_waic      0.92600   0.92736
# 36   devries_model_bbvgg16_do1_cutoutFalse    mcd_pe        0.92911   0.92271
# 37   devries_model_bbvgg16_do1_cutoutFalse    mcd_ee        0.92911   0.92227
# 70   devries_model_bbvgg13_do1_cutoutTrue     mcd_ee        0.92878   0.91945
# 33   devries_model_bbvgg16_do1_cutoutFalse    devries_mcd   0.92911   0.92146
# 72   devries_model_bbvgg13_do1_cutoutTrue     mcd_sv        0.92878   0.91818
# 388  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_mi        0.93167   0.91205
# 201  devries_model_bbvgg13_do1_cutoutFalse    mcd_pe        0.93033   0.91419
# 365  confidnet_model_bbvgg13_do0_cutoutFalse  det_mcp       0.93889   0.91665
# 303  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_mi        0.93022   0.91366
# 202  devries_model_bbvgg13_do1_cutoutFalse    mcd_ee        0.93033   0.91307
# 40   devries_model_bbvgg16_do1_cutoutFalse    mcd_waic      0.92911   0.91857
# 34   devries_model_bbvgg16_do1_cutoutFalse    devries_waic  0.92911   0.91669
# 146  devries_model_bbvgg16_do1_cutoutTrue     mcd_pe        0.92600   0.92092
# 71   devries_model_bbvgg13_do1_cutoutTrue     mcd_mi        0.92878   0.91443
# 39   devries_model_bbvgg16_do1_cutoutFalse    mcd_sv        0.92911   0.91601
# 147  devries_model_bbvgg16_do1_cutoutTrue     mcd_ee        0.92600   0.92048
# 204  devries_model_bbvgg13_do1_cutoutFalse    mcd_sv        0.93033   0.91082
# 149  devries_model_bbvgg16_do1_cutoutTrue     mcd_sv        0.92600   0.91796
# 143  devries_model_bbvgg16_do1_cutoutTrue     devries_mcd   0.92600   0.91826
# 66   devries_model_bbvgg13_do1_cutoutTrue     devries_mcd   0.92878   0.91235
# 38   devries_model_bbvgg16_do1_cutoutFalse    mcd_mi        0.92911   0.91187
# 198  devries_model_bbvgg13_do1_cutoutFalse    devries_mcd   0.93033   0.90721
# 203  devries_model_bbvgg13_do1_cutoutFalse    mcd_mi        0.93033   0.90701
# 251  devries_model_bbvgg16_do0_cutoutFalse    det_pe        0.93878   0.90807
# 144  devries_model_bbvgg16_do1_cutoutTrue     devries_waic  0.92600   0.91294
# 148  devries_model_bbvgg16_do1_cutoutTrue     mcd_mi        0.92600   0.91229
# 67   devries_model_bbvgg13_do1_cutoutTrue     devries_waic  0.92878   0.90577
# 199  devries_model_bbvgg13_do1_cutoutFalse    devries_waic  0.93033   0.90043
# 250  devries_model_bbvgg16_do0_cutoutFalse    det_mcp       0.93878   0.90807
# 282  confidnet_model_bbvgg16_do0_cutoutFalse  tcp           0.93833   0.90292
# 281  confidnet_model_bbvgg16_do0_cutoutFalse  det_pe        0.93833   0.89506
# 435  confidnet_model_bbvgg13_do1_cutoutTrue   det_mcp       0.91144   0.91618
# 437  confidnet_model_bbvgg13_do1_cutoutTrue   tcp           0.91144   0.91578
# 280  confidnet_model_bbvgg16_do0_cutoutFalse  det_mcp       0.93833   0.89460
# 436  confidnet_model_bbvgg13_do1_cutoutTrue   det_pe        0.91144   0.90483
# 63   devries_model_bbvgg13_do1_cutoutTrue     det_mcp       0.90600   0.91395
# 65   devries_model_bbvgg13_do1_cutoutTrue     devries       0.90600   0.90685
# 64   devries_model_bbvgg13_do1_cutoutTrue     det_pe        0.90600   0.90550
# 140  devries_model_bbvgg16_do1_cutoutTrue     det_mcp       0.90311   0.90745
# 142  devries_model_bbvgg16_do1_cutoutTrue     devries       0.90311   0.90408
# 141  devries_model_bbvgg16_do1_cutoutTrue     det_pe        0.90311   0.90000
# 30   devries_model_bbvgg16_do1_cutoutFalse    det_mcp       0.89289   0.91295
# 32   devries_model_bbvgg16_do1_cutoutFalse    devries       0.89289   0.90997
# 31   devries_model_bbvgg16_do1_cutoutFalse    det_pe        0.89289   0.90904
# 297  confidnet_model_bbvgg16_do1_cutoutFalse  tcp           0.89033   0.91078
# 295  confidnet_model_bbvgg16_do1_cutoutFalse  det_mcp       0.89033   0.90812
# 296  confidnet_model_bbvgg16_do1_cutoutFalse  det_pe        0.89033   0.90359
# 382  confidnet_model_bbvgg13_do1_cutoutFalse  tcp           0.88956   0.90336
# 380  confidnet_model_bbvgg13_do1_cutoutFalse  det_mcp       0.88956   0.90296
# 381  confidnet_model_bbvgg13_do1_cutoutFalse  det_pe        0.88956   0.90077
# 195  devries_model_bbvgg13_do1_cutoutFalse    det_mcp       0.87833   0.91158
# 196  devries_model_bbvgg13_do1_cutoutFalse    det_pe        0.87833   0.90747
# 197  devries_model_bbvgg13_do1_cutoutFalse    devries       0.87833   0.90062
#
#      failap_err      aurc
# 267  0.46548     5.37522
# 491  0.44100     5.39919
# 492  0.44483     5.45423
# 2    0.42866     5.51878
# 490  0.43627     5.67734
# 351  0.44452     5.99669
# 266  0.48297     6.08961
# 11   0.42223     6.13917
# 352  0.44067     6.21290
# 350  0.44324     6.36421
# 1    0.45929     6.44231
# 265  0.49451     6.51798
# 0    0.46307     6.72454
# 252  0.41488     7.02405
# 440  0.48133     7.48335
# 445  0.46931     7.64845
# 438  0.43064     7.72223
# 439  0.41117     7.91451
# 442  0.41865     7.96948
# 441  0.42232     7.98084
# 385  0.45328     8.03057
# 10   0.43359     8.14150
# 300  0.44484     8.15377
# 305  0.44395     8.19961
# 383  0.41531     8.20504
# 68   0.45898     8.25757
# 73   0.46290     8.30635
# 444  0.39587     8.32241
# 367  0.41949     8.37990
# 366  0.43307     8.40046
# 384  0.39715     8.41608
# 35   0.47472     8.46985
# 386  0.40856     8.48952
# 387  0.40859     8.50922
# 301  0.40959     8.59250
# 298  0.41385     8.60274
# 200  0.42722     8.66615
# 299  0.40119     8.70870
# 145  0.49698     8.71103
# 443  0.39111     8.71243
# 302  0.41270     8.73461
# 389  0.38827     8.75373
# 304  0.37803     8.76140
# 205  0.42021     8.77651
# 69   0.41031     8.79743
# 9    0.42708     8.83814
# 390  0.43406     8.84108
# 150  0.48859     8.86782
# 36   0.43363     8.87469
# 37   0.42470     8.90763
# 70   0.40674     8.98898
# 33   0.42513     8.99568
# 72   0.37970     9.07187
# 388  0.38247     9.08698
# 201  0.37997     9.13829
# 365  0.42585     9.16217
# 303  0.37667     9.17393
# 202  0.37041     9.21942
# 40   0.44162     9.31378
# 34   0.37946     9.32327
# 146  0.43727     9.35372
# 71   0.37737     9.36665
# 39   0.40198     9.37226
# 147  0.42802     9.39794
# 204  0.36597     9.41566
# 149  0.40831     9.50234
# 143  0.41664     9.55450
# 66   0.39220     9.59856
# 38   0.40227     9.68200
# 198  0.37615     9.68684
# 203  0.36443     9.71045
# 251  0.43773     9.91939
# 144  0.38419     9.95749
# 148  0.40477     9.97033
# 67   0.34357     10.11607
# 199  0.32372     10.20520
# 250  0.42776     10.62898
# 282  0.43335     10.77196
# 281  0.45684     12.01362
# 435  0.46366     12.46657
# 437  0.45867     12.47422
# 280  0.44290     12.61310
# 436  0.41594     13.55152
# 63   0.47328     13.61037
# 65   0.43898     14.29021
# 64   0.42745     14.45140
# 140  0.46121     15.04044
# 142  0.42864     15.32445
# 141  0.42069     15.81967
# 30   0.50826     16.46365
# 32   0.48916     16.72725
# 31   0.49349     16.89663
# 297  0.52296     17.52195
# 295  0.51838     17.67809
# 296  0.49827     18.20813
# 382  0.47621     18.24960
# 380  0.46964     18.43889
# 381  0.46543     18.65175
# 195  0.55686     19.80647
# 196  0.52905     20.29503
# 197  0.50199     21.24632

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["pure_det"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["cutout"] = df.apply(lambda row: True if "cutoutTrue" in row["name"] else False, axis=1)
df["dnorm"] = df.apply(lambda row: True if "dnormTrue" in row["name"] else False, axis=1)
df["sm"] = df.apply(lambda row: 250 if "sm250" in row["name"] else 200, axis=1)
df["250_sweep"] = df.apply(lambda row: True if "_sm" in row["name"] else False, axis=1)
# df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)

# %%
data =  df[(df.study == "iid_study")]
# data =  df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
print(data.name.tolist())
dims = ["confid", "backbone", "dropout", "sm", "dnorm", "model"]
metrics = ["accuracy", "failauc", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()
# Out:
# ['devries_model_bbvgg13_do0_cutoutTrue', 'devries_model_bbvgg13_do0_cutoutTrue', 'devries_model_bbvgg13_do0_cutoutTrue', 'devries_model_bbvgg13_do0_cutoutFalse', 'devries_model_bbvgg13_do0_cutoutFalse', 'devries_model_bbvgg13_do0_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg16_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg16_do1_cutoutTrue', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg13_do1_cutoutFalse', 'devries_model_bbvgg16_do0_cutoutFalse', 'devries_model_bbvgg16_do0_cutoutFalse', 'devries_model_bbvgg16_do0_cutoutFalse', 'devries_model_bbvgg16_do0_cutoutTrue', 'devries_model_bbvgg16_do0_cutoutTrue', 'devries_model_bbvgg16_do0_cutoutTrue', 'confidnet_model_bbvgg16_do0_cutoutFalse', 'confidnet_model_bbvgg16_do0_cutoutFalse', 'confidnet_model_bbvgg16_do0_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg16_do1_cutoutFalse', 'confidnet_model_bbvgg13_do0_cutoutTrue', 'confidnet_model_bbvgg13_do0_cutoutTrue', 'confidnet_model_bbvgg13_do0_cutoutTrue', 'confidnet_model_bbvgg13_do0_cutoutFalse', 'confidnet_model_bbvgg13_do0_cutoutFalse', 'confidnet_model_bbvgg13_do0_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutFalse', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg13_do1_cutoutTrue', 'confidnet_model_bbvgg1 ...

# %%
data[["name", "confid", "failauc"]].sort_values(by="failauc", ascending=False)
# Out:
#                                         name        confid  failauc
# 174  devries_model_bbvgg16_do1_cutoutTrue     det_pe        0.97111
# 175  devries_model_bbvgg16_do1_cutoutTrue     devries       0.96598
# 173  devries_model_bbvgg16_do1_cutoutTrue     det_mcp       0.96230
# 75   devries_model_bbvgg16_do1_cutoutFalse    det_pe        0.95965
# 14   devries_model_bbvgg13_do0_cutoutTrue     devries       0.95929
# 276  devries_model_bbvgg16_do0_cutoutTrue     devries       0.95056
# 500  confidnet_model_bbvgg16_do0_cutoutTrue   det_pe        0.94695
# 76   devries_model_bbvgg16_do1_cutoutFalse    devries       0.94385
# 469  confidnet_model_bbvgg13_do1_cutoutTrue   det_pe        0.94313
# 74   devries_model_bbvgg16_do1_cutoutFalse    det_mcp       0.94290
# 81   devries_model_bbvgg16_do1_cutoutFalse    mcd_ee        0.94286
# 501  confidnet_model_bbvgg16_do0_cutoutTrue   tcp           0.94181
# 180  devries_model_bbvgg16_do1_cutoutTrue     mcd_ee        0.94127
# 360  confidnet_model_bbvgg13_do0_cutoutTrue   det_pe        0.94081
# 80   devries_model_bbvgg16_do1_cutoutFalse    mcd_pe        0.94041
# 329  confidnet_model_bbvgg16_do1_cutoutFalse  det_pe        0.94021
# 499  confidnet_model_bbvgg16_do0_cutoutTrue   det_mcp       0.93991
# 361  confidnet_model_bbvgg13_do0_cutoutTrue   tcp           0.93981
# 414  confidnet_model_bbvgg13_do1_cutoutFalse  det_pe        0.93799
# 275  devries_model_bbvgg16_do0_cutoutTrue     det_pe        0.93798
# 176  devries_model_bbvgg16_do1_cutoutTrue     devries_mcd   0.93664
# 475  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_ee        0.93500
# 119  devries_model_bbvgg13_do1_cutoutTrue     det_pe        0.93474
# 77   devries_model_bbvgg16_do1_cutoutFalse    devries_mcd   0.93435
# 179  devries_model_bbvgg16_do1_cutoutTrue     mcd_pe        0.93354
# 125  devries_model_bbvgg13_do1_cutoutTrue     mcd_ee        0.93285
# 13   devries_model_bbvgg13_do0_cutoutTrue     det_pe        0.93271
# 359  confidnet_model_bbvgg13_do0_cutoutTrue   det_mcp       0.93255
# 274  devries_model_bbvgg16_do0_cutoutTrue     det_mcp       0.93062
# 26   devries_model_bbvgg13_do0_cutoutFalse    devries       0.93001
# 177  devries_model_bbvgg16_do1_cutoutTrue     devries_waic  0.92985
# 121  devries_model_bbvgg13_do1_cutoutTrue     devries_mcd   0.92931
# 468  confidnet_model_bbvgg13_do1_cutoutTrue   det_mcp       0.92676
# 415  confidnet_model_bbvgg13_do1_cutoutFalse  tcp           0.92590
# 12   devries_model_bbvgg13_do0_cutoutTrue     det_mcp       0.92570
# 474  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_pe        0.92551
# 420  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_ee        0.92535
# 124  devries_model_bbvgg13_do1_cutoutTrue     mcd_pe        0.92524
# 25   devries_model_bbvgg13_do0_cutoutFalse    det_pe        0.92475
# 470  confidnet_model_bbvgg13_do1_cutoutTrue   tcp           0.92430
# 335  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_ee        0.92259
# 472  confidnet_model_bbvgg13_do1_cutoutTrue   tcp_waic      0.92254
# 79   devries_model_bbvgg16_do1_cutoutFalse    mcd_mcp       0.92245
# 471  confidnet_model_bbvgg13_do1_cutoutTrue   tcp_mcd       0.92212
# 419  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_pe        0.92173
# 417  confidnet_model_bbvgg13_do1_cutoutFalse  tcp_waic      0.92093
# 413  confidnet_model_bbvgg13_do1_cutoutFalse  det_mcp       0.92005
# 334  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_pe        0.91971
# 82   devries_model_bbvgg16_do1_cutoutFalse    mcd_mi        0.91924
# 122  devries_model_bbvgg13_do1_cutoutTrue     devries_waic  0.91901
# 235  devries_model_bbvgg13_do1_cutoutFalse    mcd_ee        0.91893
# 118  devries_model_bbvgg13_do1_cutoutTrue     det_mcp       0.91878
# 24   devries_model_bbvgg13_do0_cutoutFalse    det_mcp       0.91834
# 416  confidnet_model_bbvgg13_do1_cutoutFalse  tcp_mcd       0.91775
# 229  devries_model_bbvgg13_do1_cutoutFalse    det_pe        0.91748
# 78   devries_model_bbvgg16_do1_cutoutFalse    devries_waic  0.91703
# 178  devries_model_bbvgg16_do1_cutoutTrue     mcd_mcp       0.91701
# 260  devries_model_bbvgg16_do0_cutoutFalse    det_pe        0.91448
# 261  devries_model_bbvgg16_do0_cutoutFalse    devries       0.91427
# 375  confidnet_model_bbvgg13_do0_cutoutFalse  det_pe        0.91355
# 234  devries_model_bbvgg13_do1_cutoutFalse    mcd_pe        0.91314
# 328  confidnet_model_bbvgg16_do1_cutoutFalse  det_mcp       0.91308
# 231  devries_model_bbvgg13_do1_cutoutFalse    devries_mcd   0.91293
# 183  devries_model_bbvgg16_do1_cutoutTrue     mcd_waic      0.91183
# 120  devries_model_bbvgg13_do1_cutoutTrue     devries       0.90917
# 473  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_mcp       0.90906
# 259  devries_model_bbvgg16_do0_cutoutFalse    det_mcp       0.90883
# 84   devries_model_bbvgg16_do1_cutoutFalse    mcd_waic      0.90832
# 330  confidnet_model_bbvgg16_do1_cutoutFalse  tcp           0.90823
# 123  devries_model_bbvgg13_do1_cutoutTrue     mcd_mcp       0.90739
# 374  confidnet_model_bbvgg13_do0_cutoutFalse  det_mcp       0.90702
# 332  confidnet_model_bbvgg16_do1_cutoutFalse  tcp_waic      0.90683
# 418  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_mcp       0.90659
# 421  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_mi        0.90600
# 291  confidnet_model_bbvgg16_do0_cutoutFalse  tcp           0.90518
# 376  confidnet_model_bbvgg13_do0_cutoutFalse  tcp           0.90507
# 290  confidnet_model_bbvgg16_do0_cutoutFalse  det_pe        0.90393
# 331  confidnet_model_bbvgg16_do1_cutoutFalse  tcp_mcd       0.90380
# 336  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_mi        0.90266
# 228  devries_model_bbvgg13_do1_cutoutFalse    det_mcp       0.90187
# 333  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_mcp       0.90140
# 128  devries_model_bbvgg13_do1_cutoutTrue     mcd_waic      0.89956
# 289  confidnet_model_bbvgg16_do0_cutoutFalse  det_mcp       0.89955
# 338  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_waic      0.89843
# 478  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_waic      0.89799
# 83   devries_model_bbvgg16_do1_cutoutFalse    mcd_sv        0.89630
# 233  devries_model_bbvgg13_do1_cutoutFalse    mcd_mcp       0.89609
# 232  devries_model_bbvgg13_do1_cutoutFalse    devries_waic  0.89388
# 181  devries_model_bbvgg16_do1_cutoutTrue     mcd_mi        0.89070
# 422  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_sv        0.88721
# 476  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_mi        0.88661
# 238  devries_model_bbvgg13_do1_cutoutFalse    mcd_waic      0.88653
# 236  devries_model_bbvgg13_do1_cutoutFalse    mcd_mi        0.88631
# 423  confidnet_model_bbvgg13_do1_cutoutFalse  mcd_waic      0.88456
# 337  confidnet_model_bbvgg16_do1_cutoutFalse  mcd_sv        0.88378
# 126  devries_model_bbvgg13_do1_cutoutTrue     mcd_mi        0.88338
# 182  devries_model_bbvgg16_do1_cutoutTrue     mcd_sv        0.86889
# 477  confidnet_model_bbvgg13_do1_cutoutTrue   mcd_sv        0.86873
# 237  devries_model_bbvgg13_do1_cutoutFalse    mcd_sv        0.86423
# 127  devries_model_bbvgg13_do1_cutoutTrue     mcd_sv        0.86237
# 230  devries_model_bbvgg13_do1_cutoutFalse    devries       0.82916

# %%
sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")  & (df.confid=="devries")].name
# Out:
# 14     devries_model_bbvgg13_do0_cutoutTrue
# 26     devries_model_bbvgg13_do0_cutoutFalse
# 76     devries_model_bbvgg16_do1_cutoutFalse
# 120    devries_model_bbvgg13_do1_cutoutTrue
# 175    devries_model_bbvgg16_do1_cutoutTrue
# 230    devries_model_bbvgg13_do1_cutoutFalse
# 261    devries_model_bbvgg16_do0_cutoutFalse
# 276    devries_model_bbvgg16_do0_cutoutTrue
# Name: name, dtype: object
