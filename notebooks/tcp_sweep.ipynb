# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/tcp_sweep.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0                                                    10
# name                               confidnet_model_bbvgg13_do0.4
# study          new_class_study_tinyimagenet_resize_proposed_mode
# model                                            confidnet_model
# network                                                    vgg13
# fold                                                           0
# confid                                                  mcd_waic
# n_test                                                     17311
# accuracy                                                  0.4801
# nll                                                          NaN
# brier_score                                                  NaN
# failauc                                                   0.9403
# failap_suc                                               0.94606
# failap_err                                               0.93307
# mce                                                      0.44734
# ece                                                      0.23564
# e-aurc                                                   29.7545
# aurc                                                     197.376
# fpr@95tpr                                                0.36511
# Name: 279, dtype: object

# %%
len(df)
# Out:
# 280

# %%
df.groupby("study").count()
# Out:
#                                                    Unnamed: 0  name  model  \
# study
# iid_study                                                  56    56     56
# new_class_study_tinyimagenet_original_mode                 56    56     56
# new_class_study_tinyimagenet_proposed_mode                 56    56     56
# new_class_study_tinyimagenet_resize_original_mode          56    56     56
# new_class_study_tinyimagenet_resize_proposed_mode          56    56     56
#
#                                                    network  fold  confid  \
# study
# iid_study                                               56    56      56
# new_class_study_tinyimagenet_original_mode              56    56      56
# new_class_study_tinyimagenet_proposed_mode              56    56      56
# new_class_study_tinyimagenet_resize_original_mode       56    56      56
# new_class_study_tinyimagenet_resize_proposed_mode       56    56      56
#
#                                                    n_test  accuracy  nll  \
# study
# iid_study                                              56        56   56
# new_class_study_tinyimagenet_original_mode             56        56    0
# new_class_study_tinyimagenet_proposed_mode             56        56    0
# new_class_study_tinyimagenet_resize_original_mode      56        56    0
# new_class_study_tinyimagenet_resize_proposed_mode      56        56    0
#
#                                                    brier_score  failauc  \
# study
# iid_study                                                   56       56
# new_class_study_tinyimagenet_original_mode                   0       56
# new_class_study_tinyimagenet_proposed_mode                   0       56
# new_class_study_tinyimagenet_resize_original_mode            0       56
# new_class_study_tinyimagenet_resize_proposed_mode            0       56
#
#                                                    failap_suc  failap_err  \
# study
# iid_study                                                  56          56
# new_class_study_tinyimagenet_original_mode                 56          56
# new_class_study_tinyimagenet_proposed_mode                 56          56
# new_class_study_tinyimagenet_resize_original_mode          56          56
# new_class_study_tinyimagenet_resize_proposed_mode          56          56
#
#                                                    mce  ece  e-aurc  aurc  \
# study
# iid_study                                           56   56      56    56
# new_class_study_tinyimagenet_original_mode          56   56      56    56
# new_class_study_tinyimagenet_proposed_mode          56   56      56    56
# new_class_study_tinyimagenet_resize_original_mode   56   56      56    56
# new_class_study_tinyimagenet_resize_proposed_mode   56   56      56    56
#
#                                                    fpr@95tpr
# study
# iid_study                                                 56
# new_class_study_tinyimagenet_original_mode                56
# new_class_study_tinyimagenet_proposed_mode                56
# new_class_study_tinyimagenet_resize_original_mode         56
# new_class_study_tinyimagenet_resize_proposed_mode         56

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"])

# %%
len(df_clean)
# Out:
# 280

# %%
df_clean.groupby("name").count()
# Out:
#                                Unnamed: 0  study  model  network  fold  \
# name
# confidnet_model_bbvgg13_do0            15     15     15       15    15
# confidnet_model_bbvgg13_do0.4          55     55     55       55    55
# confidnet_model_bbvgg16_do0            15     15     15       15    15
# confidnet_model_bbvgg16_do0.4          55     55     55       55    55
# devries_model_bbvgg13_do0              15     15     15       15    15
# devries_model_bbvgg13_do0.4            55     55     55       55    55
# devries_model_bbvgg16_do0              15     15     15       15    15
# devries_model_bbvgg16_do0.4            55     55     55       55    55
#
#                                confid  n_test  accuracy  nll  brier_score  \
# name
# confidnet_model_bbvgg13_do0        15      15        15    3            3
# confidnet_model_bbvgg13_do0.4      55      55        55   11           11
# confidnet_model_bbvgg16_do0        15      15        15    3            3
# confidnet_model_bbvgg16_do0.4      55      55        55   11           11
# devries_model_bbvgg13_do0          15      15        15    3            3
# devries_model_bbvgg13_do0.4        55      55        55   11           11
# devries_model_bbvgg16_do0          15      15        15    3            3
# devries_model_bbvgg16_do0.4        55      55        55   11           11
#
#                                failauc  failap_suc  failap_err  mce  ece  \
# name
# confidnet_model_bbvgg13_do0         15          15          15   15   15
# confidnet_model_bbvgg13_do0.4       55          55          55   55   55
# confidnet_model_bbvgg16_do0         15          15          15   15   15
# confidnet_model_bbvgg16_do0.4       55          55          55   55   55
# devries_model_bbvgg13_do0           15          15          15   15   15
# devries_model_bbvgg13_do0.4         55          55          55   55   55
# devries_model_bbvgg16_do0           15          15          15   15   15
# devries_model_bbvgg16_do0.4         55          55          55   55   55
#
#                                e-aurc  aurc  fpr@95tpr
# name
# confidnet_model_bbvgg13_do0        15    15         15
# confidnet_model_bbvgg13_do0.4      55    55         55
# confidnet_model_bbvgg16_do0        15    15         15
# confidnet_model_bbvgg16_do0.4      55    55         55
# devries_model_bbvgg13_do0          15    15         15
# devries_model_bbvgg13_do0.4        55    55         55
# devries_model_bbvgg16_do0          15    15         15
# devries_model_bbvgg16_do0.4        55    55         55

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-19-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                               name    confid  accuracy  failauc  failap_err  \
# 4    devries_model_bbvgg16_do0      det_pe    0.95267   0.93750  0.42517
# 3    devries_model_bbvgg16_do0      det_mcp   0.95267   0.93655  0.40441
# 2    confidnet_model_bbvgg13_do0    tcp       0.94411   0.94393  0.51606
# 10   devries_model_bbvgg13_do0      det_pe    0.95067   0.93314  0.40921
# 1    confidnet_model_bbvgg13_do0    det_pe    0.94411   0.94176  0.50140
# 28   confidnet_model_bbvgg16_do0    det_pe    0.94600   0.93349  0.45570
# 9    devries_model_bbvgg13_do0      det_mcp   0.95067   0.93193  0.41142
# 0    confidnet_model_bbvgg13_do0    det_mcp   0.94411   0.94149  0.50749
# 29   confidnet_model_bbvgg16_do0    tcp       0.94600   0.93035  0.46285
# 27   confidnet_model_bbvgg16_do0    det_mcp   0.94600   0.93085  0.45474
# 76   devries_model_bbvgg13_do0.4    mcd_mcp   0.93689   0.92843  0.43725
# 65   devries_model_bbvgg16_do0.4    mcd_mcp   0.93289   0.93308  0.46148
# 78   devries_model_bbvgg13_do0.4    mcd_ee    0.93689   0.92321  0.39933
# 175  confidnet_model_bbvgg16_do0.4  mcd_mcp   0.93733   0.92406  0.42025
# 77   devries_model_bbvgg13_do0.4    mcd_pe    0.93689   0.92284  0.39715
# 70   devries_model_bbvgg16_do0.4    mcd_waic  0.93289   0.93049  0.45579
# 173  confidnet_model_bbvgg16_do0.4  tcp_mcd   0.93733   0.92036  0.38099
# 80   devries_model_bbvgg13_do0.4    mcd_sv    0.93689   0.91830  0.34919
# 176  confidnet_model_bbvgg16_do0.4  mcd_pe    0.93733   0.91729  0.37440
# 174  confidnet_model_bbvgg16_do0.4  tcp_waic  0.93733   0.91728  0.36454
# 177  confidnet_model_bbvgg16_do0.4  mcd_ee    0.93733   0.91669  0.37038
# 67   devries_model_bbvgg16_do0.4    mcd_ee    0.93289   0.92437  0.40664
# 66   devries_model_bbvgg16_do0.4    mcd_pe    0.93289   0.92454  0.41141
# 81   devries_model_bbvgg13_do0.4    mcd_waic  0.93689   0.91647  0.40518
# 79   devries_model_bbvgg13_do0.4    mcd_mi    0.93689   0.91351  0.35654
# 179  confidnet_model_bbvgg16_do0.4  mcd_sv    0.93733   0.91373  0.34220
# 180  confidnet_model_bbvgg16_do0.4  mcd_waic  0.93733   0.91461  0.40089
# 69   devries_model_bbvgg16_do0.4    mcd_sv    0.93289   0.92223  0.40602
# 178  confidnet_model_bbvgg16_do0.4  mcd_mi    0.93733   0.90915  0.34345
# 68   devries_model_bbvgg16_do0.4    mcd_mi    0.93289   0.91535  0.37715
# 184  confidnet_model_bbvgg13_do0.4  tcp_mcd   0.92344   0.92644  0.46850
# 186  confidnet_model_bbvgg13_do0.4  mcd_mcp   0.92344   0.92725  0.47994
# 191  confidnet_model_bbvgg13_do0.4  mcd_waic  0.92344   0.92509  0.47369
# 185  confidnet_model_bbvgg13_do0.4  tcp_waic  0.92344   0.92290  0.44456
# 187  confidnet_model_bbvgg13_do0.4  mcd_pe    0.92344   0.91986  0.43320
# 188  confidnet_model_bbvgg13_do0.4  mcd_ee    0.92344   0.91923  0.43170
# 190  confidnet_model_bbvgg13_do0.4  mcd_sv    0.92344   0.91415  0.37956
# 189  confidnet_model_bbvgg13_do0.4  mcd_mi    0.92344   0.90898  0.39014
# 61   devries_model_bbvgg16_do0.4    det_pe    0.91111   0.91158  0.44230
# 60   devries_model_bbvgg16_do0.4    det_mcp   0.91111   0.91124  0.44362
# 170  confidnet_model_bbvgg16_do0.4  det_mcp   0.90833   0.91382  0.48880
# 171  confidnet_model_bbvgg16_do0.4  det_pe    0.90833   0.91193  0.46992
# 72   devries_model_bbvgg13_do0.4    det_pe    0.91022   0.90919  0.46135
# 71   devries_model_bbvgg13_do0.4    det_mcp   0.91022   0.90982  0.47955
# 182  confidnet_model_bbvgg13_do0.4  det_pe    0.90078   0.91116  0.49217
# 181  confidnet_model_bbvgg13_do0.4  det_mcp   0.90078   0.91223  0.50142
# 172  confidnet_model_bbvgg16_do0.4  tcp       0.90833   0.88066  0.36113
# 183  confidnet_model_bbvgg13_do0.4  tcp       0.90078   0.88797  0.41496
# 5    devries_model_bbvgg16_do0      tcp       0.95267   0.50000  0.04733
# 11   devries_model_bbvgg13_do0      tcp       0.95067   0.50000  0.04933
# 74   devries_model_bbvgg13_do0.4    tcp_mcd   0.93689   0.50000  0.06311
# 75   devries_model_bbvgg13_do0.4    tcp_waic  0.93689   0.50000  0.06311
# 63   devries_model_bbvgg16_do0.4    tcp_mcd   0.93289   0.50000  0.06711
# 64   devries_model_bbvgg16_do0.4    tcp_waic  0.93289   0.50000  0.06711
# 62   devries_model_bbvgg16_do0.4    tcp       0.91111   0.50000  0.08889
# 73   devries_model_bbvgg13_do0.4    tcp       0.91022   0.50000  0.08978
#
#          aurc
# 4    4.88580
# 3    5.01831
# 2    5.16056
# 10   5.22552
# 1    5.39603
# 28   5.64960
# 9    5.72837
# 0    5.76586
# 29   6.11898
# 27   6.39861
# 76   7.18589
# 65   7.50924
# 78   7.51088
# 175  7.52031
# 77   7.53187
# 70   7.70657
# 173  7.77148
# 80   7.85145
# 176  7.92648
# 174  7.94764
# 177  7.97919
# 67   8.02501
# 66   8.02728
# 81   8.04414
# 79   8.13945
# 179  8.15757
# 180  8.21848
# 69   8.28600
# 178  8.55620
# 68   8.84055
# 184  9.17497
# 186  9.27451
# 191  9.43143
# 185  9.44815
# 187  9.78524
# 188  9.84402
# 190  10.33838
# 189  10.90928
# 61   12.80749
# 60   12.95358
# 170  13.50256
# 171  13.57452
# 72   13.61412
# 71   13.63559
# 182  14.97579
# 181  15.04066
# 172  17.21192
# 183  17.78975
# 5    47.32807
# 11   49.32785
# 74   63.10410
# 75   63.10410
# 63   67.10365
# 64   67.10365
# 62   88.87901
# 73   89.76780

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["pure_det"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)

# %%
data =  df[(df.study == "iid_study") ]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
dims = ["confid", "backbone", "dropout", "pure_det"]
metrics = ["accuracy", "failauc", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()

# %%
data[["name", "confid", "failauc", "failap_err", "aurc", "accuracy"]].sort_values(by="aurc", ascending=True)
# Out:
#                               name    confid  failauc  failap_err      aurc  \
# 4    devries_model_bbvgg16_do0      det_pe    0.93750  0.42517     4.88580
# 3    devries_model_bbvgg16_do0      det_mcp   0.93655  0.40441     5.01831
# 2    confidnet_model_bbvgg13_do0    tcp       0.94393  0.51606     5.16056
# 10   devries_model_bbvgg13_do0      det_pe    0.93314  0.40921     5.22552
# 1    confidnet_model_bbvgg13_do0    det_pe    0.94176  0.50140     5.39603
# 28   confidnet_model_bbvgg16_do0    det_pe    0.93349  0.45570     5.64960
# 9    devries_model_bbvgg13_do0      det_mcp   0.93193  0.41142     5.72837
# 0    confidnet_model_bbvgg13_do0    det_mcp   0.94149  0.50749     5.76586
# 29   confidnet_model_bbvgg16_do0    tcp       0.93035  0.46285     6.11898
# 27   confidnet_model_bbvgg16_do0    det_mcp   0.93085  0.45474     6.39861
# 76   devries_model_bbvgg13_do0.4    mcd_mcp   0.92843  0.43725     7.18589
# 65   devries_model_bbvgg16_do0.4    mcd_mcp   0.93308  0.46148     7.50924
# 78   devries_model_bbvgg13_do0.4    mcd_ee    0.92321  0.39933     7.51088
# 175  confidnet_model_bbvgg16_do0.4  mcd_mcp   0.92406  0.42025     7.52031
# 77   devries_model_bbvgg13_do0.4    mcd_pe    0.92284  0.39715     7.53187
# 70   devries_model_bbvgg16_do0.4    mcd_waic  0.93049  0.45579     7.70657
# 173  confidnet_model_bbvgg16_do0.4  tcp_mcd   0.92036  0.38099     7.77148
# 80   devries_model_bbvgg13_do0.4    mcd_sv    0.91830  0.34919     7.85145
# 176  confidnet_model_bbvgg16_do0.4  mcd_pe    0.91729  0.37440     7.92648
# 174  confidnet_model_bbvgg16_do0.4  tcp_waic  0.91728  0.36454     7.94764
# 177  confidnet_model_bbvgg16_do0.4  mcd_ee    0.91669  0.37038     7.97919
# 67   devries_model_bbvgg16_do0.4    mcd_ee    0.92437  0.40664     8.02501
# 66   devries_model_bbvgg16_do0.4    mcd_pe    0.92454  0.41141     8.02728
# 81   devries_model_bbvgg13_do0.4    mcd_waic  0.91647  0.40518     8.04414
# 79   devries_model_bbvgg13_do0.4    mcd_mi    0.91351  0.35654     8.13945
# 179  confidnet_model_bbvgg16_do0.4  mcd_sv    0.91373  0.34220     8.15757
# 180  confidnet_model_bbvgg16_do0.4  mcd_waic  0.91461  0.40089     8.21848
# 69   devries_model_bbvgg16_do0.4    mcd_sv    0.92223  0.40602     8.28600
# 178  confidnet_model_bbvgg16_do0.4  mcd_mi    0.90915  0.34345     8.55620
# 68   devries_model_bbvgg16_do0.4    mcd_mi    0.91535  0.37715     8.84055
# 184  confidnet_model_bbvgg13_do0.4  tcp_mcd   0.92644  0.46850     9.17497
# 186  confidnet_model_bbvgg13_do0.4  mcd_mcp   0.92725  0.47994     9.27451
# 191  confidnet_model_bbvgg13_do0.4  mcd_waic  0.92509  0.47369     9.43143
# 185  confidnet_model_bbvgg13_do0.4  tcp_waic  0.92290  0.44456     9.44815
# 187  confidnet_model_bbvgg13_do0.4  mcd_pe    0.91986  0.43320     9.78524
# 188  confidnet_model_bbvgg13_do0.4  mcd_ee    0.91923  0.43170     9.84402
# 190  confidnet_model_bbvgg13_do0.4  mcd_sv    0.91415  0.37956     10.33838
# 189  confidnet_model_bbvgg13_do0.4  mcd_mi    0.90898  0.39014     10.90928
# 61   devries_model_bbvgg16_do0.4    det_pe    0.91158  0.44230     12.80749
# 60   devries_model_bbvgg16_do0.4    det_mcp   0.91124  0.44362     12.95358
# 170  confidnet_model_bbvgg16_do0.4  det_mcp   0.91382  0.48880     13.50256
# 171  confidnet_model_bbvgg16_do0.4  det_pe    0.91193  0.46992     13.57452
# 72   devries_model_bbvgg13_do0.4    det_pe    0.90919  0.46135     13.61412
# 71   devries_model_bbvgg13_do0.4    det_mcp   0.90982  0.47955     13.63559
# 182  confidnet_model_bbvgg13_do0.4  det_pe    0.91116  0.49217     14.97579
# 181  confidnet_model_bbvgg13_do0.4  det_mcp   0.91223  0.50142     15.04066
# 172  confidnet_model_bbvgg16_do0.4  tcp       0.88066  0.36113     17.21192
# 183  confidnet_model_bbvgg13_do0.4  tcp       0.88797  0.41496     17.78975
# 5    devries_model_bbvgg16_do0      tcp       0.50000  0.04733     47.32807
# 11   devries_model_bbvgg13_do0      tcp       0.50000  0.04933     49.32785
# 74   devries_model_bbvgg13_do0.4    tcp_mcd   0.50000  0.06311     63.10410
# 75   devries_model_bbvgg13_do0.4    tcp_waic  0.50000  0.06311     63.10410
# 63   devries_model_bbvgg16_do0.4    tcp_mcd   0.50000  0.06711     67.10365
# 64   devries_model_bbvgg16_do0.4    tcp_waic  0.50000  0.06711     67.10365
# 62   devries_model_bbvgg16_do0.4    tcp       0.50000  0.08889     88.87901
# 73   devries_model_bbvgg13_do0.4    tcp       0.50000  0.08978     89.76780
#
#      accuracy
# 4    0.95267
# 3    0.95267
# 2    0.94411
# 10   0.95067
# 1    0.94411
# 28   0.94600
# 9    0.95067
# 0    0.94411
# 29   0.94600
# 27   0.94600
# 76   0.93689
# 65   0.93289
# 78   0.93689
# 175  0.93733
# 77   0.93689
# 70   0.93289
# 173  0.93733
# 80   0.93689
# 176  0.93733
# 174  0.93733
# 177  0.93733
# 67   0.93289
# 66   0.93289
# 81   0.93689
# 79   0.93689
# 179  0.93733
# 180  0.93733
# 69   0.93289
# 178  0.93733
# 68   0.93289
# 184  0.92344
# 186  0.92344
# 191  0.92344
# 185  0.92344
# 187  0.92344
# 188  0.92344
# 190  0.92344
# 189  0.92344
# 61   0.91111
# 60   0.91111
# 170  0.90833
# 171  0.90833
# 72   0.91022
# 71   0.91022
# 182  0.90078
# 181  0.90078
# 172  0.90833
# 183  0.90078
# 5    0.95267
# 11   0.95067
# 74   0.93689
# 75   0.93689
# 63   0.93289
# 64   0.93289
# 62   0.91111
# 73   0.91022

# %%
sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-382fd463c4a0> in <module>
# ----> 1 sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
#       2 sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
#       3
#       4
#
# ~/research/venvs/genv/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/research/venvs/genv/lib/python3.8/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2792         warnings.warn(msg, UserWarning)
#    2793
# -> 2794     plotter = _StripPlotter(x, y, hue, data, order, hue_order,
#    2795                             jitter, dodge, orient, color, palette)
#    2796     if ax is None:
#
# ~/research/venvs/genv/lib/python3.8/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette)
#    1097                  jitter, dodge, orient, color, palette):
#    1098         """Initialize the plotter."""
# -> 1099         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1100         self.establish_colors(color, palette, 1)
#    1101
#
# ~/research/venvs/genv/lib/python3.8/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'sched'

# %%
df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")  & (df.confid=="devries")].name
