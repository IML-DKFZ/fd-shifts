# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/ultimate_cifar_fix_sweep_noreflect.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0     10
# name           confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# study          new_class_study_tinyimagenet_resize_proposed_mode
# model          confidnet_model
# network        vgg13
# fold           0
# confid         mcd_waic
# n_test         19463
# accuracy       0.4862
# nll            NaN
# brier_score    NaN
# failauc        0.95901
# failap_suc     0.96432
# failap_err     0.95461
# mce            0.54748
# ece            0.26975
# e-aurc         19.725
# aurc           182.906
# fpr@95tpr      0.2676
# Name: 1749, dtype: object

# %%
len(df)
# Out:
# 1750

# %%
df.groupby("study").count()
# Out:
#                                                    Unnamed: 0  name  model  \
# study
# iid_study                                          454         454   454
# new_class_study_tinyimagenet_original_mode         324         324   324
# new_class_study_tinyimagenet_proposed_mode         324         324   324
# new_class_study_tinyimagenet_resize_original_mode  324         324   324
# new_class_study_tinyimagenet_resize_proposed_mode  324         324   324
#
#                                                    network  fold  confid  \
# study
# iid_study                                          454      454   454
# new_class_study_tinyimagenet_original_mode         324      324   324
# new_class_study_tinyimagenet_proposed_mode         324      324   324
# new_class_study_tinyimagenet_resize_original_mode  324      324   324
# new_class_study_tinyimagenet_resize_proposed_mode  324      324   324
#
#                                                    n_test  accuracy  nll  \
# study
# iid_study                                          454     454       454
# new_class_study_tinyimagenet_original_mode         324     324       0
# new_class_study_tinyimagenet_proposed_mode         324     324       0
# new_class_study_tinyimagenet_resize_original_mode  324     324       0
# new_class_study_tinyimagenet_resize_proposed_mode  324     324       0
#
#                                                    brier_score  failauc  \
# study
# iid_study                                          454          454
# new_class_study_tinyimagenet_original_mode         0            212
# new_class_study_tinyimagenet_proposed_mode         0            212
# new_class_study_tinyimagenet_resize_original_mode  0            212
# new_class_study_tinyimagenet_resize_proposed_mode  0            212
#
#                                                    failap_suc  failap_err  \
# study
# iid_study                                          454         454
# new_class_study_tinyimagenet_original_mode         324         212
# new_class_study_tinyimagenet_proposed_mode         324         212
# new_class_study_tinyimagenet_resize_original_mode  324         212
# new_class_study_tinyimagenet_resize_proposed_mode  324         212
#
#                                                    mce  ece  e-aurc  aurc  \
# study
# iid_study                                          454  454  454     454
# new_class_study_tinyimagenet_original_mode         324  324  324     324
# new_class_study_tinyimagenet_proposed_mode         324  324  324     324
# new_class_study_tinyimagenet_resize_original_mode  324  324  324     324
# new_class_study_tinyimagenet_resize_proposed_mode  324  324  324     324
#
#                                                    fpr@95tpr
# study
# iid_study                                          454
# new_class_study_tinyimagenet_original_mode         212
# new_class_study_tinyimagenet_proposed_mode         212
# new_class_study_tinyimagenet_resize_original_mode  212
# new_class_study_tinyimagenet_resize_proposed_mode  212

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"], keep="last")
df_clean = df_clean[df_clean.name.str.contains("cutout")]

# %%
len(df_clean)
# Out:
# 1060

# %%
df_clean.groupby("name").count()
# Out:
#                                                                   Unnamed: 0  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   study  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   model  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   network  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   fold  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   confid  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   n_test  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   accuracy  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   nll  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   3
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    3
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  3
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    3
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     3
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   3
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   11
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    11
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  11
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    11
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     11
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   11
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   3
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    3
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  3
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    3
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     3
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   3
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   11
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    11
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  11
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    11
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     11
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   11
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      8
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       8
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      8
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       8
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      3
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       3
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      3
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       3
#
#                                                                   brier_score  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   3
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    3
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  3
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    3
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     3
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   3
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   11
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    11
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  11
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    11
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     11
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   11
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   3
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    3
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  3
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    3
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     3
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   3
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   11
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    11
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  11
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    11
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     11
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   11
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      8
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       8
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      8
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       8
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      3
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       3
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      3
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       3
#
#                                                                   failauc  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   failap_suc  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   failap_err  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   mce  ece  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15   15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15   15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15   15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55   55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55   55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55   55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15   15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15   15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15   15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55   55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55   55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55   55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40   40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40   40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40   40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40   40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15   15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15   15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15   15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15   15
#
#                                                                   e-aurc  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   aurc  \
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15
#
#                                                                   fpr@95tpr
# name
# confidnet_model_bbvgg13_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg13_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg13_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg13_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect   55
# confidnet_model_bbvgg16_do0_msFalse_cutoutFalse                   15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue                    15
# confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect  15
# confidnet_model_bbvgg16_do0_msTrue_cutoutFalse                    15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue                     15
# confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect   15
# confidnet_model_bbvgg16_do1_msFalse_cutoutFalse                   55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue                    55
# confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect  55
# confidnet_model_bbvgg16_do1_msTrue_cutoutFalse                    55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue                     55
# confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect   55
# det_mcd_model_bbvgg13_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg13_do1_msTrue_cutoutTrue                       40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutFalse                      40
# det_mcd_model_bbvgg16_do1_msTrue_cutoutTrue                       40
# devries_model_bbvgg13_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg13_do0_msTrue_cutoutTrue                       15
# devries_model_bbvgg16_do0_msTrue_cutoutFalse                      15
# devries_model_bbvgg16_do0_msTrue_cutoutTrue                       15

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-121-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                                   name  \
# 1471  confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect
# 1045  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1046  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1044  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1501  confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect
# 1293  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1525  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1288  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1705  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1700  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1051  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1698  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1047  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1286  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1575  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1486  confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect
# 1277  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 966   confidnet_model_bbvgg16_do0_msFalse_cutoutTrue
# 1048  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1520  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1580  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1282  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1050  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1502  confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect
# 1470  confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect
# 1289  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1699  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1279  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1278  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1701  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1287  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1290  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 965   confidnet_model_bbvgg16_do0_msFalse_cutoutTrue
# 1573  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1696  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1702  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1273  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1049  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1285  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1274  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1576  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1275  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1518  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1574  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1697  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1487  confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect
# 1577  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1272  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1485  confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect
# 1472  confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect
# 1284  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1283  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1292  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1704  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1276  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1519  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1521  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1291  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1571  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 968   confidnet_model_bbvgg16_do0_msTrue_cutoutTrue
# 1500  confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect
# 1579  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1522  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1630  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1703  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1524  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1516  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1695  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1635  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 969   confidnet_model_bbvgg16_do0_msTrue_cutoutTrue
# 1578  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 964   confidnet_model_bbvgg16_do0_msFalse_cutoutTrue
# 1572  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1280  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1281  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1517  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1515  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1035  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1040  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1523  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1631  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1036  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 967   confidnet_model_bbvgg16_do0_msTrue_cutoutTrue
# 1037  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1042  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1632  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1681  confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect
# 1255  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1253  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1260  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1570  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1254  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1041  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1628  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1066  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1256  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1682  confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect
# 1257  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1038  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1039  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 20    devries_model_bbvgg16_do0_msTrue_cutoutTrue
# 1067  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1043  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1634  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1266  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1068  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1626  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1633  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1627  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 914   confidnet_model_bbvgg13_do0_msTrue_cutoutTrue
# 1073  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1629  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1271  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1680  confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect
# 1259  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1267  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1069  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1258  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1062  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1057  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1070  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1270  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1268  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1033  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 19    devries_model_bbvgg16_do0_msTrue_cutoutTrue
# 1625  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1058  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1269  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1264  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 915   confidnet_model_bbvgg13_do0_msTrue_cutoutTrue
# 1061  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1031  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1034  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1060  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 913   confidnet_model_bbvgg13_do0_msTrue_cutoutTrue
# 1071  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1059  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1265  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1072  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1030  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1032  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 145   devries_model_bbvgg13_do0_msTrue_cutoutTrue
# 1251  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1250  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1252  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 18    devries_model_bbvgg16_do0_msTrue_cutoutTrue
# 912   confidnet_model_bbvgg13_do0_msFalse_cutoutTrue
# 911   confidnet_model_bbvgg13_do0_msFalse_cutoutTrue
# 910   confidnet_model_bbvgg13_do0_msFalse_cutoutTrue
# 98    devries_model_bbvgg13_do0_msTrue_cutoutFalse
# 143   devries_model_bbvgg13_do0_msTrue_cutoutTrue
# 1064  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 144   devries_model_bbvgg13_do0_msTrue_cutoutTrue
# 1262  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1261  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1065  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1055  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1263  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1063  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1056  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1053  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 97    devries_model_bbvgg13_do0_msTrue_cutoutFalse
# 1052  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 96    devries_model_bbvgg13_do0_msTrue_cutoutFalse
# 930   confidnet_model_bbvgg13_do0_msTrue_cutoutFalse
# 35    devries_model_bbvgg16_do0_msTrue_cutoutFalse
# 932   confidnet_model_bbvgg13_do0_msFalse_cutoutFalse
# 933   confidnet_model_bbvgg13_do0_msFalse_cutoutFalse
# 931   confidnet_model_bbvgg13_do0_msFalse_cutoutFalse
# 929   confidnet_model_bbvgg13_do0_msTrue_cutoutFalse
# 1054  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 959   confidnet_model_bbvgg16_do0_msTrue_cutoutFalse
# 928   confidnet_model_bbvgg13_do0_msTrue_cutoutFalse
# 34    devries_model_bbvgg16_do0_msTrue_cutoutFalse
# 953   confidnet_model_bbvgg16_do0_msFalse_cutoutFalse
# 952   confidnet_model_bbvgg16_do0_msFalse_cutoutFalse
# 958   confidnet_model_bbvgg16_do0_msTrue_cutoutFalse
# 33    devries_model_bbvgg16_do0_msTrue_cutoutFalse
# 954   confidnet_model_bbvgg16_do0_msFalse_cutoutFalse
# 960   confidnet_model_bbvgg16_do0_msTrue_cutoutFalse
#
#         confid  accuracy  failauc  failap_err      aurc
# 1471  det_pe    0.94660   0.94087  0.47486     5.10362
# 1045  tcp_waic  0.94660   0.93652  0.40756     5.13416
# 1046  mcd_mcp   0.94660   0.93915  0.43838     5.16740
# 1044  tcp_mcd   0.94660   0.93672  0.41147     5.17011
# 1501  det_pe    0.94730   0.94259  0.50211     5.19176
# 911   det_pe    0.94490   0.91717  0.44139     7.39820
# 910   det_mcp   0.94490   0.91860  0.43914     7.62499
# 98    devries   0.93522   0.92553  0.40981     7.64333
# 143   det_mcp   0.94311   0.91783  0.42843     8.15481
# 1064  det_pe    0.93600   0.92198  0.46616     8.21499
# 144   det_pe    0.94311   0.91670  0.44342     8.23876
# 1262  det_pe    0.93810   0.92101  0.47584     8.28061
# 1261  det_mcp   0.93810   0.92160  0.46782     8.30865
# 1065  tcp       0.93600   0.92047  0.46267     8.36445
# 1055  tcp_mcd   0.93840   0.91455  0.42078     8.43657
# 1263  tcp       0.93810   0.91803  0.46111     8.43830
# 1063  det_mcp   0.93600   0.92197  0.45536     8.78852
# 1056  tcp_waic  0.93840   0.90859  0.40792     8.88473
# 1053  det_pe    0.93960   0.91419  0.43872     9.06404
# 97    det_pe    0.93522   0.91711  0.42959     9.24330
# 1052  det_mcp   0.93960   0.91411  0.42021     9.40348
# 96    det_mcp   0.93522   0.91763  0.42630     9.51078
# 930   tcp       0.93690   0.90442  0.43995     10.38166
# 35    devries   0.92889   0.91294  0.44388     10.42640
# 932   det_pe    0.93560   0.90496  0.46863     10.43889
# 933   tcp       0.93560   0.90197  0.44657     10.76013
# 931   det_mcp   0.93560   0.90612  0.46119     11.06390
# 929   det_pe    0.93690   0.89724  0.42411     11.08062
# 1054  tcp       0.93960   0.89394  0.38737     11.25858
# 959   det_pe    0.93750   0.89242  0.42610     11.50052
# 928   det_mcp   0.93690   0.89890  0.43793     11.69287
# 34    det_pe    0.92889   0.90213  0.44608     12.09518
# 953   det_pe    0.93810   0.88887  0.42449     12.33281
# 952   det_mcp   0.93810   0.89059  0.41188     12.75647
# 958   det_mcp   0.93750   0.89032  0.40331     12.86002
# 33    det_mcp   0.92889   0.90097  0.42824     12.96466
# 954   tcp       0.93810   0.88472  0.40714     13.00791
# 960   tcp       0.93750   0.87410  0.38471     14.42061

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["model"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["cutout"] = df.apply(lambda row: True if "cutoutTrue" in row["name"] else False, axis=1)
df["ms"] = df.apply(lambda row: True if "msTrue" in row["name"] else False, axis=1)
df["noreflect"] = df.apply(lambda row: True if "noreflect" in row["name"] else False, axis=1)
# df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)

# %%
data =  df[(df.study == "iid_study") & (df.confid.str.contains("tcp"))]
# data =  df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
print(data.name.tolist())
dims = ["confid", "backbone", "dropout", "model", "cutout", "ms", "noreflect"]
metrics = ["accuracy", "failauc", "failap_err", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()
# Out:
# ['confidnet_model_bbvgg13_do0_msFalse_cutoutTrue', 'confidnet_model_bbvgg13_do0_msTrue_cutoutTrue', 'confidnet_model_bbvgg13_do0_msTrue_cutoutFalse', 'confidnet_model_bbvgg13_do0_msFalse_cutoutFalse', 'confidnet_model_bbvgg16_do0_msFalse_cutoutFalse', 'confidnet_model_bbvgg16_do0_msTrue_cutoutFalse', 'confidnet_model_bbvgg16_do0_msFalse_cutoutTrue', 'confidnet_model_bbvgg16_do0_msTrue_cutoutTrue', 'confidnet_model_bbvgg13_do1_msTrue_cutoutTrue', 'confidnet_model_bbvgg13_do1_msTrue_cutoutTrue', 'confidnet_model_bbvgg13_do1_msTrue_cutoutTrue', 'confidnet_model_bbvgg13_do1_msFalse_cutoutTrue', 'confidnet_model_bbvgg13_do1_msFalse_cutoutTrue', 'confidnet_model_bbvgg13_do1_msFalse_cutoutTrue', 'confidnet_model_bbvgg13_do1_msTrue_cutoutFalse', 'confidnet_model_bbvgg13_do1_msTrue_cutoutFalse', 'confidnet_model_bbvgg13_do1_msTrue_cutoutFalse', 'confidnet_model_bbvgg13_do1_msFalse_cutoutFalse', 'confidnet_model_bbvgg13_do1_msFalse_cutoutFalse', 'confidnet_model_bbvgg13_do1_msFalse_cutoutFalse', 'confidnet_model_bbvgg16_do1_msFalse_cutoutFalse', 'confidnet_model_bbvgg16_do1_msFalse_cutoutFalse', 'confidnet_model_bbvgg16_do1_msFalse_cutoutFalse', 'confidnet_model_bbvgg16_do1_msTrue_cutoutFalse', 'confidnet_model_bbvgg16_do1_msTrue_cutoutFalse', 'confidnet_model_bbvgg16_do1_msTrue_cutoutFalse', 'confidnet_model_bbvgg16_do1_msTrue_cutoutTrue', 'confidnet_model_bbvgg16_do1_msTrue_cutoutTrue', 'confidnet_model_bbvgg16_do1_msTrue_cutoutTrue', 'confidnet_model_bbvgg16_do1_msFalse_cutoutTrue', 'confidnet_model_bbvgg16_do1_msFalse_cutoutTrue', 'confidnet_model_bbvgg16_do1_msFalse_cutoutTrue', 'confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect', 'confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect']

# %%
data[["name", "confid", "failauc", "failap_err", "aurc", "failap_suc", "accuracy"]].sort_values(by="aurc", ascending=True)
# Out:
#                                                                   name  \
# 1045  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1044  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1698  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1286  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 966   confidnet_model_bbvgg16_do0_msFalse_cutoutTrue
# 1502  confidnet_model_bbvgg16_do0_msFalse_cutoutTrue_relulastnoreflect
# 1699  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1287  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1573  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1285  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue
# 1274  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1275  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1518  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1574  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1697  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue_relulastnoreflect
# 1487  confidnet_model_bbvgg13_do0_msTrue_cutoutTrue_relulastnoreflect
# 1472  confidnet_model_bbvgg13_do0_msFalse_cutoutTrue_relulastnoreflect
# 1276  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue
# 1519  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 969   confidnet_model_bbvgg16_do0_msTrue_cutoutTrue
# 1572  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue_relulastnoreflect
# 1517  confidnet_model_bbvgg16_do1_msFalse_cutoutTrue_relulastnoreflect
# 1253  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1254  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 1628  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1066  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1682  confidnet_model_bbvgg16_do0_msTrue_cutoutTrue_relulastnoreflect
# 1067  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1043  confidnet_model_bbvgg13_do1_msFalse_cutoutTrue
# 1627  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1629  confidnet_model_bbvgg16_do1_msTrue_cutoutTrue_relulastnoreflect
# 1033  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1264  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 915   confidnet_model_bbvgg13_do0_msTrue_cutoutTrue
# 1034  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1265  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1032  confidnet_model_bbvgg13_do1_msTrue_cutoutTrue
# 1252  confidnet_model_bbvgg16_do1_msFalse_cutoutFalse
# 912   confidnet_model_bbvgg13_do0_msFalse_cutoutTrue
# 1065  confidnet_model_bbvgg13_do1_msFalse_cutoutFalse
# 1055  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 1263  confidnet_model_bbvgg16_do1_msTrue_cutoutFalse
# 1056  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 930   confidnet_model_bbvgg13_do0_msTrue_cutoutFalse
# 933   confidnet_model_bbvgg13_do0_msFalse_cutoutFalse
# 1054  confidnet_model_bbvgg13_do1_msTrue_cutoutFalse
# 954   confidnet_model_bbvgg16_do0_msFalse_cutoutFalse
# 960   confidnet_model_bbvgg16_do0_msTrue_cutoutFalse
#
#         confid  failauc  failap_err      aurc  failap_suc  accuracy
# 1045  tcp_waic  0.93652  0.40756     5.13416   0.99616     0.9466
# 1044  tcp_mcd   0.93672  0.41147     5.17011   0.99612     0.9466
# 1698  tcp_mcd   0.93699  0.41524     5.25318   0.99605     0.9463
# 1286  tcp_mcd   0.93844  0.42507     5.28752   0.99612     0.9445
# 966   tcp       0.93392  0.44410     5.32019   0.99584     0.9488
# 1502  tcp       0.94096  0.49539     5.36313   0.99587     0.9473
# 1699  tcp_waic  0.93529  0.40103     5.36962   0.99593     0.9463
# 1287  tcp_waic  0.93662  0.40918     5.39420   0.99600     0.9445
# 1573  tcp_mcd   0.93814  0.44107     5.41047   0.99601     0.9441
