# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/dg_sweep_ultimate.csv"
df = pd.read_csv(in_path)

# %%
len(df)
# Out:
# 4627

# %%
df.groupby("study").count()
df = df.drop(df[df.model=="mcd_sv"].index)
print(len(df))
# Out:
# 4627

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"])

# %%
len(df_clean)
# Out:
# 3934

# %%
df_clean.groupby("name").count()
# Out:
#                                                                     Unnamed: 0  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     study  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     model  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     network  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         0
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           0
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           0
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  0
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        0
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         0
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  0
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        0
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    0
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          0
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           0
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    0
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          0
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           0
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         0
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           0
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           0
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  0
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        0
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         0
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  0
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        0
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    0
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          0
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           0
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    0
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          0
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           0
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    0
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     0
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   0
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     0
#
#                                                                     fold  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     confid  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     n_test  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# ...
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     risk@80cov  \
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102
#
#                                                                     risk@75cov
# name
# devries_model_bbvgg13_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg13_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg13_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg13_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg13_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg13_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg13_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg13_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg13_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg13_do1_run2_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do0_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do0_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do0_run1_rew10_schedCosineAnnealing_coTrue    30
# devries_model_bbvgg16_do0_run1_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run1_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run1_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew10_schedCosineAnnealing_coTrue    27
# devries_model_bbvgg16_do0_run2_rew2.2_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew3_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do0_run2_rew4.5_schedCosineAnnealing_coTrue   30
# devries_model_bbvgg16_do0_run2_rew6_schedCosineAnnealing_coTrue     30
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.0_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.0_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbvgg16_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbvgg16_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew3_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew3_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbvgg16_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbvgg16_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbvgg16_do1_run1_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run1_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run1_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run1_rew6_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew10_schedCosineAnnealing_coTrue    102
# devries_model_bbvgg16_do1_run2_rew2.2_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew3_schedCosineAnnealing_coTrue     102
# devries_model_bbvgg16_do1_run2_rew4.5_schedCosineAnnealing_coTrue   102
# devries_model_bbvgg16_do1_run2_rew6_schedCosineAnnealing_coTrue     102

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr, risk@100cov, risk@95cov, risk@90cov, risk@85cov, risk@80cov, risk@75cov]
# Index: []

# %%
df = df_clean
df[:10]
# Out:
#    Unnamed: 0                                                       name  \
# 0  0           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 1  1           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 2  2           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 3  0           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 4  1           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 5  2           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 6  0           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 7  1           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 8  2           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
# 9  0           devries_model_bbvgg13_do1_run0_rew6_schedMultiStep_coTrue
#
#                                                study          model  network  \
# 0  iid_study                                          devries_model NaN
# 1  iid_study                                          devries_model NaN
# 2  iid_study                                          devries_model NaN
# 3  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 4  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 5  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 6  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 7  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 8  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 9  new_class_study_tinyimagenet_resize_original_mode  devries_model NaN
#
#    fold   confid   n_test  accuracy      nll  brier_score  failauc  \
# 0  0.0   det_mcp  9000.0   0.94233   0.02173  0.0905       0.93662
# 1  0.0   det_pe   9000.0   0.94233   0.02173  0.0905       0.93827
# 2  0.0   dg       9000.0   0.94233   0.02173  0.0905       0.91679
# 3  0.0   det_mcp  18000.0  0.50000  NaN      NaN           0.94623
# 4  0.0   det_pe   18000.0  0.50000  NaN      NaN           0.95395
# 5  0.0   dg       18000.0  0.50000  NaN      NaN           0.97233
# 6  0.0   det_mcp  17481.0  0.48516  NaN      NaN           0.96589
# 7  0.0   det_pe   17481.0  0.48516  NaN      NaN           0.97052
# 8  0.0   dg       17481.0  0.48516  NaN      NaN           0.98220
# 9  0.0   det_mcp  18000.0  0.50000  NaN      NaN           0.95286
#
devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1390  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1391  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1539  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1540  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1541  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1593  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1594  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1595  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1650  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1651  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1652  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1725  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1726  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1727  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1794  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1795  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1796  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1878  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1879  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1880  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1941  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1942  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 1943  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2052  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2053  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2054  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2149  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2150  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2151  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2550  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2551  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2552  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2553  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2554  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2556  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2557  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2558  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2561  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2562  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2563  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2564  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2565  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2567  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2568  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2569  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2572  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2573  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2574  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2575  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2576  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2578  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2579  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2580  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2583  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2584  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2585  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2586  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2587  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2589  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2590  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2591  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2594  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2595  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2596  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2597  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2598  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2600  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2601  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2602  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2605  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2606  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2607  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2608  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2609  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2611  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2612  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2613  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2616  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2617  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2618  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2619  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2620  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2622  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2623  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2624  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2627  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2628  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2629  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2630  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2631  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2633  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2634  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2635  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2638  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2639  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2640  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2641  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2642  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2644  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2645  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
# 2646  devries_model_bbvgg13_do1_run1_rew2.2_schedCosineAnnealing_coTrue
#
#                                                   study          model  \
# 1389  in_class_cifar10                                   devries_model
# 1390  in_class_cifar10                                   devries_model
# 1391  in_class_cifar10                                   devries_model
# 1539  iid_study                                          devries_model
# 1540  iid_study                                          devries_model
# 1541  iid_study                                          devries_model
# 1593  new_class_study_tinyimagenet_original_mode         devries_model
# 1594  new_class_study_tinyimagenet_original_mode         devries_model
# 1595  new_class_study_tinyimagenet_original_mode         devries_model
# 1650  new_class_study_tinyimagenet_proposed_mode         devries_model
# 1651  new_class_study_tinyimagenet_proposed_mode         devries_model
# 1652  new_class_study_tinyimagenet_proposed_mode         devries_model
# 1725  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 1726  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 1727  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 1794  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 1795  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 1796  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 1878  new_class_study_cifar100_original_mode             devries_model
# 1879  new_class_study_cifar100_original_mode             devries_model
# 1880  new_class_study_cifar100_original_mode             devries_model
# 1941  new_class_study_cifar100_proposed_mode             devries_model
# 1942  new_class_study_cifar100_proposed_mode             devries_model
# 1943  new_class_study_cifar100_proposed_mode             devries_model
# 2052  new_class_study_svhn_original_mode                 devries_model
# 2053  new_class_study_svhn_original_mode                 devries_model
# 2054  new_class_study_svhn_original_mode                 devries_model
# 2149  new_class_study_svhn_proposed_mode                 devries_model
# 2150  new_class_study_svhn_proposed_mode                 devries_model
# 2151  new_class_study_svhn_proposed_mode                 devries_model
# 2550  iid_study                                          devries_model
# 2551  iid_study                                          devries_model
# 2552  iid_study                                          devries_model
# 2553  iid_study                                          devries_model
# 2554  iid_study                                          devries_model
# 2556  iid_study                                          devries_model
# 2557  iid_study                                          devries_model
# 2558  iid_study                                          devries_model
# 2561  new_class_study_tinyimagenet_original_mode         devries_model
# 2562  new_class_study_tinyimagenet_original_mode         devries_model
# 2563  new_class_study_tinyimagenet_original_mode         devries_model
# 2564  new_class_study_tinyimagenet_original_mode         devries_model
# 2565  new_class_study_tinyimagenet_original_mode         devries_model
# 2567  new_class_study_tinyimagenet_original_mode         devries_model
# 2568  new_class_study_tinyimagenet_original_mode         devries_model
# 2569  new_class_study_tinyimagenet_original_mode         devries_model
# 2572  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2573  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2574  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2575  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2576  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2578  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2579  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2580  new_class_study_tinyimagenet_proposed_mode         devries_model
# 2583  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2584  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2585  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2586  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2587  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2589  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2590  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2591  new_class_study_tinyimagenet_resize_original_mode  devries_model
# 2594  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2595  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2596  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2597  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2598  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2600  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2601  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2602  new_class_study_tinyimagenet_resize_proposed_mode  devries_model
# 2605  new_class_study_cifar100_original_mode             devries_model
# 2606  new_class_study_cifar100_original_mode             devries_model
# 2607  new_class_study_cifar100_original_mode             devries_model
# 2608  new_class_study_cifar100_original_mode             devries_model
# 2609  new_class_study_cifar100_original_mode             devries_model
# 2611  new_class_study_cifar100_original_mode             devries_model
# 2612  new_class_study_cifar100_original_mode             devries_model
# 2613  new_class_study_cifar100_original_mode             devries_model
# 2616  new_class_study_cifar100_proposed_mode             devries_model
# 2617  new_class_study_cifar100_proposed_mode             devries_model
# 2618  new_class_study_cifar100_proposed_mode             devries_model
# 2619  new_class_study_cifar100_proposed_mode             devries_model
# 2620  new_class_study_cifar100_proposed_mode             devries_model
# 2622  new_class_study_cifar100_proposed_mode             devries_model
# 2623  new_class_study_cifar100_proposed_mode             devries_model
# 2624  new_class_study_cifar100_proposed_mode             devries_model
# 2627  new_class_study_svhn_original_mode                 devries_model
# 2628  new_class_study_svhn_original_mode                 devries_model
# 2629  new_class_study_svhn_original_mode                 devries_model
# 2630  new_class_study_svhn_original_mode                 devries_model
# 2631  new_class_study_svhn_original_mode                 devries_model
# 2633  new_class_study_svhn_original_mode                 devries_model
# 2634  new_class_study_svhn_original_mode                 devries_model
# 2635  new_class_study_svhn_original_mode                 devries_model
# 2638  new_class_study_svhn_proposed_mode                 devries_model
# 2639  new_class_study_svhn_proposed_mode                 devries_model
# 2640  new_class_study_svhn_proposed_mode                 devries_model
# 2641  new_class_study_svhn_proposed_mode                 devries_model
# 2642  new_class_study_svhn_proposed_mode                 devries_model
# 2644  new_class_study_svhn_proposed_mode                 devries_model
# 2645  new_class_study_svhn_proposed_mode                 devries_model
# 2646  new_class_study_svhn_proposed_mode                 devries_model
#
#       network  fold    confid   n_test  accuracy      nll  brier_score  \
# 1389 NaN       0.0   det_mcp   9000.0   0.93544   0.05197  0.11408
# 1390 NaN       0.0   det_pe    9000.0   0.93544   0.05197  0.11408
# 1391 NaN       0.0   dg        9000.0   0.93544   0.05197  0.11408
# 1539 NaN       0.0   det_mcp   9000.0   0.93544   0.05197  0.11408
# 1540 NaN       0.0   det_pe    9000.0   0.93544   0.05197  0.11408
# 1541 NaN       0.0   dg        9000.0   0.93544   0.05197  0.11408
# 1593 NaN       0.0   det_mcp   18000.0  0.50000  NaN      NaN
# 1594 NaN       0.0   det_pe    18000.0  0.50000  NaN      NaN
# 1595 NaN       0.0   dg        18000.0  0.50000  NaN      NaN
# 1650 NaN       0.0   det_mcp   17419.0  0.48332  NaN      NaN
# 1651 NaN       0.0   det_pe    17419.0  0.48332  NaN      NaN
# 1652 NaN       0.0   dg        17419.0  0.48332  NaN      NaN
# 1725 NaN       0.0   det_mcp   18000.0  0.50000  NaN      NaN
# 1726 NaN       0.0   det_pe    18000.0  0.50000  NaN      NaN
# 1727 NaN       0.0   dg        18000.0  0.50000  NaN      NaN
# 1794 NaN       0.0   det_mcp   17419.0  0.48332  NaN      NaN
# 1795 NaN       0.0   det_pe    17419.0  0.48332  NaN      NaN
# 1796 NaN       0.0   dg        17419.0  0.48332  NaN      NaN
# 1878 NaN       0.0   det_mcp   18000.0  0.50000  NaN      NaN
# 1879 NaN       0.0   det_pe    18000.0  0.50000  NaN      NaN
# 1880 NaN       0.0   dg        18000.0  0.50000  NaN      NaN
# 1941 NaN       0.0   det_mcp   17419.0  0.48332  NaN      NaN
# 1942 NaN       0.0   det_pe    17419.0  0.48332  NaN      NaN
# 1943 NaN       0.0   dg        17419.0  0.48332  NaN      NaN
# 2052 NaN       0.0   det_mcp   34032.0  0.26446  NaN      NaN
# 2053 NaN       0.0   det_pe    34032.0  0.26446  NaN      NaN
# 2054 NaN       0.0   dg        34032.0  0.26446  NaN      NaN
# 2149 NaN       0.0   det_mcp   33451.0  0.25168  NaN      NaN
# 2150 NaN       0.0   det_pe    33451.0  0.25168  NaN      NaN
# 2151 NaN       0.0   dg        33451.0  0.25168  NaN      NaN
# 2550 NaN       0.0   mcd_mcp   9000.0   0.93778   0.03291  0.10370
# 2551 NaN       0.0   mcd_pe    9000.0   0.93778   0.03291  0.10370
# 2552 NaN       0.0   mcd_ee    9000.0   0.93778   0.03291  0.10370
# 2553 NaN       0.0   mcd_mi    9000.0   0.93778   0.03291  0.10370
# 2554 NaN       0.0   mcd_sv    9000.0   0.93778   0.03291  0.10370
# 2556 NaN       0.0   mcd_waic  9000.0   0.93778   0.03291  0.10370
# 2557 NaN       0.0   dg_waic   9000.0   0.93778   0.03291  0.10370
# 2558 NaN       0.0   dg_mcd    9000.0   0.93778   0.03291  0.10370
# 2561 NaN       0.0   mcd_mcp   18000.0  0.50000  NaN      NaN
# 2562 NaN       0.0   mcd_pe    18000.0  0.50000  NaN      NaN
# 2563 NaN       0.0   mcd_ee    18000.0  0.50000  NaN      NaN
# 2564 NaN       0.0   mcd_mi    18000.0  0.50000  NaN      NaN
# 2565 NaN       0.0   mcd_sv    18000.0  0.50000  NaN      NaN
# 2567 NaN       0.0   mcd_waic  18000.0  0.50000  NaN      NaN
# 2568 NaN       0.0   dg_waic   18000.0  0.50000  NaN      NaN
# 2569 NaN       0.0   dg_mcd    18000.0  0.50000  NaN      NaN
# 2572 NaN       0.0   mcd_mcp   17440.0  0.48394  NaN      NaN
# 2573 NaN       0.0   mcd_pe    17440.0  0.48394  NaN      NaN
# 2574 NaN       0.0   mcd_ee    17440.0  0.48394  NaN      NaN
# 2575 NaN       0.0   mcd_mi    17440.0  0.48394  NaN      NaN
# 2576 NaN       0.0   mcd_sv    17440.0  0.48394  NaN      NaN
# 2578 NaN       0.0   mcd_waic  17440.0  0.48394  NaN      NaN
# 2579 NaN       0.0   dg_waic   17419.0  0.48394  NaN      NaN
# 2580 NaN       0.0   dg_mcd    17440.0  0.48394  NaN      NaN
# 2583 NaN       0.0   mcd_mcp   18000.0  0.50000  NaN      NaN
# 2584 NaN       0.0   mcd_pe    18000.0  0.50000  NaN      NaN
# 2585 NaN       0.0   mcd_ee    18000.0  0.50000  NaN      NaN
# 2586 NaN       0.0   mcd_mi    18000.0  0.50000  NaN      NaN
# 2587 NaN       0.0   mcd_sv    18000.0  0.50000  NaN      NaN
# 2589 NaN       0.0   mcd_waic  18000.0  0.50000  NaN      NaN
# 2590 NaN       0.0   dg_waic   18000.0  0.50000  NaN      NaN
# 2591 NaN       0.0   dg_mcd    18000.0  0.50000  NaN      NaN
# 2594 NaN       0.0   mcd_mcp   17440.0  0.48394  NaN      NaN
# 2595 NaN       0.0   mcd_pe    17440.0  0.48394  NaN      NaN
# 2596 NaN       0.0   mcd_ee    17440.0  0.48394  NaN      NaN
# 2597 NaN       0.0   mcd_mi    17440.0  0.48394  NaN      NaN
# 2598 NaN       0.0   mcd_sv    17440.0  0.48394  NaN      NaN
# 2600 NaN       0.0   mcd_waic  17440.0  0.48394  NaN      NaN
# 2601 NaN       0.0   dg_waic   17419.0  0.48394  NaN      NaN
# 2602 NaN       0.0   dg_mcd    17440.0  0.48394  NaN      NaN
# 2605 NaN       0.0   mcd_mcp   18000.0  0.50000  NaN      NaN
# 2606 NaN       0.0   mcd_pe    18000.0  0.50000  NaN      NaN
# 2607 NaN       0.0   mcd_ee    18000.0  0.50000  NaN      NaN
# 2608 NaN       0.0   mcd_mi    18000.0  0.50000  NaN      NaN
# 2609 NaN       0.0   mcd_sv    18000.0  0.50000  NaN      NaN
# 2611 NaN       0.0   mcd_waic  18000.0  0.50000  NaN      NaN
# 2612 NaN       0.0   dg_waic   18000.0  0.50000  NaN      NaN
# 2613 NaN       0.0   dg_mcd    18000.0  0.50000  NaN      NaN
# 2616 NaN       0.0   mcd_mcp   17440.0  0.48394  NaN      NaN
# 2617 NaN       0.0   mcd_pe    17440.0  0.48394  NaN      NaN
# 2618 NaN       0.0   mcd_ee    17440.0  0.48394  NaN      NaN
# 2619 NaN       0.0   mcd_mi    17440.0  0.48394  NaN      NaN
# 2620 NaN       0.0   mcd_sv    17440.0  0.48394  NaN      NaN
# 2622 NaN       0.0   mcd_waic  17440.0  0.48394  NaN      NaN
# 2623 NaN       0.0   dg_waic   17419.0  0.48394  NaN      NaN
# 2624 NaN       0.0   dg_mcd    17440.0  0.48394  NaN      NaN
# 2627 NaN       0.0   mcd_mcp   34032.0  0.26446  NaN      NaN
# 2628 NaN       0.0   mcd_pe    34032.0  0.26446  NaN      NaN
# 2629 NaN       0.0   mcd_ee    34032.0  0.26446  NaN      NaN
# 2630 NaN       0.0   mcd_mi    34032.0  0.26446  NaN      NaN
# 2631 NaN       0.0   mcd_sv    34032.0  0.26446  NaN      NaN
# 2633 NaN       0.0   mcd_waic  34032.0  0.26446  NaN      NaN
# 2634 NaN       0.0   dg_waic   34032.0  0.26446  NaN      NaN
:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["model"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["run"] = df.apply(lambda row: row["name"].split("run")[1].split("_")[0] if "run" in row["name"] else "-1", axis=1)
# df["relu"] = df.apply(lambda row: "last" if ("last" in row["name"] or row["backbone"]=="vgg") else "first", axis=1)
# df["reflect"] = df.apply(lambda row: False if ("noreflect" in row["name"] or row["backbone"]=="vgg") else True, axis=1)
df["rew"] = df.apply(lambda row: row["name"].split("_rew")[1].split("_")[0], axis=1)
df["sched"] = df.apply(lambda row: "Multi" if "MultiStep" in row["name"] else "Cosine", axis=1)
df["co"] = df.apply(lambda row: True if "coTrue" in row["name"] else False, axis=1)


# df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)
# df.backbone.tolist()
# Out:
# <ipython-input-69-844a229ff22b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
# <ipython-input-69-844a229ff22b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
# <ipython-input-69-844a229ff22b>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["model"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
# <ipython-input-69-844a229ff22b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["run"] = df.apply(lambda row: row["name"].split("run")[1].split("_")[0] if "run" in row["name"] else "-1", axis=1)
# <ipython-input-69-844a229ff22b>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rew"] = df.apply(lambda row: row["name"].split("_rew")[1].split("_")[0], axis=1)
# <ipython-input-69-844a229ff22b>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sched"] = df.apply(lambda row: "Multi" if "MultiStep" in row["name"] else "Cosine", axis=1)
# <ipython-input-69-844a229ff22b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["co"] = df.apply(lambda row: True if "coTrue" in row["name"] else False, axis=1)

# %%
non_agg_columns = ["study", "model", "backbone", "rew", "dropout", "sched", "confid", "co"]
import numpy as np
dfg = df.groupby(by=non_agg_columns).mean().reset_index()
dfg_std = df.groupby(by=non_agg_columns).std().reset_index()
rename_dict = {k:"{}_std".format(k) for k in dfg.columns if k not in non_agg_columns }
dfg_std = dfg_std.rename(columns=rename_dict)
print(len(df), len(dfg), len(dfg_std))
print(dfg_std.columns)
print(rename_dict)
# Out:
# 3933 2292 2292
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid', 'co',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std', 'risk@100cov_std', 'risk@95cov_std',
#        'risk@90cov_std', 'risk@85cov_std', 'risk@80cov_std', 'risk@75cov_std'],
#       dtype='object')
# {'Unnamed: 0': 'Unnamed: 0_std', 'network': 'network_std', 'fold': 'fold_std', 'n_test': 'n_test_std', 'accuracy': 'accuracy_std', 'nll': 'nll_std', 'brier_score': 'brier_score_std', 'failauc': 'failauc_std', 'failap_suc': 'failap_suc_std', 'failap_err': 'failap_err_std', 'mce': 'mce_std', 'ece': 'ece_std', 'e-aurc': 'e-aurc_std', 'aurc': 'aurc_std', 'fpr@95tpr': 'fpr@95tpr_std', 'risk@100cov': 'risk@100cov_std', 'risk@95cov': 'risk@95cov_std', 'risk@90cov': 'risk@90cov_std', 'risk@85cov': 'risk@85cov_std', 'risk@80cov': 'risk@80cov_std', 'risk@75cov': 'risk@75cov_std'}

# %%
study= "iid_study"
select = (dfg.study == study)
data =  dfg[select]
data_std =  dfg_std[select]
# data =  df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]

# %%
plot_data = data[ (data.sched.str.contains("Cosine")) & (data.co == True)]# & (data["ne"].str.contains("250")) & (data["ap"]==False)]
scale = 5
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=scale * 0.3)
dims = ["confid", "model", "backbone", "dropout", "rew", "sched", "co"]
metrics = ["accuracy", "failauc", "failap_err", "aurc"]

f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data, s = scale*0.8)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=90)
        # if "iid" in study and metric == "aurc":
        #     axs[xix, yix].set_ylim(4, 8)
        # if "iid" in study and metric == "failauc":
        #     axs[xix, yix].set_ylim(0.90, 0.96)
plt.tight_layout()
# plt.savefig("/Users/Paul/research/files/analysis/{}_cifar10.png".format(study))

# %%
std_columns = [c for c in data_std.columns if "std"in c]
for s in std_columns:
    data[s] = data_std[s]

print(data.columns)
print(data_std.columns)
print(len(data))
data[["model", "backbone",  "dropout", "co", "confid", "sched", "rew", "accuracy", "accuracy_std", "failauc", "failauc_std", "aurc", "aurc_std", "failap_suc", "risk@100cov", "risk@95cov", "risk@90cov", "risk@85cov", "risk@80cov"]].sort_values(by="aurc", ascending=True)
# Out:
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid', 'co',
#        'Unnamed: 0', 'network', 'fold', 'n_test', 'accuracy', 'nll',
#        'brier_score', 'failauc', 'failap_suc', 'failap_err', 'mce', 'ece',
#        'e-aurc', 'aurc', 'fpr@95tpr', 'risk@100cov', 'risk@95cov',
#        'risk@90cov', 'risk@85cov', 'risk@80cov', 'risk@75cov',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std', 'risk@100cov_std', 'risk@95cov_std',
#        'risk@90cov_std', 'risk@85cov_std', 'risk@80cov_std', 'risk@75cov_std'],
#       dtype='object')
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid', 'co',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std', 'risk@100cov_std', 'risk@95cov_std',
#        'risk@90cov_std', 'risk@85cov_std', 'risk@80cov_std', 'risk@75cov_std'],
#       dtype='object')
# 248
# <ipython-input-73-6d99a07b5909>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[s] = data_std[s]
#        model backbone dropout     co    confid   sched  rew  accuracy  \
# 209  devries  vgg16    0       True   det_pe    Cosine  4.5  0.950835
# 183  devries  vgg16    0       True   det_pe    Cosine  3    0.950850
# 1    devries  vgg13    0       True   det_pe    Cosine  10   0.949555
# 113  devries  vgg13    1       True   mcd_mcp   Cosine  6    0.945385
# 99   devries  vgg13    0       True   det_pe    Cosine  6    0.950853
# 140  devries  vgg16    0       True   dg        Cosine  2.0  0.948220
# 182  devries  vgg16    0       True   det_mcp   Cosine  3    0.950850
# 93   devries  vgg13    1       True   mcd_mcp   Cosine  4.5  0.947055
# 115  devries  vgg13    1       True   mcd_pe    Cosine  6    0.945385
# 112  devries  vgg13    1       True   mcd_ee    Cosine  6    0.945385
# 223  devries  vgg16    0       True   det_pe    Cosine  6    0.953370
# 9    devries  vgg13    1       True   mcd_mcp   Cosine  10   0.945610
# 133  devries  vgg16    1       True   mcd_mcp   Cosine  10   0.945945
# 95   devries  vgg13    1       True   mcd_pe    Cosine  4.5  0.947055
# 0    devries  vgg13    0       True   det_mcp   Cosine  10   0.949555
# 34   devries  vgg13    0       True   dg        Cosine  2.2  0.949740
# 92   devries  vgg13    1       True   mcd_ee    Cosine  4.5  0.947055
# 208  devries  vgg16    0       True   det_mcp   Cosine  4.5  0.950835
# 116  devries  vgg13    1       True   mcd_sv    Cosine  6    0.945385
# 96   devries  vgg13    1       True   mcd_sv    Cosine  4.5  0.947055
# 11   devries  vgg13    1       True   mcd_pe    Cosine  10   0.945610
# 184  devries  vgg16    0       True   dg        Cosine  3    0.950850
# 32   devries  vgg13    0       True   det_mcp   Cosine  2.2  0.949740
# 59   devries  vgg13    0       True   det_pe    Cosine  3    0.950853
# 135  devries  vgg16    1       True   mcd_pe    Cosine  10   0.945945
# 125  devries  vgg16    0       True   det_pe    Cosine  10   0.949780
# 237  devries  vgg16    1       True   mcd_mcp   Cosine  6    0.944280
# 8    devries  vgg13    1       True   mcd_ee    Cosine  10   0.945610
# 85   devries  vgg13    0       True   det_pe    Cosine  4.5  0.949835
# 132  devries  vgg16    1       True   mcd_ee    Cosine  10   0.945945
# 94   devries  vgg13    1       True   mcd_mi    Cosine  4.5  0.947055
# 114  devries  vgg13    1       True   mcd_mi    Cosine  6    0.945385
# 4    devries  vgg13    1       True   det_pe    Cosine  10   0.944830
# 107  devries  vgg13    1       True   det_pe    Cosine  6    0.944407
# 12   devries  vgg13    1       True   mcd_sv    Cosine  10   0.945610
# 217  devries  vgg16    1       True   mcd_mcp   Cosine  4.5  0.943830
# 33   devries  vgg13    0       True   det_pe    Cosine  2.2  0.949740
# 73   devries  vgg13    1       True   mcd_mcp   Cosine  3    0.942835
# 222  devries  vgg16    0       True   det_mcp   Cosine  6    0.953370
# 98   devries  vgg13    0       True   det_mcp   Cosine  6    0.950853
# 75   devries  vgg13    1       True   mcd_pe    Cosine  3    0.942835
# 219  devries  vgg16    1       True   mcd_pe    Cosine  4.5  0.943830
# 128  devries  vgg16    1       True   det_pe    Cosine  10   0.944725
# 81   devries  vgg13    1       True   det_pe    Multi   3    0.944890
# 216  devries  vgg16    1       True   mcd_ee    Cosine  4.5  0.943830
# 88   devries  vgg13    1       True   det_pe    Cosine  4.5  0.944335
# 10   devries  vgg13    1       True   mcd_mi    Cosine  10   0.945610
# 17   devries  vgg13    0       True   det_mcp   Multi   2.0  0.949000
# 239  devries  vgg16    1       True   mcd_pe    Cosine  6    0.944280
# 136  devries  vgg16    1       True   mcd_sv    Cosine  10   0.945945
# 236  devries  vgg16    1       True   mcd_ee    Cosine  6    0.944280
# 156  devries  vgg16    0       True   det_mcp   Cosine  2.2  0.948480
# 19   devries  vgg13    0       True   dg        Multi   2.0  0.949000
# 72   devries  vgg13    1       True   mcd_ee    Cosine  3    0.942835
# 158  devries  vgg16    0       True   dg        Cosine  2.2  0.948480
# 117  devries  vgg13    1       True   mcd_waic  Cosine  6    0.945385
# 16   devries  vgg13    0       True   dg        Cosine  2.0  0.949000
# 124  devries  vgg16    0       True   det_mcp   Cosine  10   0.949780
# 138  devries  vgg16    0       True   det_mcp   Cosine  2.0  0.948220
# 134  devries  vgg16    1       True   mcd_mi    Cosine  10   0.945945
# 84   devries  vgg13    0       True   det_mcp   Cosine  4.5  0.949835
# 58   devries  vgg13    0       True   det_mcp   Cosine  3    0.950853
# 55   devries  vgg13    1       True   det_pe    Multi   2.2  0.944780
# 18   devries  vgg13    0       True   det_pe    Multi   2.0  0.949000
# 79   devries  vgg13    1       True   det_mcp   Multi   3    0.944890
# 87   devries  vgg13    1       True   det_mcp   Cosine  4.5  0.944335
# 240  devries  vgg16    1       True   mcd_sv    Cosine  6    0.944280
# 220  devries  vgg16    1       True   mcd_sv    Cosine  4.5  0.943830
# 127  devries  vgg16    1       True   det_mcp   Cosine  10   0.944725
# 76   devries  vgg13    1       True   mcd_sv    Cosine  3    0.942835
# 74   devries  vgg13    1       True   mcd_mi    Cosine  3    0.942835
# 137  devries  vgg16    1       True   mcd_waic  Cosine  10   0.945945
# 157  devries  vgg16    0       True   det_pe    Cosine  2.2  0.948480
# 3    devries  vgg13    1       True   det_mcp   Cosine  10   0.944830
# 62   devries  vgg13    0       True   det_pe    Multi   3    0.950560
# 221  devries  vgg16    1       True   mcd_waic  Cosine  4.5  0.943830
# 121  devries  vgg13    1       True   det_pe    Multi   6    0.942330
# 212  devries  vgg16    1       True   det_pe    Cosine  4.5  0.943055
# 231  devries  vgg16    1       True   det_pe    Cosine  6    0.944260
# 105  devries  vgg13    1       True   det_mcp   Cosine  6    0.944407
# 218  devries  vgg16    1       True   mcd_mi    Cosine  4.5  0.943830
# 47   devries  vgg13    1       True   mcd_mcp   Cosine  2.2  0.940055
# 238  devries  vgg16    1       True   mcd_mi    Cosine  6    0.944280
# 179  devries  vgg16    1       True   det_pe    Multi   2.2  0.941220
# 102  devries  vgg13    0       True   det_pe    Multi   6    0.948440
# 229  devries  vgg16    1       True   det_mcp   Cosine  6    0.944260
# 14   devries  vgg13    0       True   det_mcp   Cosine  2.0  0.949000
# 245  devries  vgg16    1       True   det_pe    Multi   6    0.941670
# 211  devries  vgg16    1       True   det_mcp   Cosine  4.5  0.943055
# 67   devries  vgg13    1       True   det_pe    Cosine  3    0.942110
# 57   devries  vgg13    1       True   dg        Multi   2.2  0.944780
# 31   devries  vgg13    1       True   dg        Multi   2.0  0.942220
# 44   devries  vgg13    1       True   dg_mcd    Cosine  2.2  0.940055
# 205  devries  vgg16    1       True   det_pe    Multi   3    0.941440
# 29   devries  vgg13    1       True   det_pe    Multi   2.0  0.942220
# 61   devries  vgg13    0       True   det_mcp   Multi   3    0.950560
# 65   devries  vgg13    1       True   det_mcp   Cosine  3    0.942110
# 53   devries  vgg13    1       True   det_mcp   Multi   2.2  0.944780
# 77   devries  vgg13    1       True   mcd_waic  Cosine  3    0.942835
# 13   devries  vgg13    1       True   mcd_waic  Cosine  10   0.945610
# 97   devries  vgg13    1       True   mcd_waic  Cosine  4.5  0.947055
# 241  devries  vgg16    1       True   mcd_waic  Cosine  6    0.944280
# 181  devries  vgg16    1       True   dg        Multi   2.2  0.941220
# 45   devries  vgg13    1       True   dg_waic   Cosine  2.2  0.940055
# 197  devries  vgg16    1       True   mcd_mcp   Cosine  3    0.940335
# 49   devries  vgg13    1       True   mcd_pe    Cosine  2.2  0.940055
# 119  devries  vgg13    1       True   det_mcp   Multi   6    0.942330
# 177  devries  vgg16    1       True   det_mcp   Multi   2.2  0.941220
# 139  devries  vgg16    0       True   det_pe    Cosine  2.0  0.948220
# 199  devries  vgg16    1       True   mcd_pe    Cosine  3    0.940335
# 43   devries  vgg13    1       True   dg        Cosine  2.2  0.937963
# 155  devries  vgg16    1       True   dg        Multi   2.0  0.943220
# 46   devries  vgg13    1       True   mcd_ee    Cosine  2.2  0.940055
# 27   devries  vgg13    1       True   det_mcp   Multi   2.0  0.942220
# 129  devries  vgg16    1       True   dg        Cosine  10   0.944725
# 60   devries  vgg13    0       True   dg        Cosine  3    0.950853
# 153  devries  vgg16    1       True   det_pe    Multi   2.0  0.943220
# 243  devries  vgg16    1       True   det_mcp   Multi   6    0.941670
# 141  devries  vgg16    0       True   det_mcp   Multi   2.0  0.947330
# 143  devries  vgg16    0       True   dg        Multi   2.0  0.947330
# 109  devries  vgg13    1       True   dg        Cosine  6    0.944407
# 101  devries  vgg13    0       True   det_mcp   Multi   6    0.948440
# 51   devries  vgg13    1       True   mcd_waic  Cosine  2.2  0.940055
# 66   devries  vgg13    1       False  det_pe    Cosine  3    0.939110
# 151  devries  vgg16    1       True   det_mcp   Multi   2.0  0.943220
# 69   devries  vgg13    1       True   dg        Cosine  3    0.942110
# 36   devries  vgg13    0       True   det_pe    Multi   2.2  0.951000
# 48   devries  vgg13    1       True   mcd_mi    Cosine  2.2  0.940055
# 15   devries  vgg13    0       True   det_pe    Cosine  2.0  0.949000
# 39   devries  vgg13    1       True   det_mcp   Cosine  2.2  0.937963
# 83   devries  vgg13    1       True   dg        Multi   3    0.944890
# 203  devries  vgg16    1       True   det_mcp   Multi   3    0.941440
# 210  devries  vgg16    0       True   dg        Cosine  4.5  0.950835
# 42   devries  vgg13    1       False  dg        Cosine  2.2  0.938670
# 5    devries  vgg13    1       True   dg        Cosine  10   0.944830
# 35   devries  vgg13    0       True   det_mcp   Multi   2.2  0.951000
# 189  devries  vgg16    1       True   det_mcp   Cosine  3    0.938000
# 106  devries  vgg13    1       False  det_pe    Cosine  6    0.939330
# 89   devries  vgg13    1       True   dg        Cosine  4.5  0.944335
# 200  devries  vgg16    1       True   mcd_sv    Cosine  3    0.940335
# 196  devries  vgg16    1       True   mcd_ee    Cosine  3    0.940335
# 186  devries  vgg16    0       True   det_pe    Multi   3    0.949560
# 230  devries  vgg16    1       False  det_pe    Cosine  6    0.937440
# 50   devries  vgg13    1       True   mcd_sv    Cosine  2.2  0.940055
# 68   devries  vgg13    1       False  dg        Cosine  3    0.939110
# 198  devries  vgg16    1       True   mcd_mi    Cosine  3    0.940335
# 161  devries  vgg16    0       True   dg        Multi   2.2  0.949890
# 110  devries  vgg13    1       True   dg_mcd    Cosine  6    0.945385
# 159  devries  vgg16    0       True   det_mcp   Multi   2.2  0.949890
# 41   devries  vgg13    1       True   det_pe    Cosine  2.2  0.937963
# 37   devries  vgg13    0       True   dg        Multi   2.2  0.951000
# 80   devries  vgg13    1       False  det_pe    Multi   3    0.936110
# 201  devries  vgg16    1       True   mcd_waic  Cosine  3    0.940335
# 160  devries  vgg16    0       True   det_pe    Multi   2.2  0.949890
# 24   devries  vgg13    1       False  dg        Cosine  2.0  0.933110
# 90   devries  vgg13    1       True   dg_mcd    Cosine  4.5  0.947055
# 38   devries  vgg13    1       False  det_mcp   Cosine  2.2  0.938670
# 130  devries  vgg16    1       True   dg_mcd    Cosine  10   0.945945
# 191  devries  vgg16    1       True   det_pe    Cosine  3    0.938000
# 28   devries  vgg13    1       False  det_pe    Multi   2.0  0.937330
# 190  devries  vgg16    1       False  det_pe    Cosine  3    0.935670
# 111  devries  vgg13    1       True   dg_waic   Cosine  6    0.945385
# 30   devries  vgg13    1       False  dg        Multi   2.0  0.937330
# 70   devries  vgg13    1       True   dg_mcd    Cosine  3    0.942835
# 228  devries  vgg16    1       False  det_mcp   Cosine  6    0.937440
# 171  devries  vgg16    1       True   mcd_mcp   Cosine  2.2  0.933555
# 188  devries  vgg16    1       False  det_mcp   Cosine  3    0.935670
# 120  devries  vgg13    1       False  det_pe    Multi   6    0.937330
# 40   devries  vgg13    1       False  det_pe    Cosine  2.2  0.938670
# 226  devries  vgg16    0       True   det_pe    Multi   6    0.949780
# 244  devries  vgg16    1       False  det_pe    Multi   6    0.938440
# 63   devries  vgg13    0       True   dg        Multi   3    0.950560
# 25   devries  vgg13    1       True   dg        Cosine  2.0  0.932110
# 123  devries  vgg13    1       True   dg        Multi   6    0.942330
# 91   devries  vgg13    1       True   dg_waic   Cosine  4.5  0.947055
# 233  devries  vgg16    1       True   dg        Cosine  6    0.944260
# 6    devries  vgg13    1       True   dg_mcd    Cosine  10   0.945610
# 213  devries  vgg16    1       True   dg        Cosine  4.5  0.943055
# 131  devries  vgg16    1       True   dg_waic   Cosine  10   0.945945
# 20   devries  vgg13    1       False  det_mcp   Cosine  2.0  0.933110
# 21   devries  vgg13    1       True   det_mcp   Cosine  2.0  0.932110
# 142  devries  vgg16    0       True   det_pe    Multi   2.0  0.947330
# 86   devries  vgg13    0       True   dg        Cosine  4.5  0.949835
# 168  devries  vgg16    1       True   dg_mcd    Cosine  2.2  0.933555
# 175  devries  vgg16    1       True   mcd_waic  Cosine  2.2  0.933555
# 204  devries  vgg16    1       False  det_pe    Multi   3    0.935560
# 225  devries  vgg16    0       True   det_mcp   Multi   6    0.949780
# 71   devries  vgg13    1       True   dg_waic   Cosine  3    0.942835
# 166  devries  vgg16    1       False  dg        Cosine  2.2  0.933890
# 167  devries  vgg16    1       True   dg        Cosine  2.2  0.931297
# 64   devries  vgg13    1       False  det_mcp   Cosine  3    0.939110
# 163  devries  vgg16    1       True   det_mcp   Cosine  2.2  0.931297
# 54   devries  vgg13    1       False  det_pe    Multi   2.2  0.934330
# 169  devries  vgg16    1       True   dg_waic   Cosine  2.2  0.933555
# 185  devries  vgg16    0       True   det_mcp   Multi   3    0.949560
# 192  devries  vgg16    1       False  dg        Cosine  3    0.935670
# 193  devries  vgg16    1       True   dg        Cosine  3    0.938000
# 7    devries  vgg13    1       True   dg_waic   Cosine  10   0.945610
# 234  devries  vgg16    1       True   dg_mcd    Cosine  6    0.944280
# 26   devries  vgg13    1       False  det_mcp   Multi   2.0  0.937330
# 108  devries  vgg13    1       False  dg        Cosine  6    0.939330
# 82   devries  vgg13    1       False  dg        Multi   3    0.936110
# 178  devries  vgg16    1       False  det_pe    Multi   2.2  0.937780
# 22   devries  vgg13    1       False  det_pe    Cosine  2.0  0.933110
# 149  devries  vgg16    1       True   dg        Cosine  2.0  0.928780
# 145  devries  vgg16    1       True   det_mcp   Cosine  2.0  0.928780
# 173  devries  vgg16    1       True   mcd_pe    Cosine  2.2  0.933555
# 214  devries  vgg16    1       True   dg_mcd    Cosine  4.5  0.943830
# 100  devries  vgg13    0       True   dg        Cosine  6    0.950853
# 152  devries  vgg16    1       False  det_pe    Multi   2.0  0.936110
# 232  devries  vgg16    1       False  dg        Cosine  6    0.937440
# 162  devries  vgg16    1       False  det_mcp   Cosine  2.2  0.933890
# 23   devries  vgg13    1       True   det_pe    Cosine  2.0  0.932110
# 235  devries  vgg16    1       True   dg_waic   Cosine  6    0.944280
# 148  devries  vgg16    1       False  dg        Cosine  2.0  0.928560
# 194  devries  vgg16    1       True   dg_mcd    Cosine  3    0.940335
# 172  devries  vgg16    1       True   mcd_mi    Cosine  2.2  0.933555
# 164  devries  vgg16    1       False  det_pe    Cosine  2.2  0.933890
# 170  devries  vgg16    1       True   mcd_ee    Cosine  2.2  0.933555
# 104  devries  vgg13    1       False  det_mcp   Cosine  6    0.939330
# 247  devries  vgg16    1       True   dg        Multi   6    0.941670
# 215  devries  vgg16    1       True   dg_waic   Cosine  4.5  0.943830
# 207  devries  vgg16    1       True   dg        Multi   3    0.941440
# 144  devries  vgg16    1       False  det_mcp   Cosine  2.0  0.928560
# 242  devries  vgg16    1       False  det_mcp   Multi   6    0.938440
# 154  devries  vgg16    1       False  dg        Multi   2.0  0.936110
# 246  devries  vgg16    1       False  dg        Multi   6    0.938440
# 195  devries  vgg16    1       True   dg_waic   Cosine  3    0.940335
# 202  devries  vgg16    1       False  det_mcp   Multi   3    0.935560
# 122  devries  vgg13    1       False  dg        Multi   6    0.937330
# 174  devries  vgg16    1       True   mcd_sv    Cosine  2.2  0.933555
# 56   devries  vgg13    1       False  dg        Multi   2.2  0.934330
# 150  devries  vgg16    1       False  det_mcp   Multi   2.0  0.936110
# 180  devries  vgg16    1       False  dg        Multi   2.2  0.937780
# 2    devries  vgg13    0       True   dg        Cosine  10   0.949555
# 165  devries  vgg16    1       True   det_pe    Cosine  2.2  0.931297
# 224  devries  vgg16    0       True   dg        Cosine  6    0.953370
# 52   devries  vgg13    1       False  det_mcp   Multi   2.2  0.934330
# 176  devries  vgg16    1       False  det_mcp   Multi   2.2  0.937780
# 187  devries  vgg16    0       True   dg        Multi   3    0.949560
# 78   devries  vgg13    1       False  det_mcp   Multi   3    0.936110
# 146  devries  vgg16    1       False  det_pe    Cosine  2.0  0.928560
# 118  devries  vgg13    1       False  det_mcp   Multi   6    0.937330
# 103  devries  vgg13    0       True   dg        Multi   6    0.948440
# 147  devries  vgg16    1       True   det_pe    Cosine  2.0  0.928780
# 206  devries  vgg16    1       False  dg        Multi   3    0.935560
# 126  devries  vgg16    0       True   dg        Cosine  10   0.949780
# 227  devries  vgg16    0       True   dg        Multi   6    0.949780
#
#      accuracy_std   failauc  failauc_std       aurc  aurc_std  failap_suc  \
# 209  0.001648      0.941495  0.001987     4.683945   0.251002  0.996400
# 183  0.002318      0.940077  0.004374     4.774980   0.157029  0.996307
# 1    0.000318      0.939910  0.003932     4.828710   0.291851  0.996310
# 113  0.000078      0.944025  0.001308     4.882515   0.043098  0.996485
