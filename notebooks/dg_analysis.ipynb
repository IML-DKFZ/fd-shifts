# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/dg_sweep_fix.csv"
df = pd.read_csv(in_path)

# %%
len(df)
# Out:
# 1728

# %%
df.groupby("study").count()
df = df.drop(df[df.model=="mcd_sv"].index)
print(len(df))
# Out:
# 1728

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"])

# %%
len(df_clean)
# Out:
# 1728

# %%
df_clean.groupby("name").count()
# Out:
#                                                     Unnamed: 0  study  model  \
# name
# devries_model_bbvgg16_do0_run0_rew2.2                       27     27     27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...          27     27     27
# devries_model_bbvgg16_do0_run0_rew2.6                       27     27     27
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...          27     27     27
# devries_model_bbvgg16_do0_run0_rew3                         27     27     27
# ...                                                        ...    ...    ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep          27     27     27
# devries_model_bbvgg16_do1_run1_rew6                         27     27     27
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep          27     27     27
# devries_model_bbvgg16_do1_run1_rew8                         27     27     27
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep          27     27     27
#
#                                                     network  fold  confid  \
# name
# devries_model_bbvgg16_do0_run0_rew2.2                     0    27      27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...        0    27      27
# devries_model_bbvgg16_do0_run0_rew2.6                     0    27      27
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...        0    27      27
# devries_model_bbvgg16_do0_run0_rew3                       0    27      27
# ...                                                     ...   ...     ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep        0    27      27
# devries_model_bbvgg16_do1_run1_rew6                       0    27      27
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep        0    27      27
# devries_model_bbvgg16_do1_run1_rew8                       0    27      27
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep        0    27      27
#
#                                                     n_test  accuracy  nll  \
# name
# devries_model_bbvgg16_do0_run0_rew2.2                   27        27    3
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...      27        27    3
# devries_model_bbvgg16_do0_run0_rew2.6                   27        27    3
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...      27        27    3
# devries_model_bbvgg16_do0_run0_rew3                     27        27    3
# ...                                                    ...       ...  ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep      27        27    3
# devries_model_bbvgg16_do1_run1_rew6                     27        27    3
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep      27        27    3
# devries_model_bbvgg16_do1_run1_rew8                     27        27    3
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep      27        27    3
#
#                                                     brier_score  failauc  \
# name
# devries_model_bbvgg16_do0_run0_rew2.2                         3       27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...            3       27
# devries_model_bbvgg16_do0_run0_rew2.6                         3       27
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...            3       27
# devries_model_bbvgg16_do0_run0_rew3                           3       27
# ...                                                         ...      ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep            3       27
# devries_model_bbvgg16_do1_run1_rew6                           3       27
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep            3       27
# devries_model_bbvgg16_do1_run1_rew8                           3       27
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep            3       27
#
#                                                     failap_suc  failap_err  \
# name
# devries_model_bbvgg16_do0_run0_rew2.2                       27          27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...          27          27
# devries_model_bbvgg16_do0_run0_rew2.6                       27          27
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...          27          27
# devries_model_bbvgg16_do0_run0_rew3                         27          27
# ...                                                        ...         ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep          27          27
# devries_model_bbvgg16_do1_run1_rew6                         27          27
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep          27          27
# devries_model_bbvgg16_do1_run1_rew8                         27          27
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep          27          27
#
#                                                     mce  ece  e-aurc  aurc  \
# name
# devries_model_bbvgg16_do0_run0_rew2.2                27   27      27    27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...   27   27      27    27
# devries_model_bbvgg16_do0_run0_rew2.6                27   27      27    27
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...   27   27      27    27
# devries_model_bbvgg16_do0_run0_rew3                  27   27      27    27
# ...                                                 ...  ...     ...   ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep   27   27      27    27
# devries_model_bbvgg16_do1_run1_rew6                  27   27      27    27
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep   27   27      27    27
# devries_model_bbvgg16_do1_run1_rew8                  27   27      27    27
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep   27   27      27    27
#
#                                                     fpr@95tpr
# name
# devries_model_bbvgg16_do0_run0_rew2.2                      27
# devries_model_bbvgg16_do0_run0_rew2.2_schedMult...         27
# devries_model_bbvgg16_do0_run0_rew2.6                      27
# devries_model_bbvgg16_do0_run0_rew2.6_schedMult...         27
# devries_model_bbvgg16_do0_run0_rew3                        27
# ...                                                       ...
# devries_model_bbvgg16_do1_run1_rew5_schedMultiStep         27
# devries_model_bbvgg16_do1_run1_rew6                        27
# devries_model_bbvgg16_do1_run1_rew6_schedMultiStep         27
# devries_model_bbvgg16_do1_run1_rew8                        27
# devries_model_bbvgg16_do1_run1_rew8_schedMultiStep         27
#
# [64 rows x 18 columns]

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean
df[:10]
# Out:
#    Unnamed: 0                                 name  \
# 0  0           devries_model_bbvgg16_do1_run0_rew4
# 1  1           devries_model_bbvgg16_do1_run0_rew4
# 2  2           devries_model_bbvgg16_do1_run0_rew4
# 3  0           devries_model_bbvgg16_do1_run0_rew4
# 4  1           devries_model_bbvgg16_do1_run0_rew4
# 5  2           devries_model_bbvgg16_do1_run0_rew4
# 6  0           devries_model_bbvgg16_do1_run0_rew4
# 7  1           devries_model_bbvgg16_do1_run0_rew4
# 8  2           devries_model_bbvgg16_do1_run0_rew4
# 9  0           devries_model_bbvgg16_do1_run0_rew4
#
#                                                study          model  network  \
# 0  iid_study                                          devries_model NaN
# 1  iid_study                                          devries_model NaN
# 2  iid_study                                          devries_model NaN
# 3  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 4  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 5  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 6  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 7  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 8  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 9  new_class_study_tinyimagenet_resize_original_mode  devries_model NaN
#
#    fold   confid  n_test  accuracy      nll  brier_score  failauc  failap_suc  \
# 0  0     det_mcp  9000    0.48056   0.73834  0.54973      0.99439  0.99356
# 1  0     det_pe   9000    0.48056   0.73834  0.54973      0.35733  0.49940
# 2  0     dg       9000    0.48056   0.73834  0.54973      0.99369  0.99322
# 3  0     det_mcp  18000   0.50000  NaN      NaN           0.63863  0.75178
# 4  0     det_pe   18000   0.50000  NaN      NaN           0.58266  0.61934
# 5  0     dg       18000   0.50000  NaN      NaN           0.64882  0.75604
# 6  0     det_mcp  13325   0.32458  NaN      NaN           0.98823  0.97853
# 7  0     det_pe   13325   0.32458  NaN      NaN           0.49465  0.44239
# 8  0     dg       13325   0.32458  NaN      NaN           0.98818  0.97980
# 9  0     det_mcp  18000   0.50000  NaN      NaN           0.62611  0.75057
#
#    failap_err      mce      ece     e-aurc       aurc  fpr@95tpr
# 0  0.99479     0.55973  0.02761  3.35294    170.64030  0.02802
# 1  0.42057     1.00000  0.50576  363.99329  531.28064  0.97390
# 2  0.99412     0.61781  0.02945  3.54264    170.83000  0.02952
# 3  0.54385     0.38911  0.28104  168.27285  321.69926  0.96756
# 4  0.56435     1.00000  0.47668  250.28467  403.71108  0.90433
# 5  0.55541     0.46758  0.28231  164.43330  317.85971  0.96522
# 6  0.99354     0.46060  0.04465  7.87498    318.07243  0.05211
# 7  0.67478     1.00000  0.64619  301.82795  612.02540  0.92322
# 8  0.99348     0.57176  0.04674  7.50084    317.69829  0.04878
# 9  0.52439     0.35423  0.27446  171.03378  324.46019  0.98333

# %%
df = df.dropna(subset=["name"])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)
#df[(df.study.str.contains("tinyimagenet_resize_original")) & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="failauc", ascending=False)
# Out:
# <ipython-input-15-6bbc6dd86d9c>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["model"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["run"] = df.apply(lambda row: row["name"].split("run")[1].split("_")[0] if "run" in row["name"] else "-1", axis=1)
# df["relu"] = df.apply(lambda row: "last" if ("last" in row["name"] or row["backbone"]=="vgg") else "first", axis=1)
# df["reflect"] = df.apply(lambda row: False if ("noreflect" in row["name"] or row["backbone"]=="vgg") else True, axis=1)
df["rew"] = df.apply(lambda row: row["name"].split("_rew")[1].split("_")[0], axis=1)
df["sched"] = df.apply(lambda row: "Multi" if "MultiStep" in row["name"] else "Cosine", axis=1)


# df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)
# df.backbone.tolist()

# %%
non_agg_columns = ["study", "model", "backbone", "rew", "dropout", "sched", "confid"]
import numpy as np
dfg = df.groupby(by=non_agg_columns).mean().reset_index()
dfg_std = df.groupby(by=non_agg_columns).std().reset_index()
rename_dict = {k:"{}_std".format(k) for k in dfg.columns if k not in non_agg_columns }
dfg_std = dfg_std.rename(columns=rename_dict)
print(len(df), len(dfg), len(dfg_std))
print(dfg_std.columns)
print(rename_dict)
# Out:
# 1728 864 864
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std'],
#       dtype='object')
# {'Unnamed: 0': 'Unnamed: 0_std', 'network': 'network_std', 'fold': 'fold_std', 'n_test': 'n_test_std', 'accuracy': 'accuracy_std', 'nll': 'nll_std', 'brier_score': 'brier_score_std', 'failauc': 'failauc_std', 'failap_suc': 'failap_suc_std', 'failap_err': 'failap_err_std', 'mce': 'mce_std', 'ece': 'ece_std', 'e-aurc': 'e-aurc_std', 'aurc': 'aurc_std', 'fpr@95tpr': 'fpr@95tpr_std'}

# %%
study= "iid_study"
data =  dfg[(dfg.study == study)]
data_std =  dfg_std[(dfg_std.study == study)]
# data =  df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]

# %%
plot_data = data[data.dropout=="1"]# & (data["ne"].str.contains("250")) & (data["ap"]==False)]
scale = 5
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=scale * 0.3)
dims = ["confid", "backbone", "dropout", "rew", "sched"]
metrics = ["accuracy", "failauc", "failap_err", "aurc"]

f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data, s = scale*0.8)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=90)
        # if "iid" in study and metric == "aurc":
        #     axs[xix, yix].set_ylim(4, 8)
        # if "iid" in study and metric == "failauc":
        #     axs[xix, yix].set_ylim(0.90, 0.96)
plt.tight_layout()
# plt.savefig("/Users/Paul/research/files/analysis/{}_cifar10.png".format(study))

# %%
std_columns = [c for c in data_std.columns if "std"in c]
for s in std_columns:
    data[s] = data_std[s]

print(data.columns)
print(data_std.columns)
print(len(data))
data[["backbone",  "dropout", "confid", "sched", "rew", "failauc", "failauc_std", "aurc", "aurc_std", "failap_suc", "accuracy", "accuracy_std"]].sort_values(by="aurc", ascending=True)
# Out:
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid',
#        'Unnamed: 0', 'network', 'fold', 'n_test', 'accuracy', 'nll',
#        'brier_score', 'failauc', 'failap_suc', 'failap_err', 'mce', 'ece',
#        'e-aurc', 'aurc', 'fpr@95tpr', 'Unnamed: 0_std', 'network_std',
#        'fold_std', 'n_test_std', 'accuracy_std', 'nll_std', 'brier_score_std',
#        'failauc_std', 'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std',
#        'e-aurc_std', 'aurc_std', 'fpr@95tpr_std'],
#       dtype='object')
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std'],
#       dtype='object')
# 96
# <ipython-input-22-a8e92cfa328f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[s] = data_std[s]
#    backbone dropout   confid   sched  rew   failauc  failauc_std        aurc  \
# 25  vgg16    0       det_pe   Cosine  3    0.932305  0.000544     5.596935
# 24  vgg16    0       det_mcp  Cosine  3    0.934410  0.000099     5.858580
# 26  vgg16    0       dg       Cosine  3    0.927850  0.003295     6.055465
# 40  vgg16    0       det_pe   Multi   3.4  0.928320  0.004059     7.720520
# 28  vgg16    0       det_pe   Multi   3    0.923905  0.001916     7.796450
# 39  vgg16    0       det_mcp  Multi   3.4  0.929735  0.003345     7.830285
# 41  vgg16    0       dg       Multi   3.4  0.924275  0.001605     8.068910
# 16  vgg16    0       det_pe   Multi   2.6  0.923185  0.003161     8.177715
# 29  vgg16    0       dg       Multi   3    0.920700  0.000891     8.193765
# 27  vgg16    0       det_mcp  Multi   3    0.924660  0.002404     8.226905
# 65  vgg16    0       dg       Multi   5    0.919705  0.002397     8.299300
# 15  vgg16    0       det_mcp  Multi   2.6  0.925440  0.003295     8.397855
# 17  vgg16    0       dg       Multi   2.6  0.920015  0.005466     8.408385
# 88  vgg16    0       det_pe   Multi   8    0.920935  0.004023     8.459135
# 5   vgg16    0       dg       Multi   2.2  0.920115  0.005296     8.463835
# 64  vgg16    0       det_pe   Multi   5    0.919370  0.004554     8.481585
# 4   vgg16    0       det_pe   Multi   2.2  0.919615  0.008888     8.560460
# 89  vgg16    0       dg       Multi   8    0.919515  0.000544     8.602270
# 77  vgg16    0       dg       Multi   6    0.920135  0.002425     8.681125
# 3   vgg16    0       det_mcp  Multi   2.2  0.921595  0.007545     8.694450
# 76  vgg16    0       det_pe   Multi   6    0.921835  0.004335     8.731730
# 63  vgg16    0       det_mcp  Multi   5    0.922220  0.004780     8.769125
# 75  vgg16    0       det_mcp  Multi   6    0.924275  0.002835     8.789205
# 87  vgg16    0       det_mcp  Multi   8    0.922900  0.003352     8.810415
# 53  vgg16    0       dg       Multi   4    0.917225  0.008733     8.975340
# 52  vgg16    0       det_pe   Multi   4    0.916965  0.010472     9.034700
# 51  vgg16    0       det_mcp  Multi   4    0.919225  0.010048     9.322025
# 12  vgg16    0       det_mcp  Cosine  2.6  0.956745  0.028291     9.684215
# 0   vgg16    0       det_mcp  Cosine  2.2  0.951775  0.037653     10.094090
# 50  vgg16    0       dg       Cosine  4    0.945350  0.041238     10.220565
# 48  vgg16    0       det_mcp  Cosine  4    0.950045  0.035518     10.265930
# 14  vgg16    0       dg       Cosine  2.6  0.947345  0.038502     10.437045
# 84  vgg16    0       det_mcp  Cosine  8    0.955480  0.026884     10.614530
# 86  vgg16    0       dg       Cosine  8    0.951205  0.028984     10.844540
# 2   vgg16    0       dg       Cosine  2.2  0.943955  0.043353     10.882730
# 34  vgg16    1       det_pe   Multi   3    0.907595  0.001973     10.963820
# 33  vgg16    1       det_mcp  Multi   3    0.912050  0.000778     11.077275
# 94  vgg16    1       det_pe   Multi   8    0.915865  0.005664     11.083055
# 82  vgg16    1       det_pe   Multi   6    0.915720  0.000750     11.125740
# 35  vgg16    1       dg       Multi   3    0.906855  0.000870     11.176975
# 46  vgg16    1       det_pe   Multi   3.4  0.913185  0.001237     11.223400
# 45  vgg16    1       det_mcp  Multi   3.4  0.917920  0.002121     11.361680
# 93  vgg16    1       det_mcp  Multi   8    0.918120  0.006534     11.384360
# 81  vgg16    1       det_mcp  Multi   6    0.918955  0.000346     11.405555
# 59  vgg16    1       dg       Multi   4    0.912485  0.000870     11.530050
# 22  vgg16    1       det_pe   Multi   2.6  0.914840  0.001513     11.535540
# 57  vgg16    1       det_mcp  Multi   4    0.916665  0.000460     11.606060
# 47  vgg16    1       dg       Multi   3.4  0.914140  0.002687     11.628550
# 21  vgg16    1       det_mcp  Multi   2.6  0.918370  0.001570     11.628720
# 58  vgg16    1       det_pe   Multi   4    0.911210  0.001513     11.644755
# 70  vgg16    1       det_pe   Multi   5    0.916325  0.001280     11.655955
# 83  vgg16    1       dg       Multi   6    0.912690  0.001117     11.746325
# 95  vgg16    1       dg       Multi   8    0.911690  0.007311     11.796210
# 69  vgg16    1       det_mcp  Multi   5    0.920145  0.002524     11.811410
# 71  vgg16    1       dg       Multi   5    0.915690  0.003564     11.814910
# 10  vgg16    1       det_pe   Multi   2.2  0.913010  0.003253     11.851970
# 23  vgg16    1       dg       Multi   2.6  0.913225  0.003302     11.948460
# 9   vgg16    1       det_mcp  Multi   2.2  0.914370  0.005911     12.271930
# 11  vgg16    1       dg       Multi   2.2  0.909175  0.007007     12.488390
# 30  vgg16    1       det_mcp  Cosine  3    0.968625  0.000304     17.693820
# 32  vgg16    1       dg       Cosine  3    0.964740  0.001032     18.237205
# 36  vgg16    0       det_mcp  Cosine  3.4  0.960995  0.034966     18.547035
# 38  vgg16    0       dg       Cosine  3.4  0.957960  0.037745     18.766970
# 90  vgg16    1       det_mcp  Cosine  8    0.972455  0.006880     26.296975
# 92  vgg16    1       dg       Cosine  8    0.969610  0.007283     26.781795
# 1   vgg16    0       det_pe   Cosine  2.2  0.815880  0.151250     43.056310
# 49  vgg16    0       det_pe   Cosine  4    0.792640  0.186704     49.853075
# 6   vgg16    1       det_mcp  Cosine  2.2  0.982310  0.005968     50.529555
# 8   vgg16    1       dg       Cosine  2.2  0.980645  0.006399     50.778660
# 85  vgg16    0       det_pe   Cosine  8    0.783735  0.212365     53.897880
# 60  vgg16    0       det_mcp  Cosine  5    0.963115  0.044682     55.505910
# 62  vgg16    0       dg       Cosine  5    0.958410  0.049130     55.814335
# 72  vgg16    0       det_mcp  Cosine  6    0.960540  0.040956     56.643505
# 74  vgg16    0       dg       Cosine  6    0.957280  0.043982     56.781860
# 13  vgg16    0       det_pe   Cosine  2.6  0.796015  0.198506     57.309430
# 18  vgg16    1       det_mcp  Cosine  2.6  0.979810  0.005105     74.859150
# 20  vgg16    1       dg       Cosine  2.6  0.977435  0.005523     75.270820
# 42  vgg16    1       det_mcp  Cosine  3.4  0.988970  0.002461     86.635030
# 44  vgg16    1       dg       Cosine  3.4  0.987750  0.002758     86.972900
# 78  vgg16    1       det_mcp  Cosine  6    0.987290  0.005374     88.268505
# 80  vgg16    1       dg       Cosine  6    0.985665  0.005537     88.655215
# 31  vgg16    1       det_pe   Cosine  3    0.630945  0.035716     106.478805
# 66  vgg16    1       det_mcp  Cosine  5    0.990340  0.000721     109.167630
