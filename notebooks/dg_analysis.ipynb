# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/dg_sweep_final.csv"
df = pd.read_csv(in_path)

# %%
len(df)
# Out:
# 1296

# %%
df.groupby("study").count()
df = df.drop(df[df.model=="mcd_sv"].index)
print(len(df))
# Out:
# 1296

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"])

# %%
len(df_clean)
# Out:
# 1296

# %%
df_clean.groupby("name").count()
# Out:
#                                                                     Unnamed: 0  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     study  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     model  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     network  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   0
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    0
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         0
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          0
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  0
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        0
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    0
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          0
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           0
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   0
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    0
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         0
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          0
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  0
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        0
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    0
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          0
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           0
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   0
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    0
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         0
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          0
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  0
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        0
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    0
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          0
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           0
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   0
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    0
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         0
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          0
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  0
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   0
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        0
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         0
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    0
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     0
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          0
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           0
#
#                                                                     fold  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     confid  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     n_test  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     accuracy  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     nll  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           3
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           3
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           3
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           3
#
#                                                                     brier_score  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           3
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           3
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           3
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   3
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    3
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         3
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        3
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         3
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    3
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     3
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          3
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           3
#
#                                                                     failauc  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     failap_suc  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     failap_err  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# ...
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     risk@85cov  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     risk@80cov  \
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27
#
#                                                                     risk@75cov
# name
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do0_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do0_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do0_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do0_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run0_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run0_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run0_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run0_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run0_rew6_schedMultiStep_coTrue           27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coFalse   27
# devries_model_bbdgvgg_do1_run1_rew-1_schedCosineAnnealing_coTrue    27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coFalse         27
# devries_model_bbdgvgg_do1_run1_rew-1_schedMultiStep_coTrue          27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coFalse  27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedCosineAnnealing_coTrue   27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coFalse        27
# devries_model_bbdgvgg_do1_run1_rew2.2_schedMultiStep_coTrue         27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coFalse    27
# devries_model_bbdgvgg_do1_run1_rew6_schedCosineAnnealing_coTrue     27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coFalse          27
# devries_model_bbdgvgg_do1_run1_rew6_schedMultiStep_coTrue           27

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr, risk@100cov, risk@95cov, risk@90cov, risk@85cov, risk@80cov, risk@75cov]
# Index: []

# %%
df = df_clean
df[:10]
# Out:
#    Unnamed: 0                                                        name  \
# 0  0           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 1  1           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 2  2           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 3  0           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 4  1           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 5  2           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 6  0           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 7  1           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 8  2           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
# 9  0           devries_model_bbdgvgg_do0_run1_rew6_schedMultiStep_coFalse
#
#                                                study          model  network  \
# 0  iid_study                                          devries_model NaN
# 1  iid_study                                          devries_model NaN
# 2  iid_study                                          devries_model NaN
# 3  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 4  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 5  new_class_study_tinyimagenet_original_mode         devries_model NaN
# 6  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 7  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 8  new_class_study_tinyimagenet_proposed_mode         devries_model NaN
# 9  new_class_study_tinyimagenet_resize_original_mode  devries_model NaN
#
#    fold   confid  n_test  accuracy     nll  brier_score  failauc  failap_suc  \
# 0  0     det_mcp  9000    0.93689   0.0332  0.11233      0.85210  0.98188
# 1  0     det_pe   9000    0.93689   0.0332  0.11233      0.84787  0.97870
# 2  0     dg       9000    0.93689   0.0332  0.11233      0.81535  0.97530
# 3  0     det_mcp  18000   0.50000  NaN     NaN           0.85073  0.79575
# 4  0     det_pe   18000   0.50000  NaN     NaN           0.84700  0.74452
# 5  0     dg       18000   0.50000  NaN     NaN           0.85442  0.78914
# 6  0     det_mcp  17432   0.48371  NaN     NaN           0.87006  0.80012
# 7  0     det_pe   17432   0.48371  NaN     NaN           0.86535  0.74516
# 8  0     dg       17432   0.48371  NaN     NaN           0.87009  0.79038
# 9  0     det_mcp  18000   0.50000  NaN     NaN           0.80115  0.73824
#
#    failap_err      mce      ece     e-aurc       aurc  fpr@95tpr  risk@100cov  \
# 0  0.39003     0.61507  0.04889  17.18357   19.21835   0.40845    6.31111
# 1  0.40939     1.00000  0.03839  20.24861   22.28339   0.40845    6.31111
# 2  0.37787     0.06264  0.06264  23.47411   25.50888   0.42254    6.31111
# 3  0.85130     0.80378  0.41856  121.06813  274.49454  0.51289    50.00000
# 4  0.86675     0.78365  0.38371  155.95452  309.38093  0.50300    50.00000
# 5  0.87567     0.94389  0.49758  119.59815  273.02456  0.44900    50.00000
# 6  0.88690     0.85078  0.43566  114.41054  279.39798  0.32256    51.62919
# 7  0.90016     0.83393  0.40097  150.82241  315.80984  0.32267    51.62919
# 8  0.90267     0.94389  0.51386  114.66478  279.65221  0.30144    51.62919
# 9  0.81042     0.79430  0.43300  163.95201  317.37842  0.59278    50.00000
#
#    risk@95cov  risk@90cov  risk@85cov  risk@80cov  risk@75cov
# 0  4.02198     2.55178     1.90992     1.64598     1.64598
# 1  4.04442     2.54258     1.82887     1.55884     1.50739
# 2  4.16326     2.67472     2.23871     2.21885     2.20447
# 3  47.61710    45.25088    42.59477    39.63758    36.34276
# 4  47.52632    44.90249    42.35117    39.53618    36.25185
# 5  47.46784    44.77160    41.90850    38.85417    35.54815
# 6  49.19993    46.67602    43.77109    40.62231    37.08037
# 7  49.13658    46.43722    43.67746    40.57348    37.03732
# 8  49.12143    46.38919    43.42016    40.17639    36.64525
# 9  47.78668    45.50000    42.88048    40.19295    37.16126

# %%
df = df.dropna(subset=["name"])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)
#df[(df.study.str.contains("tinyimagenet_resize_original")) & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="failauc", ascending=False)
# Out:
# <ipython-input-35-6bbc6dd86d9c>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["model"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["run"] = df.apply(lambda row: row["name"].split("run")[1].split("_")[0] if "run" in row["name"] else "-1", axis=1)
# df["relu"] = df.apply(lambda row: "last" if ("last" in row["name"] or row["backbone"]=="vgg") else "first", axis=1)
# df["reflect"] = df.apply(lambda row: False if ("noreflect" in row["name"] or row["backbone"]=="vgg") else True, axis=1)
df["rew"] = df.apply(lambda row: row["name"].split("_rew")[1].split("_")[0], axis=1)
df["sched"] = df.apply(lambda row: "Multi" if "MultiStep" in row["name"] else "Cosine", axis=1)
df["co"] = df.apply(lambda row: True if "coTrue" in row["name"] else False, axis=1)


# df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)
# df.backbone.tolist()

# %%
non_agg_columns = ["study", "model", "backbone", "rew", "dropout", "sched", "confid", "co"]
import numpy as np
dfg = df.groupby(by=non_agg_columns).mean().reset_index()
dfg_std = df.groupby(by=non_agg_columns).std().reset_index()
rename_dict = {k:"{}_std".format(k) for k in dfg.columns if k not in non_agg_columns }
dfg_std = dfg_std.rename(columns=rename_dict)
print(len(df), len(dfg), len(dfg_std))
print(dfg_std.columns)
print(rename_dict)
# Out:
# 1296 648 648
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid', 'co',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std', 'risk@100cov_std', 'risk@95cov_std',
#        'risk@90cov_std', 'risk@85cov_std', 'risk@80cov_std', 'risk@75cov_std'],
#       dtype='object')
# {'Unnamed: 0': 'Unnamed: 0_std', 'network': 'network_std', 'fold': 'fold_std', 'n_test': 'n_test_std', 'accuracy': 'accuracy_std', 'nll': 'nll_std', 'brier_score': 'brier_score_std', 'failauc': 'failauc_std', 'failap_suc': 'failap_suc_std', 'failap_err': 'failap_err_std', 'mce': 'mce_std', 'ece': 'ece_std', 'e-aurc': 'e-aurc_std', 'aurc': 'aurc_std', 'fpr@95tpr': 'fpr@95tpr_std', 'risk@100cov': 'risk@100cov_std', 'risk@95cov': 'risk@95cov_std', 'risk@90cov': 'risk@90cov_std', 'risk@85cov': 'risk@85cov_std', 'risk@80cov': 'risk@80cov_std', 'risk@75cov': 'risk@75cov_std'}

# %%
study= "iid_study"
select = (dfg.study == study) & (dfg.co == False)
data =  dfg[select]
data_std =  dfg_std[select]
# data =  df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]

# %%
plot_data = data# [data.dropout=="1"]# & (data["ne"].str.contains("250")) & (data["ap"]==False)]
scale = 5
sns.set_style("whitegrid")
sns.set_context("paper", font_scale=scale * 0.3)
dims = ["confid", "backbone", "dropout", "rew", "sched", "co"]
metrics = ["accuracy", "failauc", "failap_err", "aurc"]

f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data, s = scale*0.8)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=plot_data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=90)
        # if "iid" in study and metric == "aurc":
        #     axs[xix, yix].set_ylim(4, 8)
        # if "iid" in study and metric == "failauc":
        #     axs[xix, yix].set_ylim(0.90, 0.96)
plt.tight_layout()
# plt.savefig("/Users/Paul/research/files/analysis/{}_cifar10.png".format(study))

# %%
std_columns = [c for c in data_std.columns if "std"in c]
for s in std_columns:
    data[s] = data_std[s]

print(data.columns)
print(data_std.columns)
print(len(data))
data[["backbone",  "dropout", "co", "confid", "sched", "rew", "failauc", "failauc_std", "aurc", "aurc_std", "failap_suc", "accuracy", "accuracy_std", "risk@100cov", "risk@95cov", "risk@90cov", "risk@85cov", "risk@80cov"]].sort_values(by="aurc", ascending=True)
# Out:
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid', 'co',
#        'Unnamed: 0', 'network', 'fold', 'n_test', 'accuracy', 'nll',
#        'brier_score', 'failauc', 'failap_suc', 'failap_err', 'mce', 'ece',
#        'e-aurc', 'aurc', 'fpr@95tpr', 'risk@100cov', 'risk@95cov',
#        'risk@90cov', 'risk@85cov', 'risk@80cov', 'risk@75cov',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std', 'risk@100cov_std', 'risk@95cov_std',
#        'risk@90cov_std', 'risk@85cov_std', 'risk@80cov_std', 'risk@75cov_std'],
#       dtype='object')
# Index(['study', 'model', 'backbone', 'rew', 'dropout', 'sched', 'confid', 'co',
#        'Unnamed: 0_std', 'network_std', 'fold_std', 'n_test_std',
#        'accuracy_std', 'nll_std', 'brier_score_std', 'failauc_std',
#        'failap_suc_std', 'failap_err_std', 'mce_std', 'ece_std', 'e-aurc_std',
#        'aurc_std', 'fpr@95tpr_std', 'risk@100cov_std', 'risk@95cov_std',
#        'risk@90cov_std', 'risk@85cov_std', 'risk@80cov_std', 'risk@75cov_std'],
#       dtype='object')
# 36
# <ipython-input-47-fdb73b525ac7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[s] = data_std[s]
#    backbone dropout     co   confid   sched  rew   failauc  failauc_std  \
# 62  dgvgg    1       False  det_pe   Cosine  6    0.937960  0.005035
# 38  dgvgg    1       False  det_pe   Cosine  2.2  0.941485  0.004858
# 14  dgvgg    1       False  det_pe   Cosine  -1   0.934665  0.000460
# 36  dgvgg    1       False  det_mcp  Cosine  2.2  0.940980  0.004398
# 60  dgvgg    1       False  det_mcp  Cosine  6    0.937070  0.005558
# 12  dgvgg    1       False  det_mcp  Cosine  -1   0.933955  0.000205
# 40  dgvgg    1       False  dg       Cosine  2.2  0.931830  0.004398
# 20  dgvgg    1       False  det_pe   Multi   -1   0.935755  0.002114
# 64  dgvgg    1       False  dg       Cosine  6    0.925650  0.004412
# 18  dgvgg    1       False  det_mcp  Multi   -1   0.934695  0.002821
# 68  dgvgg    1       False  det_pe   Multi   6    0.933520  0.002093
# 16  dgvgg    1       False  dg       Cosine  -1   0.922700  0.001796
# 66  dgvgg    1       False  det_mcp  Multi   6    0.932685  0.001054
# 44  dgvgg    1       False  det_pe   Multi   2.2  0.929440  0.000000
# 42  dgvgg    1       False  det_mcp  Multi   2.2  0.928840  0.000269
# 22  dgvgg    1       False  dg       Multi   -1   0.919500  0.002729
# 70  dgvgg    1       False  dg       Multi   6    0.914180  0.004356
# 46  dgvgg    1       False  dg       Multi   2.2  0.907740  0.001768
# 0   dgvgg    0       False  det_mcp  Cosine  -1   0.877445  0.010076
# 48  dgvgg    0       False  det_mcp  Cosine  6    0.869635  0.009935
# 24  dgvgg    0       False  det_mcp  Cosine  2.2  0.870920  0.002234
# 26  dgvgg    0       False  det_pe   Cosine  2.2  0.871635  0.004914
# 50  dgvgg    0       False  det_pe   Cosine  6    0.870580  0.007623
# 2   dgvgg    0       False  det_pe   Cosine  -1   0.876770  0.009108
# 30  dgvgg    0       False  det_mcp  Multi   2.2  0.853375  0.005070
# 54  dgvgg    0       False  det_mcp  Multi   6    0.844955  0.010105
# 6   dgvgg    0       False  det_mcp  Multi   -1   0.842765  0.012792
# 32  dgvgg    0       False  det_pe   Multi   2.2  0.850355  0.004547
# 4   dgvgg    0       False  dg       Cosine  -1   0.829940  0.018767
# 8   dgvgg    0       False  det_pe   Multi   -1   0.841280  0.011795
# 52  dgvgg    0       False  dg       Cosine  6    0.828625  0.004363
# 56  dgvgg    0       False  det_pe   Multi   6    0.838845  0.012763
# 28  dgvgg    0       False  dg       Cosine  2.2  0.825890  0.005035
# 34  dgvgg    0       False  dg       Multi   2.2  0.818925  0.026014
# 58  dgvgg    0       False  dg       Multi   6    0.806455  0.012579
# 10  dgvgg    0       False  dg       Multi   -1   0.808145  0.020372
#
#          aurc  aurc_std  failap_suc  accuracy  accuracy_std  risk@100cov  \
# 62  5.916035   0.110302  0.995715    0.940110  0.002517      5.988890
# 38  5.934490   0.078531  0.995760    0.939000  0.002362      6.100000
# 14  6.002290   0.054518  0.995515    0.941835  0.000389      5.816665
# 36  6.133025   0.008761  0.995550    0.939000  0.002362      6.100000
# 60  6.206500   0.193634  0.995410    0.940110  0.002517      5.988890
# 12  6.260595   0.168680  0.995245    0.941835  0.000389      5.816665
# 40  6.591375   0.032506  0.995075    0.939000  0.002362      6.100000
# 20  6.706640   0.548503  0.994900    0.939615  0.000078      6.038885
# 64  6.792485   0.083516  0.994795    0.940110  0.002517      5.988890
# 18  6.900780   0.381597  0.994695    0.939615  0.000078      6.038885
# 68  6.920095   0.157777  0.994680    0.939610  0.000396      6.038890
# 16  6.954255   0.001902  0.994520    0.941835  0.000389      5.816665
# 66  7.085815   0.153308  0.994505    0.939610  0.000396      6.038890
# 44  7.176160   0.655403  0.994360    0.940330  0.001570      5.966670
# 42  7.481640   0.559915  0.994045    0.940330  0.001570      5.966670
# 22  8.540180   0.693078  0.992970    0.939615  0.000078      6.038885
# 70  8.771865   0.624057  0.992720    0.939610  0.000396      6.038890
# 46  9.652445   1.370182  0.991745    0.940330  0.001570      5.966670
