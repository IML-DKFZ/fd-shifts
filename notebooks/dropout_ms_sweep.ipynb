# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/dropout_ms_sweep.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0                                                     2
# name              confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue
# study          new_class_study_tinyimagenet_resize_proposed_mode
# model                                            confidnet_model
# network                                                    vgg13
# fold                                                           0
# confid                                                       tcp
# n_test                                                     17528
# accuracy                                                 0.48654
# nll                                                          NaN
# brier_score                                                  NaN
# failauc                                                   0.9568
# failap_suc                                               0.95918
# failap_err                                               0.95358
# mce                                                      0.73072
# ece                                                      0.31276
# e-aurc                                                   22.2624
# aurc                                                     185.204
# fpr@95tpr                                                0.26978
# Name: 291, dtype: object

# %%
len(df)
# Out:
# 292

# %%
df.groupby("study").count()
# Out:
#                                                    Unnamed: 0  name  model  \
# study
# iid_study                                                  68    68     68
# new_class_study_tinyimagenet_original_mode                 56    56     56
# new_class_study_tinyimagenet_proposed_mode                 56    56     56
# new_class_study_tinyimagenet_resize_original_mode          56    56     56
# new_class_study_tinyimagenet_resize_proposed_mode          56    56     56
#
#                                                    network  fold  confid  \
# study
# iid_study                                               68    68      68
# new_class_study_tinyimagenet_original_mode              56    56      56
# new_class_study_tinyimagenet_proposed_mode              56    56      56
# new_class_study_tinyimagenet_resize_original_mode       56    56      56
# new_class_study_tinyimagenet_resize_proposed_mode       56    56      56
#
#                                                    n_test  accuracy  nll  \
# study
# iid_study                                              68        68   68
# new_class_study_tinyimagenet_original_mode             56        56    0
# new_class_study_tinyimagenet_proposed_mode             56        56    0
# new_class_study_tinyimagenet_resize_original_mode      56        56    0
# new_class_study_tinyimagenet_resize_proposed_mode      56        56    0
#
#                                                    brier_score  failauc  \
# study
# iid_study                                                   68       68
# new_class_study_tinyimagenet_original_mode                   0       56
# new_class_study_tinyimagenet_proposed_mode                   0       56
# new_class_study_tinyimagenet_resize_original_mode            0       56
# new_class_study_tinyimagenet_resize_proposed_mode            0       56
#
#                                                    failap_suc  failap_err  \
# study
# iid_study                                                  68          68
# new_class_study_tinyimagenet_original_mode                 56          56
# new_class_study_tinyimagenet_proposed_mode                 56          56
# new_class_study_tinyimagenet_resize_original_mode          56          56
# new_class_study_tinyimagenet_resize_proposed_mode          56          56
#
#                                                    mce  ece  e-aurc  aurc  \
# study
# iid_study                                           68   68      68    68
# new_class_study_tinyimagenet_original_mode          56   56      56    56
# new_class_study_tinyimagenet_proposed_mode          56   56      56    56
# new_class_study_tinyimagenet_resize_original_mode   56   56      56    56
# new_class_study_tinyimagenet_resize_proposed_mode   56   56      56    56
#
#                                                    fpr@95tpr
# study
# iid_study                                                 68
# new_class_study_tinyimagenet_original_mode                56
# new_class_study_tinyimagenet_proposed_mode                56
# new_class_study_tinyimagenet_resize_original_mode         56
# new_class_study_tinyimagenet_resize_proposed_mode         56

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"], keep="last")

# %%
len(df_clean)
# Out:
# 280

# %%
df_clean.groupby("name").count()
# Out:
#                                                  Unnamed: 0  study  model  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse          15     15     15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue           15     15     15
# confidnet_model_bbvgg13_do1_avgpoolFalse                 55     55     55
# confidnet_model_bbvgg13_do1_avgpoolTrue                  55     55     55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse          15     15     15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue           15     15     15
# confidnet_model_bbvgg16_do1_avgpoolFalse                 55     55     55
# confidnet_model_bbvgg16_do1_avgpoolTrue                  55     55     55
#
#                                                  network  fold  confid  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse       15    15      15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue        15    15      15
# confidnet_model_bbvgg13_do1_avgpoolFalse              55    55      55
# confidnet_model_bbvgg13_do1_avgpoolTrue               55    55      55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse       15    15      15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue        15    15      15
# confidnet_model_bbvgg16_do1_avgpoolFalse              55    55      55
# confidnet_model_bbvgg16_do1_avgpoolTrue               55    55      55
#
#                                                  n_test  accuracy  nll  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse      15        15    3
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue       15        15    3
# confidnet_model_bbvgg13_do1_avgpoolFalse             55        55   11
# confidnet_model_bbvgg13_do1_avgpoolTrue              55        55   11
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse      15        15    3
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue       15        15    3
# confidnet_model_bbvgg16_do1_avgpoolFalse             55        55   11
# confidnet_model_bbvgg16_do1_avgpoolTrue              55        55   11
#
#                                                  brier_score  failauc  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse            3       15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue             3       15
# confidnet_model_bbvgg13_do1_avgpoolFalse                  11       55
# confidnet_model_bbvgg13_do1_avgpoolTrue                   11       55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse            3       15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue             3       15
# confidnet_model_bbvgg16_do1_avgpoolFalse                  11       55
# confidnet_model_bbvgg16_do1_avgpoolTrue                   11       55
#
#                                                  failap_suc  failap_err  mce  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse          15          15   15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue           15          15   15
# confidnet_model_bbvgg13_do1_avgpoolFalse                 55          55   55
# confidnet_model_bbvgg13_do1_avgpoolTrue                  55          55   55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse          15          15   15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue           15          15   15
# confidnet_model_bbvgg16_do1_avgpoolFalse                 55          55   55
# confidnet_model_bbvgg16_do1_avgpoolTrue                  55          55   55
#
#                                                  ece  e-aurc  aurc  fpr@95tpr
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse   15      15    15         15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue    15      15    15         15
# confidnet_model_bbvgg13_do1_avgpoolFalse          55      55    55         55
# confidnet_model_bbvgg13_do1_avgpoolTrue           55      55    55         55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse   15      15    15         15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue    15      15    15         15
# confidnet_model_bbvgg16_do1_avgpoolFalse          55      55    55         55
# confidnet_model_bbvgg16_do1_avgpoolTrue           55      55    55         55

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-11-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                 name    confid  accuracy  \
# 237  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   tcp       0.95022
# 236  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   det_pe    0.95022
# 245  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  det_pe    0.94944
# 246  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  tcp       0.94944
# 235  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   det_mcp   0.95022
# 248  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   det_pe    0.94756
# 247  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   det_mcp   0.94756
# 244  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  det_mcp   0.94944
# 249  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   tcp       0.94756
# 233  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  det_pe    0.94989
# 234  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  tcp       0.94989
# 232  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  det_mcp   0.94989
# 125  confidnet_model_bbvgg16_do1_avgpoolTrue          tcp_mcd   0.93789
# 127  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_mcp   0.93789
# 126  confidnet_model_bbvgg16_do1_avgpoolTrue          tcp_waic  0.93789
# 11   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_mcp   0.93178
# 129  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_ee    0.93789
# 128  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_pe    0.93789
# 55   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_mcp   0.93511
# 182  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_mcp   0.93367
# 53   confidnet_model_bbvgg13_do1_avgpoolTrue          tcp_mcd   0.93511
# 131  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_sv    0.93789
# 57   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_ee    0.93511
# 187  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_waic  0.93367
# 54   confidnet_model_bbvgg13_do1_avgpoolTrue          tcp_waic  0.93511
# 56   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_pe    0.93511
# 180  confidnet_model_bbvgg16_do1_avgpoolFalse         tcp_mcd   0.93367
# 9    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp_mcd   0.93178
# 16   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_waic  0.93178
# 12   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_pe    0.93178
# 130  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_mi    0.93789
# 184  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_ee    0.93367
# 181  confidnet_model_bbvgg16_do1_avgpoolFalse         tcp_waic  0.93367
# 15   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_sv    0.93178
# 183  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_pe    0.93367
# 132  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_waic  0.93789
# 13   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_ee    0.93178
# 10   confidnet_model_bbvgg13_do1_avgpoolFalse         tcp_waic  0.93178
# 59   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_sv    0.93511
# 186  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_sv    0.93367
# 14   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_mi    0.93178
# 58   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_mi    0.93511
# 185  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_mi    0.93367
# 60   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_waic  0.93511
# 8    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp       0.91289
# 6    confidnet_model_bbvgg13_do1_avgpoolFalse         det_mcp   0.91289
# 124  confidnet_model_bbvgg16_do1_avgpoolTrue          tcp       0.91189
# 50   confidnet_model_bbvgg13_do1_avgpoolTrue          det_mcp   0.91289
# 122  confidnet_model_bbvgg16_do1_avgpoolTrue          det_mcp   0.91189
# 52   confidnet_model_bbvgg13_do1_avgpoolTrue          tcp       0.91289
# 7    confidnet_model_bbvgg13_do1_avgpoolFalse         det_pe    0.91289
# 51   confidnet_model_bbvgg13_do1_avgpoolTrue          det_pe    0.91289
# 179  confidnet_model_bbvgg16_do1_avgpoolFalse         tcp       0.90622
# 177  confidnet_model_bbvgg16_do1_avgpoolFalse         det_mcp   0.90622
# 123  confidnet_model_bbvgg16_do1_avgpoolTrue          det_pe    0.91189
# 178  confidnet_model_bbvgg16_do1_avgpoolFalse         det_pe    0.90622
#
#      failauc  failap_err      aurc
# 237  0.94150  0.45482     4.79812
# 236  0.93818  0.44359     4.92336
# 245  0.93646  0.47870     5.09874
# 246  0.93758  0.47547     5.16359
# 235  0.93752  0.42281     5.19562
# 248  0.93834  0.45444     5.25734
# 247  0.93849  0.44788     5.34716
# 244  0.93647  0.47887     5.49533
# 249  0.93421  0.46062     5.68965
# 233  0.93406  0.48990     5.72371
# 234  0.93299  0.48524     5.83870
# 232  0.93385  0.47886     5.89735
# 125  0.92642  0.39755     6.98906
# 127  0.92812  0.42138     7.00819
# 126  0.92414  0.38140     7.09145
# 11   0.93463  0.48198     7.30878
# 129  0.92290  0.37968     7.35932
# 128  0.92251  0.37507     7.38149
# 55   0.92682  0.45406     7.42835
# 182  0.92895  0.44376     7.61085
# 53   0.92319  0.41852     7.67038
# 131  0.91685  0.33842     7.72964
# 57   0.92100  0.39861     7.80913
# 187  0.92611  0.43475     7.87020
# 54   0.92014  0.39296     7.88683
# 56   0.91991  0.39958     7.88897
# 180  0.92475  0.39296     7.90572
# 9    0.92735  0.43873     7.92765
# 16   0.92534  0.46132     8.04908
# 12   0.92423  0.41031     8.04951
# 130  0.91235  0.33923     8.05312
# 184  0.92212  0.38525     8.07725
# 181  0.92231  0.37888     8.07832
# 15   0.92354  0.39429     8.08201
# 183  0.92183  0.39978     8.10400
# 132  0.91447  0.39107     8.12612
# 13   0.92286  0.40096     8.15796
# 10   0.92345  0.41574     8.21678
# 59   0.91353  0.35560     8.36695
# 186  0.91640  0.38080     8.50329
# 14   0.91633  0.38569     8.62562
# 58   0.90848  0.35966     8.72241
# 185  0.91041  0.38820     8.96107
# 60   0.90157  0.38722     9.44137
# 8    0.91861  0.47638     11.78997
# 6    0.91834  0.47373     11.83836
# 124  0.91694  0.46536     12.14401
# 50   0.91519  0.47308     12.20614
# 122  0.91649  0.47466     12.25061
# 52   0.91378  0.46474     12.32789
# 7    0.91054  0.45169     12.57697
# 51   0.90907  0.43793     12.77597
# 179  0.92198  0.53581     12.89126
# 177  0.91983  0.52404     13.06707
# 123  0.90771  0.42465     13.08168
# 178  0.91561  0.48719     13.47560

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["pure_det"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["avg_pool"] = df.apply(lambda row: True if "avgpoolTrue" in row["name"] else False, axis=1)
df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)

# %%
data =  df[(df.study == "iid_study") ]
# data =  df[(df.study == "new_class_study_tinyimagenet_original_mode") ]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
dims = ["confid", "backbone", "dropout", "avg_pool", "ms"]
metrics = ["accuracy", "failauc", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()

# %%
data[["name", "confid", "failauc", "failap_err", "aurc", "accuracy"]].sort_values(by="aurc", ascending=True)
# Out:
#                                                 name    confid  failauc  \
# 237  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   tcp       0.94150
# 236  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   det_pe    0.93818
# 245  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  det_pe    0.93646
# 246  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  tcp       0.93758
# 235  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   det_mcp   0.93752
# 248  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   det_pe    0.93834
# 247  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   det_mcp   0.93849
# 244  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  det_mcp   0.93647
# 249  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   tcp       0.93421
# 233  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  det_pe    0.93406
# 234  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  tcp       0.93299
# 232  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  det_mcp   0.93385
# 125  confidnet_model_bbvgg16_do1_avgpoolTrue          tcp_mcd   0.92642
# 127  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_mcp   0.92812
# 126  confidnet_model_bbvgg16_do1_avgpoolTrue          tcp_waic  0.92414
# 11   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_mcp   0.93463
# 129  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_ee    0.92290
# 128  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_pe    0.92251
# 55   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_mcp   0.92682
# 182  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_mcp   0.92895
# 53   confidnet_model_bbvgg13_do1_avgpoolTrue          tcp_mcd   0.92319
# 131  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_sv    0.91685
# 57   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_ee    0.92100
# 187  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_waic  0.92611
# 54   confidnet_model_bbvgg13_do1_avgpoolTrue          tcp_waic  0.92014
# 56   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_pe    0.91991
# 180  confidnet_model_bbvgg16_do1_avgpoolFalse         tcp_mcd   0.92475
# 9    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp_mcd   0.92735
# 16   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_waic  0.92534
# 12   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_pe    0.92423
# 130  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_mi    0.91235
# 184  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_ee    0.92212
# 181  confidnet_model_bbvgg16_do1_avgpoolFalse         tcp_waic  0.92231
# 15   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_sv    0.92354
# 183  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_pe    0.92183
# 132  confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_waic  0.91447
# 13   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_ee    0.92286
# 10   confidnet_model_bbvgg13_do1_avgpoolFalse         tcp_waic  0.92345
# 59   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_sv    0.91353
# 186  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_sv    0.91640
# 14   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_mi    0.91633
# 58   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_mi    0.90848
# 185  confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_mi    0.91041
# 60   confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_waic  0.90157
# 8    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp       0.91861
# 6    confidnet_model_bbvgg13_do1_avgpoolFalse         det_mcp   0.91834
# 124  confidnet_model_bbvgg16_do1_avgpoolTrue          tcp       0.91694
# 50   confidnet_model_bbvgg13_do1_avgpoolTrue          det_mcp   0.91519
# 122  confidnet_model_bbvgg16_do1_avgpoolTrue          det_mcp   0.91649
# 52   confidnet_model_bbvgg13_do1_avgpoolTrue          tcp       0.91378
# 7    confidnet_model_bbvgg13_do1_avgpoolFalse         det_pe    0.91054
# 51   confidnet_model_bbvgg13_do1_avgpoolTrue          det_pe    0.90907
# 179  confidnet_model_bbvgg16_do1_avgpoolFalse         tcp       0.92198
# 177  confidnet_model_bbvgg16_do1_avgpoolFalse         det_mcp   0.91983
# 123  confidnet_model_bbvgg16_do1_avgpoolTrue          det_pe    0.90771
# 178  confidnet_model_bbvgg16_do1_avgpoolFalse         det_pe    0.91561
#
#      failap_err      aurc  accuracy
# 237  0.45482     4.79812   0.95022
# 236  0.44359     4.92336   0.95022
# 245  0.47870     5.09874   0.94944
# 246  0.47547     5.16359   0.94944
# 235  0.42281     5.19562   0.95022
# 248  0.45444     5.25734   0.94756
# 247  0.44788     5.34716   0.94756
# 244  0.47887     5.49533   0.94944
# 249  0.46062     5.68965   0.94756
# 233  0.48990     5.72371   0.94989
# 234  0.48524     5.83870   0.94989
# 232  0.47886     5.89735   0.94989
# 125  0.39755     6.98906   0.93789
# 127  0.42138     7.00819   0.93789
# 126  0.38140     7.09145   0.93789
# 11   0.48198     7.30878   0.93178
# 129  0.37968     7.35932   0.93789
# 128  0.37507     7.38149   0.93789
# 55   0.45406     7.42835   0.93511
# 182  0.44376     7.61085   0.93367
# 53   0.41852     7.67038   0.93511
# 131  0.33842     7.72964   0.93789
# 57   0.39861     7.80913   0.93511
# 187  0.43475     7.87020   0.93367
# 54   0.39296     7.88683   0.93511
# 56   0.39958     7.88897   0.93511
# 180  0.39296     7.90572   0.93367
# 9    0.43873     7.92765   0.93178
# 16   0.46132     8.04908   0.93178
# 12   0.41031     8.04951   0.93178
# 130  0.33923     8.05312   0.93789
# 184  0.38525     8.07725   0.93367
# 181  0.37888     8.07832   0.93367
# 15   0.39429     8.08201   0.93178
# 183  0.39978     8.10400   0.93367
# 132  0.39107     8.12612   0.93789
# 13   0.40096     8.15796   0.93178
# 10   0.41574     8.21678   0.93178
# 59   0.35560     8.36695   0.93511
# 186  0.38080     8.50329   0.93367
# 14   0.38569     8.62562   0.93178
# 58   0.35966     8.72241   0.93511
# 185  0.38820     8.96107   0.93367
# 60   0.38722     9.44137   0.93511
# 8    0.47638     11.78997  0.91289
# 6    0.47373     11.83836  0.91289
# 124  0.46536     12.14401  0.91189
# 50   0.47308     12.20614  0.91289
# 122  0.47466     12.25061  0.91189
# 52   0.46474     12.32789  0.91289
# 7    0.45169     12.57697  0.91289
# 51   0.43793     12.77597  0.91289
# 179  0.53581     12.89126  0.90622
# 177  0.52404     13.06707  0.90622
# 123  0.42465     13.08168  0.91189
# 178  0.48719     13.47560  0.90622

# %%
sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")  & (df.confid=="devries")].name
