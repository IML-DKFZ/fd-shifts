# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
in_path = "/Users/Paul/research/files/analysis/dropout_ms_sweep.csv"
df = pd.read_csv(in_path)

# %%
df.iloc[-1]
# Out:
# Unnamed: 0                                                    10
# name                     confidnet_model_bbvgg13_do1_avgpoolTrue
# study          new_class_study_tinyimagenet_resize_proposed_mode
# model                                            confidnet_model
# network                                                    vgg13
# fold                                                           0
# confid                                                  mcd_waic
# n_test                                                     17387
# accuracy                                                 0.48237
# nll                                                          NaN
# brier_score                                                  NaN
# failauc                                                  0.90558
# failap_suc                                               0.91667
# failap_err                                               0.89413
# mce                                                      0.46197
# ece                                                      0.19917
# e-aurc                                                   47.0971
# aurc                                                     213.057
# fpr@95tpr                                                0.46311
# Name: 290, dtype: object

# %%
len(df)
# Out:
# 291

# %%
df.groupby("study").count()
# Out:
#                                                    Unnamed: 0  name  model  \
# study
# iid_study                                                  67    67     67
# new_class_study_tinyimagenet_original_mode                 56    56     56
# new_class_study_tinyimagenet_proposed_mode                 56    56     56
# new_class_study_tinyimagenet_resize_original_mode          56    56     56
# new_class_study_tinyimagenet_resize_proposed_mode          56    56     56
#
#                                                    network  fold  confid  \
# study
# iid_study                                               67    67      67
# new_class_study_tinyimagenet_original_mode              56    56      56
# new_class_study_tinyimagenet_proposed_mode              56    56      56
# new_class_study_tinyimagenet_resize_original_mode       56    56      56
# new_class_study_tinyimagenet_resize_proposed_mode       56    56      56
#
#                                                    n_test  accuracy  nll  \
# study
# iid_study                                              67        67   67
# new_class_study_tinyimagenet_original_mode             56        56    0
# new_class_study_tinyimagenet_proposed_mode             56        56    0
# new_class_study_tinyimagenet_resize_original_mode      56        56    0
# new_class_study_tinyimagenet_resize_proposed_mode      56        56    0
#
#                                                    brier_score  failauc  \
# study
# iid_study                                                   67       67
# new_class_study_tinyimagenet_original_mode                   0       56
# new_class_study_tinyimagenet_proposed_mode                   0       56
# new_class_study_tinyimagenet_resize_original_mode            0       56
# new_class_study_tinyimagenet_resize_proposed_mode            0       56
#
#                                                    failap_suc  failap_err  \
# study
# iid_study                                                  67          67
# new_class_study_tinyimagenet_original_mode                 56          56
# new_class_study_tinyimagenet_proposed_mode                 56          56
# new_class_study_tinyimagenet_resize_original_mode          56          56
# new_class_study_tinyimagenet_resize_proposed_mode          56          56
#
#                                                    mce  ece  e-aurc  aurc  \
# study
# iid_study                                           67   67      67    67
# new_class_study_tinyimagenet_original_mode          56   56      56    56
# new_class_study_tinyimagenet_proposed_mode          56   56      56    56
# new_class_study_tinyimagenet_resize_original_mode   56   56      56    56
# new_class_study_tinyimagenet_resize_proposed_mode   56   56      56    56
#
#                                                    fpr@95tpr
# study
# iid_study                                                 67
# new_class_study_tinyimagenet_original_mode                56
# new_class_study_tinyimagenet_proposed_mode                56
# new_class_study_tinyimagenet_resize_original_mode         56
# new_class_study_tinyimagenet_resize_proposed_mode         56

# %%
df_clean = df.drop_duplicates(subset=["name", "study", "model", "network", "confid"])

# %%
len(df_clean)
# Out:
# 280

# %%
df_clean.groupby("name").count()
# Out:
#                                                  Unnamed: 0  study  model  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse          15     15     15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue           15     15     15
# confidnet_model_bbvgg13_do1_avgpoolFalse                 55     55     55
# confidnet_model_bbvgg13_do1_avgpoolTrue                  55     55     55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse          15     15     15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue           15     15     15
# confidnet_model_bbvgg16_do1_avgpoolFalse                 55     55     55
# confidnet_model_bbvgg16_do1_avgpoolTrue                  55     55     55
#
#                                                  network  fold  confid  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse       15    15      15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue        15    15      15
# confidnet_model_bbvgg13_do1_avgpoolFalse              55    55      55
# confidnet_model_bbvgg13_do1_avgpoolTrue               55    55      55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse       15    15      15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue        15    15      15
# confidnet_model_bbvgg16_do1_avgpoolFalse              55    55      55
# confidnet_model_bbvgg16_do1_avgpoolTrue               55    55      55
#
#                                                  n_test  accuracy  nll  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse      15        15    3
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue       15        15    3
# confidnet_model_bbvgg13_do1_avgpoolFalse             55        55   11
# confidnet_model_bbvgg13_do1_avgpoolTrue              55        55   11
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse      15        15    3
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue       15        15    3
# confidnet_model_bbvgg16_do1_avgpoolFalse             55        55   11
# confidnet_model_bbvgg16_do1_avgpoolTrue              55        55   11
#
#                                                  brier_score  failauc  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse            3       15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue             3       15
# confidnet_model_bbvgg13_do1_avgpoolFalse                  11       55
# confidnet_model_bbvgg13_do1_avgpoolTrue                   11       55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse            3       15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue             3       15
# confidnet_model_bbvgg16_do1_avgpoolFalse                  11       55
# confidnet_model_bbvgg16_do1_avgpoolTrue                   11       55
#
#                                                  failap_suc  failap_err  mce  \
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse          15          15   15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue           15          15   15
# confidnet_model_bbvgg13_do1_avgpoolFalse                 55          55   55
# confidnet_model_bbvgg13_do1_avgpoolTrue                  55          55   55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse          15          15   15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue           15          15   15
# confidnet_model_bbvgg16_do1_avgpoolFalse                 55          55   55
# confidnet_model_bbvgg16_do1_avgpoolTrue                  55          55   55
#
#                                                  ece  e-aurc  aurc  fpr@95tpr
# name
# confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse   15      15    15         15
# confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue    15      15    15         15
# confidnet_model_bbvgg13_do1_avgpoolFalse          55      55    55         55
# confidnet_model_bbvgg13_do1_avgpoolTrue           55      55    55         55
# confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse   15      15    15         15
# confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue    15      15    15         15
# confidnet_model_bbvgg16_do1_avgpoolFalse          55      55    55         55
# confidnet_model_bbvgg16_do1_avgpoolTrue           55      55    55         55

# %%
df_clean[df_clean.name=="det_devries_bbvgg16_doTrue_normTrue_schedCosineAnnealing"]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, study, model, network, fold, confid, n_test, accuracy, nll, brier_score, failauc, failap_suc, failap_err, mce, ece, e-aurc, aurc, fpr@95tpr]
# Index: []

# %%
df = df_clean

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
df[(df.study == "iid_study") & ~(df.name.str.contains("det"))][["name", "confid", "accuracy", "failauc", "failap_err", "aurc"]].sort_values(by="aurc", ascending=True)
# Out:
# <ipython-input-12-36b5d462abf3>:4: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                                                 name    confid  accuracy  \
# 123  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   tcp       0.95000
# 122  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   det_pe    0.95000
# 137  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   det_pe    0.94944
# 138  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   tcp       0.94944
# 121  confidnet_model_bbvgg13_do0_avgpoolTrue_msTrue   det_mcp   0.95000
# 136  confidnet_model_bbvgg16_do0_avgpoolTrue_msTrue   det_mcp   0.94944
# 82   confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_mcp   0.93178
# 5    confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_mcp   0.93389
# 10   confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_waic  0.93389
# 80   confidnet_model_bbvgg16_do1_avgpoolTrue          tcp_mcd   0.93178
# 3    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp_mcd   0.93389
# 197  confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_mcp   0.93189
# 60   confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_mcp   0.93322
# 81   confidnet_model_bbvgg16_do1_avgpoolTrue          tcp_waic  0.93178
# 83   confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_pe    0.93178
# 84   confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_ee    0.93178
# 4    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp_waic  0.93389
# 195  confidnet_model_bbvgg13_do1_avgpoolTrue          tcp_mcd   0.93189
# 58   confidnet_model_bbvgg16_do1_avgpoolFalse         tcp_mcd   0.93322
# 6    confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_pe    0.93389
# 7    confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_ee    0.93389
# 199  confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_ee    0.93189
# 198  confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_pe    0.93189
# 59   confidnet_model_bbvgg16_do1_avgpoolFalse         tcp_waic  0.93322
# 65   confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_waic  0.93322
# 196  confidnet_model_bbvgg13_do1_avgpoolTrue          tcp_waic  0.93189
# 86   confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_sv    0.93178
# 9    confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_sv    0.93389
# 61   confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_pe    0.93322
# 62   confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_ee    0.93322
# 85   confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_mi    0.93178
# 8    confidnet_model_bbvgg13_do1_avgpoolFalse         mcd_mi    0.93389
# 201  confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_sv    0.93189
# 64   confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_sv    0.93322
# 87   confidnet_model_bbvgg16_do1_avgpoolTrue          mcd_waic  0.93178
# 200  confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_mi    0.93189
# 63   confidnet_model_bbvgg16_do1_avgpoolFalse         mcd_mi    0.93322
# 202  confidnet_model_bbvgg13_do1_avgpoolTrue          mcd_waic  0.93189
# 153  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  tcp       0.91933
# 156  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  tcp       0.91433
# 151  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  det_mcp   0.91933
# 152  confidnet_model_bbvgg13_do0_avgpoolTrue_msFalse  det_pe    0.91933
# 155  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  det_pe    0.91433
# 154  confidnet_model_bbvgg16_do0_avgpoolTrue_msFalse  det_mcp   0.91433
# 193  confidnet_model_bbvgg13_do1_avgpoolTrue          det_pe    0.91067
# 192  confidnet_model_bbvgg13_do1_avgpoolTrue          det_mcp   0.91067
# 78   confidnet_model_bbvgg16_do1_avgpoolTrue          det_pe    0.90678
# 77   confidnet_model_bbvgg16_do1_avgpoolTrue          det_mcp   0.90678
# 1    confidnet_model_bbvgg13_do1_avgpoolFalse         det_pe    0.90844
# 0    confidnet_model_bbvgg13_do1_avgpoolFalse         det_mcp   0.90844
# 55   confidnet_model_bbvgg16_do1_avgpoolFalse         det_mcp   0.90633
# 56   confidnet_model_bbvgg16_do1_avgpoolFalse         det_pe    0.90633
# 194  confidnet_model_bbvgg13_do1_avgpoolTrue          tcp       0.91067
# 79   confidnet_model_bbvgg16_do1_avgpoolTrue          tcp       0.90678
# 2    confidnet_model_bbvgg13_do1_avgpoolFalse         tcp       0.90844
# 57   confidnet_model_bbvgg16_do1_avgpoolFalse         tcp       0.90633
#
#      failauc  failap_err      aurc
# 123  0.93102  0.40403     5.37355
# 122  0.93094  0.40864     5.38966
# 137  0.92982  0.40988     5.59104
# 138  0.92937  0.41983     5.66750
# 121  0.93104  0.40767     5.78015
# 136  0.92925  0.41399     5.98084
# 82   0.93146  0.44651     7.66681
# 5    0.92710  0.42706     7.71933
# 10   0.92373  0.42553     7.90406
# 80   0.92797  0.43413     7.91297
# 3    0.92214  0.39241     7.96341
# 197  0.92704  0.45735     7.99798
# 60   0.92408  0.41602     8.02344
# 81   0.92539  0.41777     8.09984
# 83   0.92453  0.41135     8.15743
# 84   0.92412  0.41124     8.18819
# 4    0.91910  0.37692     8.18933
# 195  0.92302  0.40678     8.22829
# 58   0.92113  0.39697     8.25845
# 6    0.91920  0.37988     8.29931
# 7    0.91742  0.37691     8.42337
# 199  0.91992  0.39743     8.43318
# 198  0.91950  0.39444     8.45691
# 59   0.91773  0.37754     8.46490
# 65   0.91839  0.40073     8.49664
# 196  0.91890  0.38538     8.53500
# 86   0.92048  0.37310     8.54390
# 9    0.91548  0.35851     8.59359
# 61   0.91551  0.37294     8.60115
# 62   0.91544  0.37799     8.60994
# 85   0.91557  0.37331     8.80977
# 8    0.91111  0.35870     8.92570
# 201  0.91407  0.36741     8.96258
# 64   0.90949  0.33777     9.07971
# 87   0.91431  0.40975     9.17646
# 200  0.90873  0.35389     9.29357
# 63   0.90373  0.33003     9.50719
# 202  0.90507  0.41373     9.71901
# 153  0.92857  0.51397     9.93319
# 156  0.93213  0.54917     10.23231
# 151  0.91875  0.46317     10.82619
# 152  0.91826  0.45976     10.84204
# 155  0.92075  0.49113     11.42780
# 154  0.92145  0.49507     11.49132
# 193  0.90808  0.44541     13.29697
# 192  0.90780  0.45093     13.52720
# 78   0.91407  0.46911     13.66292
# 77   0.91385  0.46803     13.97198
# 1    0.90292  0.45493     14.55412
# 0    0.90430  0.47068     14.60573
# 55   0.90160  0.46091     15.48298
# 56   0.90056  0.44982     15.69283
# 194  0.87886  0.37242     16.93979
# 79   0.88058  0.36838     17.58367
# 2    0.87448  0.37111     17.68603
# 57   0.87064  0.35502     18.81666

# %%
##  observations:
##  iid: cosine > multilr. norm equal. vgg16_do_false: good accuracy, horrible auc/aurc. if vgg16, then with do.

# %%
meanprops = dict(linestyle='-', linewidth=1, color='k', alpha=0.5)
whiskerprops=dict(linestyle='-', linewidth=0)

# %%
df["backbone"] = df.apply(lambda row: row["name"].split("bb")[1].split("_")[0], axis=1)
df["dropout"] = df.apply(lambda row: row["name"].split("do")[1].split("_")[0], axis=1)
df["pure_det"] = df.apply(lambda row: row["name"].split("_")[0], axis=1)
df["avg_pool"] = df.apply(lambda row: True if "avgpoolTrue" in row["name"] else False, axis=1)
df["ms"] = df.apply(lambda row: False if "msFalse" in row["name"] else True, axis=1)

# %%
data =  df[(df.study == "iid_study") & (df.confid == "det_mcp") ]
#data =  df[(df.study == "iid_study")  & (df.backbone == "vgg16") ]
dims = ["confid", "backbone", "dropout", "avg_pool", "ms"]
metrics = ["accuracy", "failauc", "aurc"]
scale = 5
f, axs = plt.subplots(nrows=len(dims), ncols=len(metrics), figsize=(len(metrics)*scale, len(dims)*scale))
for xix, dim in enumerate(dims):
    for yix, metric in enumerate(metrics):
        y = metric
        sns.stripplot(ax=axs[xix, yix], x=dim, y=metric, data=data)
        sns.boxplot(ax=axs[xix, yix], x=dim, y=metric, data=data, saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)
        axs[xix, yix].set_xticklabels(axs[xix, yix].get_xticklabels(),rotation=30)

plt.tight_layout()

# %%
sns.stripplot(x="pure_det", y="accuracy", data=df[(df.study == "iid_study") & (df.confid== "det_mcp")])
sns.boxplot(x="pure_det", y="accuracy", data=df[(df.study == "iid_study") & (df.confid== "det_mcp")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
sns.stripplot(x="sched", y="aurc", data=df[(df.study == "iid_study")])
sns.boxplot(x="sched", y="aurc", data=df[(df.study == "iid_study")], saturation=0, showbox=False, showcaps=False, showfliers=False, whiskerprops=whiskerprops, showmeans=True, meanprops=meanprops, meanline=True)

# %%
df[(df.study == "new_class_study_tinyimagenet_resize_original_mode")  & (df.confid=="devries")].name
